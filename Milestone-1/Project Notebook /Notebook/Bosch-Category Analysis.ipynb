# %% [markdown]
# ### Objective: Extract Summarized Categorical features of Bosch assembly line
#
# 1. Reject Null
# 2. View unique components per line
# 3. Get throughput per line
# 4. Get count unique components assembled per line

# %%
#Import Packages: 

from pyspark.sql import SparkSession 
from pyspark.sql.functions import *
from pyspark.sql.types import *
import zipfile
import pandas as pd
import numpy as np
import vaex
from pyspark.sql import functions as F
import re

# %%
#Create Spark sesison:

spark = SparkSession\
        .builder\
        .master("local[*]")\
        .appName('Spark Project')\
        .getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.0.33:4045">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Number of cores used: 
cores = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
print("You are working with", cores, "core(s)")
# Out:
# You are working with 1 core(s)

# %%
#Read csv files: 
category = spark.read.csv('../data/train_categorical.csv', header = True)
date  = spark.read.csv('../data/train_date.csv', header = True)
numeric = spark.read.csv('../data/train_numeric.csv', header = True)

# %%
#Create Temporary View to run SQl commands:
category.createOrReplaceTempView('category')
date.createOrReplaceTempView('date')
numeric.createOrReplaceTempView('numeric')

# %% [markdown]
# ### Initial Exploration:

# %%
#View Catgeory Schema: 
category.printSchema()
# Out:
# root
#  |-- Id: string (nullable = true)
#  |-- L0_S1_F25: string (nullable = true)
#  |-- L0_S1_F27: string (nullable = true)
#  |-- L0_S1_F29: string (nullable = true)
#  |-- L0_S1_F31: string (nullable = true)
#  |-- L0_S2_F33: string (nullable = true)
#  |-- L0_S2_F35: string (nullable = true)
#  |-- L0_S2_F37: string (nullable = true)
#  |-- L0_S2_F39: string (nullable = true)
#  |-- L0_S2_F41: string (nullable = true)
#  |-- L0_S2_F43: string (nullable = true)
#  |-- L0_S2_F45: string (nullable = true)
#  |-- L0_S2_F47: string (nullable = true)
#  |-- L0_S2_F49: string (nullable = true)
#  |-- L0_S2_F51: string (nullable = true)
#  |-- L0_S2_F53: string (nullable = true)
#  |-- L0_S2_F55: string (nullable = true)
#  |-- L0_S2_F57: string (nullable = true)
#  |-- L0_S2_F59: string (nullable = true)
#  |-- L0_S2_F61: string (nullable = true)
#  |-- L0_S2_F63: string (nullable = true)
#  |-- L0_S2_F65: string (nullable = true)
#  |-- L0_S2_F67: string (nullable = true)
#  |-- L0_S3_F69: string (nullable = true)
#  |-- L0_S3_F71: string (nullable = true)
#  |-- L0_S3_F73: string (nullable = true)
#  |-- L0_S3_F75: string (nullable = true)
#  |-- L0_S3_F77: string (nullable = true)
#  |-- L0_S3_F79: string (nullable = true)
#  |-- L0_S3_F81: string (nullable = true)
#  |-- L0_S3_F83: string (nullable = true)
#  |-- L0_S3_F85: string (nullable = true)
#  |-- L0_S3_F87: string (nullable = true)
#  |-- L0_S3_F89: string (nullable = true)
#  |-- L0_S3_F91: string (nullable = true)
#  |-- L0_S3_F93: string (nullable = true)
#  |-- L0_S3_F95: string (nullable = true)
#  |-- L0_S3_F97: string (nullable = true)
#  |-- L0_S3_F99: string (nullable = true)
#  |-- L0_S3_F101: string (nullable = true)
#  |-- L0_S3_F103: string (nullable = true)
#  |-- L0_S4_F105: string (nullable = true)
#  |-- L0_S4_F107: string (nullable = true)
#  |-- L0_S4_F108: string (nullable = true)
#  |-- L0_S4_F110: string (nullable = true)
#  |-- L0_S4_F112: string (nullable = true)
#  |-- L0_S4_F113: string (nullable = true)
#  |-- L0_S6_F119: string (nullable = true)
#  |-- L0_S6_F121: string (nullable = true)
#  |-- L0_S6_F123: string (nullable = true)
#  |-- L0_S6_F125: string (nullable = true)
#  |-- L0_S6_F126: string (nullable = true)
#  |-- L0_S6_F128: string (nullable = true)
#  |-- L0_S6_F129: string (nullable = true)
#  |-- L0_S6_F131: string (nullable = true)
#  |-- L0_S6_F133: string (nullable = true)
#  |-- L0_S6_F135: string (nullable = true)
#  |-- L0_S9_F151: string (nullable = true)
#  |-- L0_S9_F153: string (nullable = true)
#  |-- L0_S9_F154: string (nullable = true)
#  |-- L0_S9_F156: string (nullable = true)
#  |-- L0_S9_F158: string (nullable = true)
#  |-- L0_S9_F159: string (nullable = true)
#  |-- L0_S9_F161: string (nullable = true)
#  |-- L0_S9_F163: string (nullable = true)
#  |-- L0_S9_F164: string (nullable = true)
#  |-- L0_S9_F166: string (nullable = true)
#  |-- L0_S9_F168: string (nullable = true)
#  |-- L0_S9_F169: string (nullable = true)
#  |-- L0_S9_F171: string (nullable = true)
#  |-- L0_S9_F173: string (nullable = true)
#  |-- L0_S9_F174: string (nullable = true)
#  |-- L0_S9_F176: string (nullable = true)
#  |-- L0_S9_F178: string (nullable = true)
#  |-- L0_S9_F179: string (nullable = true)
#  |-- L0_S9_F181: string (nullable = true)
#  |-- L0_S9_F183: string (nullable = true)
#  |-- L0_S9_F184: string (nullable = true)
#  |-- L0_S9_F186: string (nullable = true)
#  |-- L0_S9_F188: string (nullable = true)
#  |-- L0_S9_F189: string (nullable = true)
#  |-- L0_S9_F191: string (nullable = true)
#  |-- L0_S9_F193: string (nullable = true)
#  |-- L0_S9_F194: string (nullable = true)
#  |-- L0_S9_F196: string (nullable = true)
#  |-- L0_S9_F198: string (nullable = true)
#  |-- L0_S9_F199: string (nullable = true)
#  |-- L0_S9_F201: string (nullable = true)
#  |-- L0_S9_F203: string (nullable = true)
#  |-- L0_S9_F204: string (nullable = true)
#  |-- L0_S9_F206: string (nullable = true)
#  |-- L0_S9_F208: string (nullable = true)
#  |-- L0_S9_F209: string (nullable = true)
#  |-- L0_S9_F211: string (nullable = true)
#  |-- L0_S9_F213: string (nullable = true)
#  |-- L0_S9_F214: string (nullable = true)
#  |-- L0_S10_F215: string (nullable = true)
#  |-- L0_S10_F217: string (nullable = true)
#  |-- L0_S10_F218: string (nullable = true)
#  |-- L0_S10_F220: string (nullable = true)
#  |-- L0_S10_F222: string (nullable = true)
#  |-- L0_S10_F223: string (nullable = true)
#  |-- L0_S10_F225: string (nullable = true)
#  |-- L0_S10_F227: string (nullable = true)
#  |-- L0_S10_F228: string (nullable = true)
#  |-- L0_S10_F230: string (nullable = true)
#  |-- L0_S10_F232: string (nullable = true)
#  |-- L0_S10_F233: string (nullable = true)
#  |-- L0_S10_F235: string (nullable = true)
#  |-- L0_S10_F237: string (nullable = true)
#  |-- L0_S10_F238: string (nullable = true)
#  |-- L0_S10_F240: string (nullable = true)
#  |-- L0_S10_F242: string (nullable = true)
#  |-- L0_S10_F243: string (nullable = true)
#  |-- L0_S10_F245: string (nullable = true)
#  |-- L0_S10_F247: string (nullable = true)
#  |-- L0_S10_F248: string (nullable = true)
#  |-- L0_S10_F250: string (nullable = true)
#  |-- L0_S10_F252: string (nullable = true)
#  |-- L0_S10_F253: string (nullable = true)
#  |-- L0_S10_F255: string (nullable = true)
#  |-- L0_S10_F257: string (nullable = true)
#  |-- L0_S10_F258: string (nullable = true)
#  |-- L0_S10_F260: string (nullable = true)
#  |-- L0_S10_F262: string (nullable = true)
#  |-- L0_S10_F263: string (nullable = true)
#  |-- L0_S10_F265: string (nullable = true)
#  |-- L0_S10_F267: string (nullable = true)
#  |-- L0_S10_F268: string (nullable = true)
#  |-- L0_S10_F270: string (nullable = true)
#  |-- L0_S10_F272: string (nullable = true)
#  |-- L0_S10_F273: string (nullable = true)
#  |-- L0_S10_F275: string (nullable = true)
#  |-- L0_S10_F277: string (nullable = true)
#  |-- L0_S10_F278: string (nullable = true)
#  |-- L0_S11_F279: string (nullable = true)
#  |-- L0_S11_F281: string (nullable = true)
#  |-- L0_S11_F283: string (nullable = true)
#  |-- L0_S11_F285: string (nullable = true)
#  |-- L0_S11_F287: string (nullable = true)
#  |-- L0_S11_F289: string (nullable = true)
#  |-- L0_S11_F291: string (nullable = true)
#  |-- L0_S11_F293: string (nullable = true)
#  |-- L0_S11_F295: string (nullable = true)
#  |-- L0_S11_F297: string (nullable = true)
#  |-- L0_S11_F299: string (nullable = true)
#  |-- L0_S11_F301: string (nullable = true)
#  |-- L0_S11_F303: string (nullable = true)
#  |-- L0_S11_F305: string (nullable = true)
#  |-- L0_S11_F307: string (nullable = true)
#  |-- L0_S11_F309: string (nullable = true)
#  |-- L0_S11_F311: string (nullable = true)
#  |-- L0_S11_F313: string (nullable = true)
#  |-- L0_S11_F315: string (nullable = true)
#  |-- L0_S11_F317: string (nullable = true)
#  |-- L0_S11_F319: string (nullable = true)
#  |-- L0_S11_F321: string (nullable = true)
#  |-- L0_S11_F323: string (nullable = true)
#  |-- L0_S11_F325: string (nullable = true)
#  |-- L0_S11_F327: string (nullable = true)
#  |-- L0_S11_F329: string (nullable = true)
#  |-- L0_S14_F359: string (nullable = true)
#  |-- L0_S14_F361: string (nullable = true)
#  |-- L0_S14_F363: string (nullable = true)
#  |-- L0_S14_F365: string (nullable = true)
#  |-- L0_S14_F367: string (nullable = true)
#  |-- L0_S14_F369: string (nullable = true)
#  |-- L0_S14_F371: string (nullable = true)
#  |-- L0_S14_F373: string (nullable = true)
#  |-- L0_S14_F375: string (nullable = true)
#  |-- L0_S14_F377: string (nullable = true)
#  |-- L0_S14_F379: string (nullable = true)
#  |-- L0_S14_F381: string (nullable = true)
#  |-- L0_S14_F383: string (nullable = true)
#  |-- L0_S14_F385: string (nullable = true)
#  |-- L0_S14_F387: string (nullable = true)
#  |-- L0_S14_F389: string (nullable = true)
#  |-- L0_S14_F391: string (nullable = true)
#  |-- L0_S14_F393: string (nullable = true)
#  |-- L0_S15_F396: string (nullable = true)
#  |-- L0_S15_F399: string (nullable = true)
#  |-- L0_S15_F402: string (nullable = true)
#  |-- L0_S15_F405: string (nullable = true)
#  |-- L0_S15_F408: string (nullable = true)
#  |-- L0_S15_F411: string (nullable = true)
#  |-- L0_S15_F414: string (nullable = true)
#  |-- L0_S15_F417: string (nullable = true)
#  |-- L0_S15_F420: string (nullable = true)
#  |-- L0_S16_F422: string (nullable = true)
#  |-- L0_S16_F424: string (nullable = true)
#  |-- L0_S16_F425: string (nullable = true)
#  |-- L0_S16_F427: string (nullable = true)
#  |-- L0_S16_F429: string (nullable = true)
#  |-- L0_S16_F430: string (nullable = true)
#  |-- L0_S18_F436: string (nullable = true)
#  |-- L0_S18_F438: string (nullable = true)
#  |-- L0_S18_F440: string (nullable = true)
#  |-- L0_S18_F442: string (nullable = true)
#  |-- L0_S18_F443: string (nullable = true)
#  |-- L0_S18_F445: string (nullable = true)
#  |-- L0_S18_F446: string (nullable = true)
#  |-- L0_S18_F448: string (nullable = true)
#  |-- L0_S18_F450: string (nullable = true)
#  |-- L0_S18_F452: string (nullable = true)
#  |-- L0_S21_F468: string (nullable = true)
#  |-- L0_S21_F470: string (nullable = true)
#  |-- L0_S21_F471: string (nullable = true)
#  |-- L0_S21_F473: string (nullable = true)
#  |-- L0_S21_F475: string (nullable = true)
#  |-- L0_S21_F476: string (nullable = true)
#  |-- L0_S21_F478: string (nullable = true)
#  |-- L0_S21_F480: string (nullable = true)
#  |-- L0_S21_F481: string (nullable = true)
#  |-- L0_S21_F483: string (nullable = true)
#  |-- L0_S21_F485: string (nullable = true)
#  |-- L0_S21_F486: string (nullable = true)
#  |-- L0_S21_F488: string (nullable = true)
#  |-- L0_S21_F490: string (nullable = true)
#  |-- L0_S21_F491: string (nullable = true)
#  |-- L0_S21_F493: string (nullable = true)
#  |-- L0_S21_F495: string (nullable = true)
#  |-- L0_S21_F496: string (nullable = true)
#  |-- L0_S21_F498: string (nullable = true)
#  |-- L0_S21_F500: string (nullable = true)
#  |-- L0_S21_F501: string (nullable = true)
#  |-- L0_S21_F503: string (nullable = true)
#  |-- L0_S21_F505: string (nullable = true)
#  |-- L0_S21_F506: string (nullable = true)
#  |-- L0_S21_F508: string (nullable = true)
#  |-- L0_S21_F510: string (nullable = true)
#  |-- L0_S21_F511: string (nullable = true)
#  |-- L0_S21_F513: string (nullable = true)
#  |-- L0_S21_F515: string (nullable = true)
#  |-- L0_S21_F516: string (nullable = true)
#  |-- L0_S21_F518: string (nullable = true)
#  |-- L0_S21_F520: string (nullable = true)
#  |-- L0_S21_F521: string (nullable = true)
#  |-- L0_S21_F523: string (nullable = true)
#  |-- L0_S21_F525: string (nullable = true)
#  |-- L0_S21_F526: string (nullable = true)
#  |-- L0_S21_F528: string (nullable = true)
#  |-- L0_S21_F530: string (nullable = true)
#  |-- L0_S21_F531: string (nullable = true)
#  |-- L0_S21_F533: string (nullable = true)
#  |-- L0_S21_F535: string (nullable = true)
#  |-- L0_S21_F536: string (nullable = true)
#  |-- L0_S21_F538: string (nullable = true)
#  |-- L0_S21_F540: string (nullable = true)
#  |-- L0_S21_F541: string (nullable = true)
#  |-- L0_S22_F542: string (nullable = true)
#  |-- L0_S22_F544: string (nullable = true)
#  |-- L0_S22_F545: string (nullable = true)
#  |-- L0_S22_F547: string (nullable = true)
#  |-- L0_S22_F549: string (nullable = true)
#  |-- L0_S22_F550: string (nullable = true)
#  |-- L0_S22_F552: string (nullable = true)
#  |-- L0_S22_F554: string (nullable = true)
#  |-- L0_S22_F555: string (nullable = true)
#  |-- L0_S22_F557: string (nullable = true)
#  |-- L0_S22_F559: string (nullable = true)
#  |-- L0_S22_F560: string (nullable = true)
#  |-- L0_S22_F562: string (nullable = true)
#  |-- L0_S22_F564: string (nullable = true)
#  |-- L0_S22_F565: string (nullable = true)
#  |-- L0_S22_F567: string (nullable = true)
#  |-- L0_S22_F569: string (nullable = true)
#  |-- L0_S22_F570: string (nullable = true)
#  |-- L0_S22_F572: string (nullable = true)
#  |-- L0_S22_F574: string (nullable = true)
#  |-- L0_S22_F575: string (nullable = true)
#  |-- L0_S22_F577: string (nullable = true)
#  |-- L0_S22_F579: string (nullable = true)
#  |-- L0_S22_F580: string (nullable = true)
#  |-- L0_S22_F582: string (nullable = true)
#  |-- L0_S22_F584: string (nullable = true)
#  |-- L0_S22_F585: string (nullable = true)
#  |-- L0_S22_F587: string (nullable = true)
#  |-- L0_S22_F589: string (nullable = true)
#  |-- L0_S22_F590: string (nullable = true)
#  |-- L0_S22_F592: string (nullable = true)
#  |-- L0_S22_F594: string (nullable = true)
#  |-- L0_S22_F595: string (nullable = true)
#  |-- L0_S22_F597: string (nullable = true)
#  |-- L0_S22_F599: string (nullable = true)
#  |-- L0_S22_F600: string (nullable = true)
#  |-- L0_S22_F602: string (nullable = true)
#  |-- L0_S22_F604: string (nullable = true)
#  |-- L0_S22_F605: string (nullable = true)
#  |-- L0_S22_F607: string (nullable = true)
#  |-- L0_S22_F609: string (nullable = true)
#  |-- L0_S22_F610: string (nullable = true)
#  |-- L0_S22_F612: string (nullable = true)
#  |-- L0_S22_F614: string (nullable = true)
#  |-- L0_S22_F615: string (nullable = true)
#  |-- L0_S23_F616: string (nullable = true)
#  |-- L0_S23_F618: string (nullable = true)
#  |-- L0_S23_F620: string (nullable = true)
#  |-- L0_S23_F622: string (nullable = true)
#  |-- L0_S23_F624: string (nullable = true)
#  |-- L0_S23_F626: string (nullable = true)
#  |-- L0_S23_F628: string (nullable = true)
#  |-- L0_S23_F630: string (nullable = true)
#  |-- L0_S23_F632: string (nullable = true)
#  |-- L0_S23_F634: string (nullable = true)
#  |-- L0_S23_F636: string (nullable = true)
#  |-- L0_S23_F638: string (nullable = true)
#  |-- L0_S23_F640: string (nullable = true)
#  |-- L0_S23_F642: string (nullable = true)
#  |-- L0_S23_F644: string (nullable = true)
#  |-- L0_S23_F646: string (nullable = true)
#  |-- L0_S23_F648: string (nullable = true)
#  |-- L0_S23_F650: string (nullable = true)
#  |-- L0_S23_F652: string (nullable = true)
#  |-- L0_S23_F654: string (nullable = true)
#  |-- L0_S23_F656: string (nullable = true)
#  |-- L0_S23_F658: string (nullable = true)
#  |-- L0_S23_F660: string (nullable = true)
#  |-- L0_S23_F662: string (nullable = true)
#  |-- L0_S23_F664: string (nullable = true)
#  |-- L0_S23_F666: string (nullable = true)
#  |-- L0_S23_F668: string (nullable = true)
#  |-- L0_S23_F670: string (nullable = true)
#  |-- L0_S23_F672: string (nullable = true)
#  |-- L0_S23_F674: string (nullable = true)
#  |-- L1_S24_F675: string (nullable = true)
#  |-- L1_S24_F676: string (nullable = true)
#  |-- L1_S24_F678: string (nullable = true)
#  |-- L1_S24_F680: string (nullable = true)
#  |-- L1_S24_F682: string (nullable = true)
#  |-- L1_S24_F684: string (nullable = true)
#  |-- L1_S24_F686: string (nullable = true)
#  |-- L1_S24_F688: string (nullable = true)
#  |-- L1_S24_F690: string (nullable = true)
#  |-- L1_S24_F692: string (nullable = true)
#  |-- L1_S24_F694: string (nullable = true)
#  |-- L1_S24_F695: string (nullable = true)
#  |-- L1_S24_F696: string (nullable = true)
#  |-- L1_S24_F698: string (nullable = true)
#  |-- L1_S24_F699: string (nullable = true)
#  |-- L1_S24_F701: string (nullable = true)
#  |-- L1_S24_F703: string (nullable = true)
#  |-- L1_S24_F704: string (nullable = true)
#  |-- L1_S24_F705: string (nullable = true)
#  |-- L1_S24_F706: string (nullable = true)
#  |-- L1_S24_F708: string (nullable = true)
#  |-- L1_S24_F709: string (nullable = true)
#  |-- L1_S24_F710: string (nullable = true)
#  |-- L1_S24_F711: string (nullable = true)
#  |-- L1_S24_F713: string (nullable = true)
#  |-- L1_S24_F714: string (nullable = true)
#  |-- L1_S24_F715: string (nullable = true)
#  |-- L1_S24_F717: string (nullable = true)
#  |-- L1_S24_F718: string (nullable = true)
#  |-- L1_S24_F720: string (nullable = true)
#  |-- L1_S24_F722: string (nullable = true)
#  |-- L1_S24_F723: string (nullable = true)
#  |-- L1_S24_F724: string (nullable = true)
#  |-- L1_S24_F726: string (nullable = true)
#  |-- L1_S24_F727: string (nullable = true)
#  |-- L1_S24_F729: string (nullable = true)
#  |-- L1_S24_F731: string (nullable = true)
#  |-- L1_S24_F732: string (nullable = true)
#  |-- L1_S24_F734: string (nullable = true)
#  |-- L1_S24_F736: string (nullable = true)
#  |-- L1_S24_F737: string (nullable = true)
#  |-- L1_S24_F738: string (nullable = true)
#  |-- L1_S24_F740: string (nullable = true)
#  |-- L1_S24_F741: string (nullable = true)
#  |-- L1_S24_F742: string (nullable = true)
#  |-- L1_S24_F744: string (nullable = true)
#  |-- L1_S24_F745: string (nullable = true)
#  |-- L1_S24_F747: string (nullable = true)
#  |-- L1_S24_F749: string (nullable = true)
#  |-- L1_S24_F750: string (nullable = true)
#  |-- L1_S24_F752: string (nullable = true)
#  |-- L1_S24_F754: string (nullable = true)
#  |-- L1_S24_F755: string (nullable = true)
#  |-- L1_S24_F757: string (nullable = true)
#  |-- L1_S24_F759: string (nullable = true)
#  |-- L1_S24_F760: string (nullable = true)
#  |-- L1_S24_F762: string (nullable = true)
#  |-- L1_S24_F764: string (nullable = true)
#  |-- L1_S24_F765: string (nullable = true)
#  |-- L1_S24_F767: string (nullable = true)
#  |-- L1_S24_F769: string (nullable = true)
#  |-- L1_S24_F770: string (nullable = true)
#  |-- L1_S24_F771: string (nullable = true)
#  |-- L1_S24_F773: string (nullable = true)
#  |-- L1_S24_F774: string (nullable = true)
#  |-- L1_S24_F776: string (nullable = true)
#  |-- L1_S24_F778: string (nullable = true)
#  |-- L1_S24_F779: string (nullable = true)
#  |-- L1_S24_F781: string (nullable = true)
#  |-- L1_S24_F783: string (nullable = true)
#  |-- L1_S24_F784: string (nullable = true)
#  |-- L1_S24_F786: string (nullable = true)
#  |-- L1_S24_F788: string (nullable = true)
#  |-- L1_S24_F789: string (nullable = true)
#  |-- L1_S24_F791: string (nullable = true)
#  |-- L1_S24_F793: string (nullable = true)
#  |-- L1_S24_F794: string (nullable = true)
#  |-- L1_S24_F796: string (nullable = true)
#  |-- L1_S24_F798: string (nullable = true)
#  |-- L1_S24_F799: string (nullable = true)
#  |-- L1_S24_F803: string (nullable = true)
#  |-- L1_S24_F805: string (nullable = true)
#  |-- L1_S24_F817: string (nullable = true)
#  |-- L1_S24_F819: string (nullable = true)
#  |-- L1_S24_F820: string (nullable = true)
#  |-- L1_S24_F821: string (nullable = true)
#  |-- L1_S24_F823: string (nullable = true)
#  |-- L1_S24_F824: string (nullable = true)
#  |-- L1_S24_F825: string (nullable = true)
#  |-- L1_S24_F827: string (nullable = true)
#  |-- L1_S24_F828: string (nullable = true)
#  |-- L1_S24_F830: string (nullable = true)
#  |-- L1_S24_F832: string (nullable = true)
#  |-- L1_S24_F833: string (nullable = true)
#  |-- L1_S24_F835: string (nullable = true)
#  |-- L1_S24_F837: string (nullable = true)
#  |-- L1_S24_F838: string (nullable = true)
#  |-- L1_S24_F840: string (nullable = true)
#  |-- L1_S24_F842: string (nullable = true)
#  |-- L1_S24_F843: string (nullable = true)
#  |-- L1_S24_F845: string (nullable = true)
#  |-- L1_S24_F847: string (nullable = true)
#  |-- L1_S24_F848: string (nullable = true)
#  |-- L1_S24_F849: string (nullable = true)
#  |-- L1_S24_F851: string (nullable = true)
#  |-- L1_S24_F852: string (nullable = true)
#  |-- L1_S24_F853: string (nullable = true)
#  |-- L1_S24_F855: string (nullable = true)
#  |-- L1_S24_F856: string (nullable = true)
#  |-- L1_S24_F858: string (nullable = true)
#  |-- L1_S24_F860: string (nullable = true)
#  |-- L1_S24_F861: string (nullable = true)
#  |-- L1_S24_F863: string (nullable = true)
#  |-- L1_S24_F865: string (nullable = true)
#  |-- L1_S24_F866: string (nullable = true)
#  |-- L1_S24_F868: string (nullable = true)
#  |-- L1_S24_F870: string (nullable = true)
#  |-- L1_S24_F871: string (nullable = true)
#  |-- L1_S24_F873: string (nullable = true)
#  |-- L1_S24_F875: string (nullable = true)
#  |-- L1_S24_F876: string (nullable = true)
#  |-- L1_S24_F878: string (nullable = true)
#  |-- L1_S24_F880: string (nullable = true)
#  |-- L1_S24_F881: string (nullable = true)
#  |-- L1_S24_F883: string (nullable = true)
#  |-- L1_S24_F885: string (nullable = true)
#  |-- L1_S24_F886: string (nullable = true)
#  |-- L1_S24_F888: string (nullable = true)
#  |-- L1_S24_F890: string (nullable = true)
#  |-- L1_S24_F891: string (nullable = true)
#  |-- L1_S24_F893: string (nullable = true)
#  |-- L1_S24_F895: string (nullable = true)
#  |-- L1_S24_F896: string (nullable = true)
#  |-- L1_S24_F898: string (nullable = true)
#  |-- L1_S24_F900: string (nullable = true)
#  |-- L1_S24_F901: string (nullable = true)
#  |-- L1_S24_F903: string (nullable = true)
#  |-- L1_S24_F905: string (nullable = true)
#  |-- L1_S24_F906: string (nullable = true)
#  |-- L1_S24_F908: string (nullable = true)
#  |-- L1_S24_F910: string (nullable = true)
#  |-- L1_S24_F911: string (nullable = true)
#  |-- L1_S24_F912: string (nullable = true)
#  |-- L1_S24_F914: string (nullable = true)
#  |-- L1_S24_F915: string (nullable = true)
#  |-- L1_S24_F916: string (nullable = true)
#  |-- L1_S24_F918: string (nullable = true)
#  |-- L1_S24_F919: string (nullable = true)
#  |-- L1_S24_F921: string (nullable = true)
#  |-- L1_S24_F923: string (nullable = true)
#  |-- L1_S24_F924: string (nullable = true)
#  |-- L1_S24_F926: string (nullable = true)
#  |-- L1_S24_F928: string (nullable = true)
#  |-- L1_S24_F929: string (nullable = true)
#  |-- L1_S24_F931: string (nullable = true)
#  |-- L1_S24_F933: string (nullable = true)
#  |-- L1_S24_F934: string (nullable = true)
#  |-- L1_S24_F936: string (nullable = true)
#  |-- L1_S24_F938: string (nullable = true)
#  |-- L1_S24_F939: string (nullable = true)
#  |-- L1_S24_F940: string (nullable = true)
#  |-- L1_S24_F942: string (nullable = true)
#  |-- L1_S24_F943: string (nullable = true)
#  |-- L1_S24_F944: string (nullable = true)
#  |-- L1_S24_F946: string (nullable = true)
#  |-- L1_S24_F947: string (nullable = true)
#  |-- L1_S24_F949: string (nullable = true)
#  |-- L1_S24_F951: string (nullable = true)
#  |-- L1_S24_F952: string (nullable = true)
#  |-- L1_S24_F954: string (nullable = true)
#  |-- L1_S24_F956: string (nullable = true)
#  |-- L1_S24_F957: string (nullable = true)
#  |-- L1_S24_F959: string (nullable = true)
#  |-- L1_S24_F961: string (nullable = true)
#  |-- L1_S24_F962: string (nullable = true)
#  |-- L1_S24_F964: string (nullable = true)
#  |-- L1_S24_F966: string (nullable = true)
#  |-- L1_S24_F967: string (nullable = true)
#  |-- L1_S24_F969: string (nullable = true)
#  |-- L1_S24_F971: string (nullable = true)
#  |-- L1_S24_F972: string (nullable = true)
#  |-- L1_S24_F974: string (nullable = true)
#  |-- L1_S24_F976: string (nullable = true)
#  |-- L1_S24_F977: string (nullable = true)
#  |-- L1_S24_F979: string (nullable = true)
#  |-- L1_S24_F981: string (nullable = true)
#  |-- L1_S24_F982: string (nullable = true)
#  |-- L1_S24_F984: string (nullable = true)
#  |-- L1_S24_F986: string (nullable = true)
#  |-- L1_S24_F987: string (nullable = true)
#  |-- L1_S24_F989: string (nullable = true)
#  |-- L1_S24_F991: string (nullable = true)
#  |-- L1_S24_F992: string (nullable = true)
#  |-- L1_S24_F994: string (nullable = true)
#  |-- L1_S24_F996: string (nullable = true)
#  |-- L1_S24_F997: string (nullable = true)
#  |-- L1_S24_F1017: string (nullable = true)
#  |-- L1_S24_F1019: string (nullable = true)
#  |-- L1_S24_F1020: string (nullable = true)
#  |-- L1_S24_F1022: string (nullable = true)
#  |-- L1_S24_F1024: string (nullable = true)
#  |-- L1_S24_F1025: string (nullable = true)
#  |-- L1_S24_F1027: string (nullable = true)
#  |-- L1_S24_F1029: string (nullable = true)
#  |-- L1_S24_F1030: string (nullable = true)
#  |-- L1_S24_F1032: string (nullable = true)
#  |-- L1_S24_F1034: string (nullable = true)
#  |-- L1_S24_F1035: string (nullable = true)
#  |-- L1_S24_F1037: string (nullable = true)
#  |-- L1_S24_F1039: string (nullable = true)
#  |-- L1_S24_F1040: string (nullable = true)
#  |-- L1_S24_F1042: string (nullable = true)
#  |-- L1_S24_F1044: string (nullable = true)
#  |-- L1_S24_F1045: string (nullable = true)
#  |-- L1_S24_F1047: string (nullable = true)
#  |-- L1_S24_F1049: string (nullable = true)
#  |-- L1_S24_F1050: string (nullable = true)
#  |-- L1_S24_F1052: string (nullable = true)
#  |-- L1_S24_F1054: string (nullable = true)
#  |-- L1_S24_F1055: string (nullable = true)
#  |-- L1_S24_F1057: string (nullable = true)
#  |-- L1_S24_F1059: string (nullable = true)
#  |-- L1_S24_F1060: string (nullable = true)
#  |-- L1_S24_F1061: string (nullable = true)
#  |-- L1_S24_F1063: string (nullable = true)
#  |-- L1_S24_F1064: string (nullable = true)
#  |-- L1_S24_F1065: string (nullable = true)
#  |-- L1_S24_F1067: string (nullable = true)
#  |-- L1_S24_F1069: string (nullable = true)
#  |-- L1_S24_F1071: string (nullable = true)
#  |-- L1_S24_F1073: string (nullable = true)
#  |-- L1_S24_F1075: string (nullable = true)
#  |-- L1_S24_F1076: string (nullable = true)
#  |-- L1_S24_F1078: string (nullable = true)
#  |-- L1_S24_F1080: string (nullable = true)
#  |-- L1_S24_F1082: string (nullable = true)
#  |-- L1_S24_F1084: string (nullable = true)
#  |-- L1_S24_F1086: string (nullable = true)
#  |-- L1_S24_F1088: string (nullable = true)
#  |-- L1_S24_F1090: string (nullable = true)
#  |-- L1_S24_F1091: string (nullable = true)
#  |-- L1_S24_F1093: string (nullable = true)
#  |-- L1_S24_F1095: string (nullable = true)
#  |-- L1_S24_F1097: string (nullable = true)
#  |-- L1_S24_F1099: string (nullable = true)
#  |-- L1_S24_F1101: string (nullable = true)
#  |-- L1_S24_F1103: string (nullable = true)
#  |-- L1_S24_F1105: string (nullable = true)
#  |-- L1_S24_F1107: string (nullable = true)
#  |-- L1_S24_F1109: string (nullable = true)
#  |-- L1_S24_F1111: string (nullable = true)
#  |-- L1_S24_F1113: string (nullable = true)
#  |-- L1_S24_F1114: string (nullable = true)
#  |-- L1_S24_F1115: string (nullable = true)
#  |-- L1_S24_F1117: string (nullable = true)
#  |-- L1_S24_F1119: string (nullable = true)
#  |-- L1_S24_F1121: string (nullable = true)
#  |-- L1_S24_F1123: string (nullable = true)
#  |-- L1_S24_F1125: string (nullable = true)
#  |-- L1_S24_F1127: string (nullable = true)
#  |-- L1_S24_F1129: string (nullable = true)
#  |-- L1_S24_F1131: string (nullable = true)
#  |-- L1_S24_F1133: string (nullable = true)
#  |-- L1_S24_F1136: string (nullable = true)
#  |-- L1_S24_F1137: string (nullable = true)
#  |-- L1_S24_F1139: string (nullable = true)
#  |-- L1_S24_F1140: string (nullable = true)
#  |-- L1_S24_F1142: string (nullable = true)
#  |-- L1_S24_F1144: string (nullable = true)
#  |-- L1_S24_F1147: string (nullable = true)
#  |-- L1_S24_F1150: string (nullable = true)
#  |-- L1_S24_F1152: string (nullable = true)
#  |-- L1_S24_F1154: string (nullable = true)
#  |-- L1_S24_F1156: string (nullable = true)
#  |-- L1_S24_F1157: string (nullable = true)
#  |-- L1_S24_F1159: string (nullable = true)
#  |-- L1_S24_F1160: string (nullable = true)
#  |-- L1_S24_F1162: string (nullable = true)
#  |-- L1_S24_F1164: string (nullable = true)
#  |-- L1_S24_F1165: string (nullable = true)
#  |-- L1_S24_F1167: string (nullable = true)
#  |-- L1_S24_F1169: string (nullable = true)
#  |-- L1_S24_F1177: string (nullable = true)
#  |-- L1_S24_F1179: string (nullable = true)
#  |-- L1_S24_F1181: string (nullable = true)
#  |-- L1_S24_F1183: string (nullable = true)
#  |-- L1_S24_F1185: string (nullable = true)
#  |-- L1_S24_F1187: string (nullable = true)
#  |-- L1_S24_F1188: string (nullable = true)
#  |-- L1_S24_F1189: string (nullable = true)
#  |-- L1_S24_F1191: string (nullable = true)
#  |-- L1_S24_F1192: string (nullable = true)
#  |-- L1_S24_F1193: string (nullable = true)
#  |-- L1_S24_F1195: string (nullable = true)
#  |-- L1_S24_F1196: string (nullable = true)
#  |-- L1_S24_F1198: string (nullable = true)
#  |-- L1_S24_F1200: string (nullable = true)
#  |-- L1_S24_F1201: string (nullable = true)
#  |-- L1_S24_F1203: string (nullable = true)
#  |-- L1_S24_F1205: string (nullable = true)
#  |-- L1_S24_F1206: string (nullable = true)
#  |-- L1_S24_F1208: string (nullable = true)
#  |-- L1_S24_F1210: string (nullable = true)
#  |-- L1_S24_F1211: string (nullable = true)
#  |-- L1_S24_F1213: string (nullable = true)
#  |-- L1_S24_F1215: string (nullable = true)
#  |-- L1_S24_F1216: string (nullable = true)
#  |-- L1_S24_F1217: string (nullable = true)
#  |-- L1_S24_F1219: string (nullable = true)
#  |-- L1_S24_F1220: string (nullable = true)
#  |-- L1_S24_F1221: string (nullable = true)
#  |-- L1_S24_F1223: string (nullable = true)
#  |-- L1_S24_F1224: string (nullable = true)
#  |-- L1_S24_F1226: string (nullable = true)
#  |-- L1_S24_F1228: string (nullable = true)
#  |-- L1_S24_F1229: string (nullable = true)
#  |-- L1_S24_F1231: string (nullable = true)
#  |-- L1_S24_F1233: string (nullable = true)
#  |-- L1_S24_F1234: string (nullable = true)
#  |-- L1_S24_F1236: string (nullable = true)
#  |-- L1_S24_F1238: string (nullable = true)
#  |-- L1_S24_F1239: string (nullable = true)
#  |-- L1_S24_F1241: string (nullable = true)
#  |-- L1_S24_F1243: string (nullable = true)
#  |-- L1_S24_F1244: string (nullable = true)
#  |-- L1_S24_F1246: string (nullable = true)
#  |-- L1_S24_F1248: string (nullable = true)
#  |-- L1_S24_F1249: string (nullable = true)
#  |-- L1_S24_F1251: string (nullable = true)
#  |-- L1_S24_F1253: string (nullable = true)
#  |-- L1_S24_F1254: string (nullable = true)
#  |-- L1_S24_F1256: string (nullable = true)
#  |-- L1_S24_F1258: string (nullable = true)
#  |-- L1_S24_F1259: string (nullable = true)
#  |-- L1_S24_F1261: string (nullable = true)
#  |-- L1_S24_F1263: string (nullable = true)
#  |-- L1_S24_F1264: string (nullable = true)
#  |-- L1_S24_F1266: string (nullable = true)
#  |-- L1_S24_F1268: string (nullable = true)
#  |-- L1_S24_F1269: string (nullable = true)
#  |-- L1_S24_F1271: string (nullable = true)
#  |-- L1_S24_F1273: string (nullable = true)
#  |-- L1_S24_F1274: string (nullable = true)
#  |-- L1_S24_F1276: string (nullable = true)
#  |-- L1_S24_F1278: string (nullable = true)
#  |-- L1_S24_F1279: string (nullable = true)
#  |-- L1_S24_F1280: string (nullable = true)
#  |-- L1_S24_F1282: string (nullable = true)
#  |-- L1_S24_F1283: string (nullable = true)
#  |-- L1_S24_F1284: string (nullable = true)
#  |-- L1_S24_F1286: string (nullable = true)
#  |-- L1_S24_F1287: string (nullable = true)
#  |-- L1_S24_F1289: string (nullable = true)
#  |-- L1_S24_F1291: string (nullable = true)
#  |-- L1_S24_F1292: string (nullable = true)
#  |-- L1_S24_F1294: string (nullable = true)
#  |-- L1_S24_F1296: string (nullable = true)
#  |-- L1_S24_F1297: string (nullable = true)
#  |-- L1_S24_F1299: string (nullable = true)
#  |-- L1_S24_F1301: string (nullable = true)
#  |-- L1_S24_F1302: string (nullable = true)
#  |-- L1_S24_F1304: string (nullable = true)
#  |-- L1_S24_F1306: string (nullable = true)
#  |-- L1_S24_F1307: string (nullable = true)
#  |-- L1_S24_F1308: string (nullable = true)
#  |-- L1_S24_F1310: string (nullable = true)
#  |-- L1_S24_F1311: string (nullable = true)
#  |-- L1_S24_F1312: string (nullable = true)
#  |-- L1_S24_F1314: string (nullable = true)
#  |-- L1_S24_F1315: string (nullable = true)
#  |-- L1_S24_F1317: string (nullable = true)
#  |-- L1_S24_F1319: string (nullable = true)
#  |-- L1_S24_F1320: string (nullable = true)
#  |-- L1_S24_F1322: string (nullable = true)
#  |-- L1_S24_F1324: string (nullable = true)
#  |-- L1_S24_F1325: string (nullable = true)
#  |-- L1_S24_F1327: string (nullable = true)
#  |-- L1_S24_F1329: string (nullable = true)
#  |-- L1_S24_F1330: string (nullable = true)
#  |-- L1_S24_F1332: string (nullable = true)
#  |-- L1_S24_F1334: string (nullable = true)
#  |-- L1_S24_F1335: string (nullable = true)
#  |-- L1_S24_F1337: string (nullable = true)
#  |-- L1_S24_F1339: string (nullable = true)
#  |-- L1_S24_F1340: string (nullable = true)
#  |-- L1_S24_F1342: string (nullable = true)
#  |-- L1_S24_F1344: string (nullable = true)
#  |-- L1_S24_F1345: string (nullable = true)
#  |-- L1_S24_F1347: string (nullable = true)
#  |-- L1_S24_F1349: string (nullable = true)
#  |-- L1_S24_F1350: string (nullable = true)
#  |-- L1_S24_F1352: string (nullable = true)
#  |-- L1_S24_F1354: string (nullable = true)
#  |-- L1_S24_F1355: string (nullable = true)
#  |-- L1_S24_F1357: string (nullable = true)
#  |-- L1_S24_F1359: string (nullable = true)
#  |-- L1_S24_F1360: string (nullable = true)
#  |-- L1_S24_F1362: string (nullable = true)
#  |-- L1_S24_F1364: string (nullable = true)
#  |-- L1_S24_F1365: string (nullable = true)
#  |-- L1_S24_F1367: string (nullable = true)
#  |-- L1_S24_F1369: string (nullable = true)
#  |-- L1_S24_F1370: string (nullable = true)
#  |-- L1_S24_F1372: string (nullable = true)
#  |-- L1_S24_F1374: string (nullable = true)
#  |-- L1_S24_F1375: string (nullable = true)
#  |-- L1_S24_F1377: string (nullable = true)
#  |-- L1_S24_F1379: string (nullable = true)
#  |-- L1_S24_F1380: string (nullable = true)
#  |-- L1_S24_F1382: string (nullable = true)
#  |-- L1_S24_F1384: string (nullable = true)
#  |-- L1_S24_F1385: string (nullable = true)
#  |-- L1_S24_F1387: string (nullable = true)
#  |-- L1_S24_F1389: string (nullable = true)
#  |-- L1_S24_F1390: string (nullable = true)
#  |-- L1_S24_F1392: string (nullable = true)
#  |-- L1_S24_F1394: string (nullable = true)
#  |-- L1_S24_F1395: string (nullable = true)
#  |-- L1_S24_F1397: string (nullable = true)
#  |-- L1_S24_F1399: string (nullable = true)
#  |-- L1_S24_F1400: string (nullable = true)
#  |-- L1_S24_F1402: string (nullable = true)
#  |-- L1_S24_F1404: string (nullable = true)
#  |-- L1_S24_F1405: string (nullable = true)
#  |-- L1_S24_F1407: string (nullable = true)
#  |-- L1_S24_F1409: string (nullable = true)
#  |-- L1_S24_F1410: string (nullable = true)
#  |-- L1_S24_F1412: string (nullable = true)
#  |-- L1_S24_F1414: string (nullable = true)
#  |-- L1_S24_F1415: string (nullable = true)
#  |-- L1_S24_F1417: string (nullable = true)
#  |-- L1_S24_F1419: string (nullable = true)
#  |-- L1_S24_F1420: string (nullable = true)
#  |-- L1_S24_F1422: string (nullable = true)
#  |-- L1_S24_F1424: string (nullable = true)
#  |-- L1_S24_F1425: string (nullable = true)
#  |-- L1_S24_F1427: string (nullable = true)
#  |-- L1_S24_F1429: string (nullable = true)
#  |-- L1_S24_F1430: string (nullable = true)
#  |-- L1_S24_F1432: string (nullable = true)
#  |-- L1_S24_F1434: string (nullable = true)
#  |-- L1_S24_F1435: string (nullable = true)
#  |-- L1_S24_F1437: string (nullable = true)
#  |-- L1_S24_F1439: string (nullable = true)
#  |-- L1_S24_F1440: string (nullable = true)
#  |-- L1_S24_F1442: string (nullable = true)
#  |-- L1_S24_F1444: string (nullable = true)
#  |-- L1_S24_F1445: string (nullable = true)
#  |-- L1_S24_F1447: string (nullable = true)
#  |-- L1_S24_F1449: string (nullable = true)
#  |-- L1_S24_F1450: string (nullable = true)
#  |-- L1_S24_F1452: string (nullable = true)
#  |-- L1_S24_F1454: string (nullable = true)
#  |-- L1_S24_F1455: string (nullable = true)
#  |-- L1_S24_F1456: string (nullable = true)
#  |-- L1_S24_F1458: string (nullable = true)
#  |-- L1_S24_F1459: string (nullable = true)
#  |-- L1_S24_F1460: string (nullable = true)
#  |-- L1_S24_F1462: string (nullable = true)
#  |-- L1_S24_F1464: string (nullable = true)
#  |-- L1_S24_F1466: string (nullable = true)
#  |-- L1_S24_F1468: string (nullable = true)
#  |-- L1_S24_F1470: string (nullable = true)
#  |-- L1_S24_F1471: string (nullable = true)
#  |-- L1_S24_F1473: string (nullable = true)
#  |-- L1_S24_F1475: string (nullable = true)
#  |-- L1_S24_F1477: string (nullable = true)
#  |-- L1_S24_F1479: string (nullable = true)
#  |-- L1_S24_F1481: string (nullable = true)
#  |-- L1_S24_F1483: string (nullable = true)
#  |-- L1_S24_F1485: string (nullable = true)
#  |-- L1_S24_F1487: string (nullable = true)
#  |-- L1_S24_F1489: string (nullable = true)
#  |-- L1_S24_F1491: string (nullable = true)
#  |-- L1_S24_F1493: string (nullable = true)
#  |-- L1_S24_F1495: string (nullable = true)
#  |-- L1_S24_F1497: string (nullable = true)
#  |-- L1_S24_F1499: string (nullable = true)
#  |-- L1_S24_F1501: string (nullable = true)
#  |-- L1_S24_F1503: string (nullable = true)
#  |-- L1_S24_F1505: string (nullable = true)
#  |-- L1_S24_F1507: string (nullable = true)
#  |-- L1_S24_F1509: string (nullable = true)
#  |-- L1_S24_F1510: string (nullable = true)
#  |-- L1_S24_F1521: string (nullable = true)
#  |-- L1_S24_F1523: string (nullable = true)
#  |-- L1_S24_F1524: string (nullable = true)
#  |-- L1_S24_F1525: string (nullable = true)
#  |-- L1_S24_F1526: string (nullable = true)
#  |-- L1_S24_F1528: string (nullable = true)
#  |-- L1_S24_F1529: string (nullable = true)
#  |-- L1_S24_F1530: string (nullable = true)
#  |-- L1_S24_F1531: string (nullable = true)
#  |-- L1_S24_F1533: string (nullable = true)
#  |-- L1_S24_F1534: string (nullable = true)
#  |-- L1_S24_F1535: string (nullable = true)
#  |-- L1_S24_F1537: string (nullable = true)
#  |-- L1_S24_F1538: string (nullable = true)
#  |-- L1_S24_F1540: string (nullable = true)
#  |-- L1_S24_F1542: string (nullable = true)
#  |-- L1_S24_F1543: string (nullable = true)
#  |-- L1_S24_F1545: string (nullable = true)
#  |-- L1_S24_F1547: string (nullable = true)
#  |-- L1_S24_F1548: string (nullable = true)
#  |-- L1_S24_F1549: string (nullable = true)
#  |-- L1_S24_F1551: string (nullable = true)
#  |-- L1_S24_F1552: string (nullable = true)
#  |-- L1_S24_F1553: string (nullable = true)
#  |-- L1_S24_F1555: string (nullable = true)
#  |-- L1_S24_F1556: string (nullable = true)
#  |-- L1_S24_F1557: string (nullable = true)
#  |-- L1_S24_F1559: string (nullable = true)
#  |-- L1_S24_F1560: string (nullable = true)
#  |-- L1_S24_F1561: string (nullable = true)
#  |-- L1_S24_F1563: string (nullable = true)
#  |-- L1_S24_F1564: string (nullable = true)
#  |-- L1_S24_F1577: string (nullable = true)
#  |-- L1_S24_F1580: string (nullable = true)
#  |-- L1_S24_F1582: string (nullable = true)
#  |-- L1_S24_F1584: string (nullable = true)
#  |-- L1_S24_F1585: string (nullable = true)
#  |-- L1_S24_F1586: string (nullable = true)
#  |-- L1_S24_F1588: string (nullable = true)
#  |-- L1_S24_F1589: string (nullable = true)
#  |-- L1_S24_F1590: string (nullable = true)
#  |-- L1_S24_F1592: string (nullable = true)
#  |-- L1_S24_F1593: string (nullable = true)
#  |-- L1_S24_F1595: string (nullable = true)
#  |-- L1_S24_F1597: string (nullable = true)
#  |-- L1_S24_F1598: string (nullable = true)
#  |-- L1_S24_F1600: string (nullable = true)
#  |-- L1_S24_F1602: string (nullable = true)
#  |-- L1_S24_F1603: string (nullable = true)
#  |-- L1_S24_F1605: string (nullable = true)
#  |-- L1_S24_F1607: string (nullable = true)
#  |-- L1_S24_F1608: string (nullable = true)
#  |-- L1_S24_F1610: string (nullable = true)
#  |-- L1_S24_F1612: string (nullable = true)
#  |-- L1_S24_F1613: string (nullable = true)
#  |-- L1_S24_F1614: string (nullable = true)
#  |-- L1_S24_F1616: string (nullable = true)
#  |-- L1_S24_F1617: string (nullable = true)
#  |-- L1_S24_F1618: string (nullable = true)
#  |-- L1_S24_F1620: string (nullable = true)
#  |-- L1_S24_F1621: string (nullable = true)
#  |-- L1_S24_F1623: string (nullable = true)
#  |-- L1_S24_F1625: string (nullable = true)
#  |-- L1_S24_F1626: string (nullable = true)
#  |-- L1_S24_F1628: string (nullable = true)
#  |-- L1_S24_F1630: string (nullable = true)
#  |-- L1_S24_F1631: string (nullable = true)
#  |-- L1_S24_F1633: string (nullable = true)
#  |-- L1_S24_F1635: string (nullable = true)
#  |-- L1_S24_F1636: string (nullable = true)
#  |-- L1_S24_F1638: string (nullable = true)
#  |-- L1_S24_F1640: string (nullable = true)
#  |-- L1_S24_F1641: string (nullable = true)
#  |-- L1_S24_F1643: string (nullable = true)
#  |-- L1_S24_F1645: string (nullable = true)
#  |-- L1_S24_F1646: string (nullable = true)
#  |-- L1_S24_F1648: string (nullable = true)
#  |-- L1_S24_F1650: string (nullable = true)
#  |-- L1_S24_F1651: string (nullable = true)
#  |-- L1_S24_F1653: string (nullable = true)
#  |-- L1_S24_F1655: string (nullable = true)
#  |-- L1_S24_F1656: string (nullable = true)
#  |-- L1_S24_F1658: string (nullable = true)
#  |-- L1_S24_F1660: string (nullable = true)
#  |-- L1_S24_F1661: string (nullable = true)
#  |-- L1_S24_F1663: string (nullable = true)
#  |-- L1_S24_F1665: string (nullable = true)
#  |-- L1_S24_F1666: string (nullable = true)
#  |-- L1_S24_F1668: string (nullable = true)
#  |-- L1_S24_F1670: string (nullable = true)
#  |-- L1_S24_F1671: string (nullable = true)
#  |-- L1_S24_F1673: string (nullable = true)
#  |-- L1_S24_F1675: string (nullable = true)
#  |-- L1_S24_F1676: string (nullable = true)
#  |-- L1_S24_F1677: string (nullable = true)
#  |-- L1_S24_F1679: string (nullable = true)
#  |-- L1_S24_F1680: string (nullable = true)
#  |-- L1_S24_F1681: string (nullable = true)
#  |-- L1_S24_F1683: string (nullable = true)
#  |-- L1_S24_F1684: string (nullable = true)
#  |-- L1_S24_F1686: string (nullable = true)
#  |-- L1_S24_F1688: string (nullable = true)
#  |-- L1_S24_F1689: string (nullable = true)
#  |-- L1_S24_F1691: string (nullable = true)
#  |-- L1_S24_F1693: string (nullable = true)
#  |-- L1_S24_F1694: string (nullable = true)
#  |-- L1_S24_F1696: string (nullable = true)
#  |-- L1_S24_F1698: string (nullable = true)
#  |-- L1_S24_F1699: string (nullable = true)
#  |-- L1_S24_F1701: string (nullable = true)
#  |-- L1_S24_F1703: string (nullable = true)
#  |-- L1_S24_F1704: string (nullable = true)
#  |-- L1_S24_F1705: string (nullable = true)
#  |-- L1_S24_F1707: string (nullable = true)
#  |-- L1_S24_F1708: string (nullable = true)
#  |-- L1_S24_F1709: string (nullable = true)
#  |-- L1_S24_F1711: string (nullable = true)
#  |-- L1_S24_F1712: string (nullable = true)
#  |-- L1_S24_F1714: string (nullable = true)
#  |-- L1_S24_F1716: string (nullable = true)
#  |-- L1_S24_F1717: string (nullable = true)
#  |-- L1_S24_F1719: string (nullable = true)
#  |-- L1_S24_F1721: string (nullable = true)
#  |-- L1_S24_F1722: string (nullable = true)
#  |-- L1_S24_F1724: string (nullable = true)
#  |-- L1_S24_F1726: string (nullable = true)
#  |-- L1_S24_F1727: string (nullable = true)
#  |-- L1_S24_F1729: string (nullable = true)
#  |-- L1_S24_F1731: string (nullable = true)
#  |-- L1_S24_F1732: string (nullable = true)
#  |-- L1_S24_F1734: string (nullable = true)
#  |-- L1_S24_F1736: string (nullable = true)
#  |-- L1_S24_F1737: string (nullable = true)
#  |-- L1_S24_F1739: string (nullable = true)
#  |-- L1_S24_F1741: string (nullable = true)
#  |-- L1_S24_F1742: string (nullable = true)
#  |-- L1_S24_F1744: string (nullable = true)
#  |-- L1_S24_F1746: string (nullable = true)
#  |-- L1_S24_F1747: string (nullable = true)
#  |-- L1_S24_F1749: string (nullable = true)
#  |-- L1_S24_F1751: string (nullable = true)
#  |-- L1_S24_F1752: string (nullable = true)
#  |-- L1_S24_F1754: string (nullable = true)
#  |-- L1_S24_F1756: string (nullable = true)
#  |-- L1_S24_F1757: string (nullable = true)
#  |-- L1_S24_F1759: string (nullable = true)
#  |-- L1_S24_F1761: string (nullable = true)
#  |-- L1_S24_F1762: string (nullable = true)
#  |-- L1_S24_F1764: string (nullable = true)
#  |-- L1_S24_F1766: string (nullable = true)
#  |-- L1_S24_F1767: string (nullable = true)
#  |-- L1_S24_F1769: string (nullable = true)
#  |-- L1_S24_F1771: string (nullable = true)
#  |-- L1_S24_F1772: string (nullable = true)
#  |-- L1_S24_F1774: string (nullable = true)
#  |-- L1_S24_F1776: string (nullable = true)
#  |-- L1_S24_F1777: string (nullable = true)
#  |-- L1_S24_F1779: string (nullable = true)
#  |-- L1_S24_F1781: string (nullable = true)
#  |-- L1_S24_F1782: string (nullable = true)
#  |-- L1_S24_F1784: string (nullable = true)
#  |-- L1_S24_F1786: string (nullable = true)
#  |-- L1_S24_F1787: string (nullable = true)
#  |-- L1_S24_F1789: string (nullable = true)
#  |-- L1_S24_F1791: string (nullable = true)
#  |-- L1_S24_F1792: string (nullable = true)
#  |-- L1_S24_F1794: string (nullable = true)
#  |-- L1_S24_F1796: string (nullable = true)
#  |-- L1_S24_F1797: string (nullable = true)
#  |-- L1_S24_F1799: string (nullable = true)
#  |-- L1_S24_F1801: string (nullable = true)
#  |-- L1_S24_F1802: string (nullable = true)
#  |-- L1_S24_F1804: string (nullable = true)
#  |-- L1_S24_F1806: string (nullable = true)
#  |-- L1_S24_F1807: string (nullable = true)
#  |-- L1_S24_F1827: string (nullable = true)
#  |-- L1_S25_F1852: string (nullable = true)
#  |-- L1_S25_F1853: string (nullable = true)
#  |-- L1_S25_F1856: string (nullable = true)
#  |-- L1_S25_F1859: string (nullable = true)
#  |-- L1_S25_F1861: string (nullable = true)
#  |-- L1_S25_F1863: string (nullable = true)
#  |-- L1_S25_F1866: string (nullable = true)
#  |-- L1_S25_F1868: string (nullable = true)
#  |-- L1_S25_F1870: string (nullable = true)
#  |-- L1_S25_F1872: string (nullable = true)
#  |-- L1_S25_F1874: string (nullable = true)
#  |-- L1_S25_F1876: string (nullable = true)
#  |-- L1_S25_F1878: string (nullable = true)
#  |-- L1_S25_F1880: string (nullable = true)
#  |-- L1_S25_F1882: string (nullable = true)
#  |-- L1_S25_F1884: string (nullable = true)
#  |-- L1_S25_F1886: string (nullable = true)
#  |-- L1_S25_F1888: string (nullable = true)
#  |-- L1_S25_F1889: string (nullable = true)
#  |-- L1_S25_F1897: string (nullable = true)
#  |-- L1_S25_F1899: string (nullable = true)
#  |-- L1_S25_F1901: string (nullable = true)
#  |-- L1_S25_F1903: string (nullable = true)
#  |-- L1_S25_F1904: string (nullable = true)
#  |-- L1_S25_F1905: string (nullable = true)
#  |-- L1_S25_F1907: string (nullable = true)
#  |-- L1_S25_F1908: string (nullable = true)
#  |-- L1_S25_F1910: string (nullable = true)
#  |-- L1_S25_F1912: string (nullable = true)
#  |-- L1_S25_F1913: string (nullable = true)
#  |-- L1_S25_F1915: string (nullable = true)
#  |-- L1_S25_F1917: string (nullable = true)
#  |-- L1_S25_F1918: string (nullable = true)
#  |-- L1_S25_F1920: string (nullable = true)
#  |-- L1_S25_F1922: string (nullable = true)
#  |-- L1_S25_F1923: string (nullable = true)
#  |-- L1_S25_F1925: string (nullable = true)
#  |-- L1_S25_F1927: string (nullable = true)
#  |-- L1_S25_F1928: string (nullable = true)
#  |-- L1_S25_F1930: string (nullable = true)
#  |-- L1_S25_F1932: string (nullable = true)
#  |-- L1_S25_F1933: string (nullable = true)
#  |-- L1_S25_F1934: string (nullable = true)
#  |-- L1_S25_F1936: string (nullable = true)
#  |-- L1_S25_F1937: string (nullable = true)
#  |-- L1_S25_F1939: string (nullable = true)
#  |-- L1_S25_F1941: string (nullable = true)
#  |-- L1_S25_F1942: string (nullable = true)
#  |-- L1_S25_F1944: string (nullable = true)
#  |-- L1_S25_F1946: string (nullable = true)
#  |-- L1_S25_F1947: string (nullable = true)
#  |-- L1_S25_F1949: string (nullable = true)
#  |-- L1_S25_F1951: string (nullable = true)
#  |-- L1_S25_F1952: string (nullable = true)
#  |-- L1_S25_F1954: string (nullable = true)
#  |-- L1_S25_F1956: string (nullable = true)
#  |-- L1_S25_F1957: string (nullable = true)
#  |-- L1_S25_F1959: string (nullable = true)
#  |-- L1_S25_F1961: string (nullable = true)
#  |-- L1_S25_F1962: string (nullable = true)
#  |-- L1_S25_F1964: string (nullable = true)
#  |-- L1_S25_F1966: string (nullable = true)
#  |-- L1_S25_F1967: string (nullable = true)
#  |-- L1_S25_F1969: string (nullable = true)
#  |-- L1_S25_F1971: string (nullable = true)
#  |-- L1_S25_F1972: string (nullable = true)
#  |-- L1_S25_F1974: string (nullable = true)
#  |-- L1_S25_F1976: string (nullable = true)
#  |-- L1_S25_F1977: string (nullable = true)
#  |-- L1_S25_F1979: string (nullable = true)
#  |-- L1_S25_F1981: string (nullable = true)
#  |-- L1_S25_F1982: string (nullable = true)
#  |-- L1_S25_F1983: string (nullable = true)
#  |-- L1_S25_F1985: string (nullable = true)
#  |-- L1_S25_F1986: string (nullable = true)
#  |-- L1_S25_F1988: string (nullable = true)
#  |-- L1_S25_F1990: string (nullable = true)
#  |-- L1_S25_F1991: string (nullable = true)
#  |-- L1_S25_F1993: string (nullable = true)
#  |-- L1_S25_F1995: string (nullable = true)
#  |-- L1_S25_F1996: string (nullable = true)
#  |-- L1_S25_F1998: string (nullable = true)
#  |-- L1_S25_F2000: string (nullable = true)
#  |-- L1_S25_F2001: string (nullable = true)
#  |-- L1_S25_F2003: string (nullable = true)
#  |-- L1_S25_F2005: string (nullable = true)
#  |-- L1_S25_F2006: string (nullable = true)
#  |-- L1_S25_F2008: string (nullable = true)
#  |-- L1_S25_F2010: string (nullable = true)
#  |-- L1_S25_F2011: string (nullable = true)
#  |-- L1_S25_F2012: string (nullable = true)
#  |-- L1_S25_F2014: string (nullable = true)
#  |-- L1_S25_F2015: string (nullable = true)
#  |-- L1_S25_F2017: string (nullable = true)
#  |-- L1_S25_F2019: string (nullable = true)
#  |-- L1_S25_F2020: string (nullable = true)
#  |-- L1_S25_F2022: string (nullable = true)
#  |-- L1_S25_F2024: string (nullable = true)
#  |-- L1_S25_F2025: string (nullable = true)
#  |-- L1_S25_F2027: string (nullable = true)
#  |-- L1_S25_F2029: string (nullable = true)
#  |-- L1_S25_F2030: string (nullable = true)
#  |-- L1_S25_F2032: string (nullable = true)
#  |-- L1_S25_F2034: string (nullable = true)
#  |-- L1_S25_F2035: string (nullable = true)
#  |-- L1_S25_F2037: string (nullable = true)
#  |-- L1_S25_F2039: string (nullable = true)
#  |-- L1_S25_F2040: string (nullable = true)
#  |-- L1_S25_F2042: string (nullable = true)
#  |-- L1_S25_F2044: string (nullable = true)
#  |-- L1_S25_F2045: string (nullable = true)
#  |-- L1_S25_F2047: string (nullable = true)
#  |-- L1_S25_F2049: string (nullable = true)
#  |-- L1_S25_F2050: string (nullable = true)
#  |-- L1_S25_F2052: string (nullable = true)
#  |-- L1_S25_F2054: string (nullable = true)
#  |-- L1_S25_F2055: string (nullable = true)
#  |-- L1_S25_F2057: string (nullable = true)
#  |-- L1_S25_F2059: string (nullable = true)
#  |-- L1_S25_F2060: string (nullable = true)
#  |-- L1_S25_F2062: string (nullable = true)
# ...
#  |-- L3_S30_F3503: string (nullable = true)
#  |-- L3_S30_F3505: string (nullable = true)
#  |-- L3_S30_F3507: string (nullable = true)
#  |-- L3_S30_F3508: string (nullable = true)
#  |-- L3_S30_F3510: string (nullable = true)
#  |-- L3_S30_F3512: string (nullable = true)
#  |-- L3_S30_F3513: string (nullable = true)
#  |-- L3_S30_F3515: string (nullable = true)
#  |-- L3_S30_F3517: string (nullable = true)
#  |-- L3_S30_F3518: string (nullable = true)
#  |-- L3_S30_F3520: string (nullable = true)
#  |-- L3_S30_F3522: string (nullable = true)
#  |-- L3_S30_F3523: string (nullable = true)
#  |-- L3_S30_F3525: string (nullable = true)
#  |-- L3_S30_F3527: string (nullable = true)
#  |-- L3_S30_F3528: string (nullable = true)
#  |-- L3_S30_F3530: string (nullable = true)
#  |-- L3_S30_F3532: string (nullable = true)
#  |-- L3_S30_F3533: string (nullable = true)
#  |-- L3_S30_F3535: string (nullable = true)
#  |-- L3_S30_F3537: string (nullable = true)
#  |-- L3_S30_F3538: string (nullable = true)
#  |-- L3_S30_F3540: string (nullable = true)
#  |-- L3_S30_F3542: string (nullable = true)
#  |-- L3_S30_F3543: string (nullable = true)
#  |-- L3_S30_F3545: string (nullable = true)
#  |-- L3_S30_F3547: string (nullable = true)
#  |-- L3_S30_F3548: string (nullable = true)
#  |-- L3_S30_F3550: string (nullable = true)
#  |-- L3_S30_F3552: string (nullable = true)
#  |-- L3_S30_F3553: string (nullable = true)
#  |-- L3_S30_F3555: string (nullable = true)
#  |-- L3_S30_F3557: string (nullable = true)
#  |-- L3_S30_F3558: string (nullable = true)
#  |-- L3_S30_F3560: string (nullable = true)
#  |-- L3_S30_F3562: string (nullable = true)
#  |-- L3_S30_F3563: string (nullable = true)
#  |-- L3_S30_F3565: string (nullable = true)
#  |-- L3_S30_F3567: string (nullable = true)
#  |-- L3_S30_F3568: string (nullable = true)
#  |-- L3_S30_F3570: string (nullable = true)
#  |-- L3_S30_F3572: string (nullable = true)
#  |-- L3_S30_F3573: string (nullable = true)
#  |-- L3_S30_F3575: string (nullable = true)
#  |-- L3_S30_F3577: string (nullable = true)
#  |-- L3_S30_F3578: string (nullable = true)
#  |-- L3_S30_F3580: string (nullable = true)
#  |-- L3_S30_F3582: string (nullable = true)
#  |-- L3_S30_F3583: string (nullable = true)
#  |-- L3_S30_F3585: string (nullable = true)
#  |-- L3_S30_F3587: string (nullable = true)
#  |-- L3_S30_F3588: string (nullable = true)
#  |-- L3_S30_F3590: string (nullable = true)
#  |-- L3_S30_F3592: string (nullable = true)
#  |-- L3_S30_F3593: string (nullable = true)
#  |-- L3_S30_F3595: string (nullable = true)
#  |-- L3_S30_F3597: string (nullable = true)
#  |-- L3_S30_F3598: string (nullable = true)
#  |-- L3_S30_F3600: string (nullable = true)
#  |-- L3_S30_F3602: string (nullable = true)
#  |-- L3_S30_F3603: string (nullable = true)
#  |-- L3_S30_F3605: string (nullable = true)
#  |-- L3_S30_F3607: string (nullable = true)
#  |-- L3_S30_F3608: string (nullable = true)
#  |-- L3_S30_F3610: string (nullable = true)
#  |-- L3_S30_F3612: string (nullable = true)
#  |-- L3_S30_F3613: string (nullable = true)
#  |-- L3_S30_F3615: string (nullable = true)
#  |-- L3_S30_F3617: string (nullable = true)
#  |-- L3_S30_F3618: string (nullable = true)
#  |-- L3_S30_F3620: string (nullable = true)
#  |-- L3_S30_F3622: string (nullable = true)
#  |-- L3_S30_F3623: string (nullable = true)
#  |-- L3_S30_F3625: string (nullable = true)
#  |-- L3_S30_F3627: string (nullable = true)
#  |-- L3_S30_F3628: string (nullable = true)
#  |-- L3_S30_F3630: string (nullable = true)
#  |-- L3_S30_F3632: string (nullable = true)
#  |-- L3_S30_F3633: string (nullable = true)
#  |-- L3_S30_F3635: string (nullable = true)
#  |-- L3_S30_F3637: string (nullable = true)
#  |-- L3_S30_F3638: string (nullable = true)
#  |-- L3_S30_F3640: string (nullable = true)
#  |-- L3_S30_F3642: string (nullable = true)
#  |-- L3_S30_F3643: string (nullable = true)
#  |-- L3_S30_F3645: string (nullable = true)
#  |-- L3_S30_F3647: string (nullable = true)
#  |-- L3_S30_F3648: string (nullable = true)
#  |-- L3_S30_F3650: string (nullable = true)
#  |-- L3_S30_F3652: string (nullable = true)
#  |-- L3_S30_F3653: string (nullable = true)
#  |-- L3_S30_F3655: string (nullable = true)
#  |-- L3_S30_F3657: string (nullable = true)
#  |-- L3_S30_F3658: string (nullable = true)
#  |-- L3_S30_F3660: string (nullable = true)
#  |-- L3_S30_F3662: string (nullable = true)
#  |-- L3_S30_F3663: string (nullable = true)
#  |-- L3_S30_F3665: string (nullable = true)
#  |-- L3_S30_F3667: string (nullable = true)
#  |-- L3_S30_F3668: string (nullable = true)
#  |-- L3_S30_F3670: string (nullable = true)
#  |-- L3_S30_F3672: string (nullable = true)
#  |-- L3_S30_F3673: string (nullable = true)
#  |-- L3_S30_F3675: string (nullable = true)
#  |-- L3_S30_F3677: string (nullable = true)
#  |-- L3_S30_F3678: string (nullable = true)
#  |-- L3_S30_F3680: string (nullable = true)
#  |-- L3_S30_F3682: string (nullable = true)
#  |-- L3_S30_F3683: string (nullable = true)
#  |-- L3_S30_F3685: string (nullable = true)
#  |-- L3_S30_F3687: string (nullable = true)
#  |-- L3_S30_F3688: string (nullable = true)
#  |-- L3_S30_F3690: string (nullable = true)
#  |-- L3_S30_F3692: string (nullable = true)
#  |-- L3_S30_F3693: string (nullable = true)
#  |-- L3_S30_F3695: string (nullable = true)
#  |-- L3_S30_F3697: string (nullable = true)
#  |-- L3_S30_F3698: string (nullable = true)
#  |-- L3_S30_F3700: string (nullable = true)
#  |-- L3_S30_F3702: string (nullable = true)
#  |-- L3_S30_F3703: string (nullable = true)
#  |-- L3_S30_F3705: string (nullable = true)
#  |-- L3_S30_F3707: string (nullable = true)
#  |-- L3_S30_F3708: string (nullable = true)
#  |-- L3_S30_F3710: string (nullable = true)
#  |-- L3_S30_F3712: string (nullable = true)
#  |-- L3_S30_F3713: string (nullable = true)
#  |-- L3_S30_F3715: string (nullable = true)
#  |-- L3_S30_F3717: string (nullable = true)
#  |-- L3_S30_F3718: string (nullable = true)
#  |-- L3_S30_F3720: string (nullable = true)
#  |-- L3_S30_F3722: string (nullable = true)
#  |-- L3_S30_F3723: string (nullable = true)
#  |-- L3_S30_F3725: string (nullable = true)
#  |-- L3_S30_F3727: string (nullable = true)
#  |-- L3_S30_F3728: string (nullable = true)
#  |-- L3_S30_F3730: string (nullable = true)
#  |-- L3_S30_F3732: string (nullable = true)
#  |-- L3_S30_F3733: string (nullable = true)
#  |-- L3_S30_F3735: string (nullable = true)
#  |-- L3_S30_F3737: string (nullable = true)
#  |-- L3_S30_F3738: string (nullable = true)
#  |-- L3_S30_F3740: string (nullable = true)
#  |-- L3_S30_F3742: string (nullable = true)
#  |-- L3_S30_F3743: string (nullable = true)
#  |-- L3_S30_F3745: string (nullable = true)
#  |-- L3_S30_F3747: string (nullable = true)
#  |-- L3_S30_F3748: string (nullable = true)
#  |-- L3_S30_F3750: string (nullable = true)
#  |-- L3_S30_F3752: string (nullable = true)
#  |-- L3_S30_F3753: string (nullable = true)
#  |-- L3_S30_F3755: string (nullable = true)
#  |-- L3_S30_F3757: string (nullable = true)
#  |-- L3_S30_F3758: string (nullable = true)
#  |-- L3_S30_F3760: string (nullable = true)
#  |-- L3_S30_F3762: string (nullable = true)
#  |-- L3_S30_F3763: string (nullable = true)
#  |-- L3_S30_F3765: string (nullable = true)
#  |-- L3_S30_F3767: string (nullable = true)
#  |-- L3_S30_F3768: string (nullable = true)
#  |-- L3_S30_F3770: string (nullable = true)
#  |-- L3_S30_F3772: string (nullable = true)
#  |-- L3_S30_F3773: string (nullable = true)
#  |-- L3_S30_F3775: string (nullable = true)
#  |-- L3_S30_F3777: string (nullable = true)
#  |-- L3_S30_F3778: string (nullable = true)
#  |-- L3_S30_F3780: string (nullable = true)
#  |-- L3_S30_F3782: string (nullable = true)
#  |-- L3_S30_F3783: string (nullable = true)
#  |-- L3_S30_F3785: string (nullable = true)
#  |-- L3_S30_F3787: string (nullable = true)
#  |-- L3_S30_F3788: string (nullable = true)
#  |-- L3_S30_F3790: string (nullable = true)
#  |-- L3_S30_F3792: string (nullable = true)
#  |-- L3_S30_F3793: string (nullable = true)
#  |-- L3_S30_F3795: string (nullable = true)
#  |-- L3_S30_F3797: string (nullable = true)
#  |-- L3_S30_F3798: string (nullable = true)
#  |-- L3_S30_F3800: string (nullable = true)
#  |-- L3_S30_F3802: string (nullable = true)
#  |-- L3_S30_F3803: string (nullable = true)
#  |-- L3_S30_F3805: string (nullable = true)
#  |-- L3_S30_F3807: string (nullable = true)
#  |-- L3_S30_F3808: string (nullable = true)
#  |-- L3_S30_F3810: string (nullable = true)
#  |-- L3_S30_F3812: string (nullable = true)
#  |-- L3_S30_F3813: string (nullable = true)
#  |-- L3_S30_F3815: string (nullable = true)
#  |-- L3_S30_F3817: string (nullable = true)
#  |-- L3_S30_F3818: string (nullable = true)
#  |-- L3_S30_F3820: string (nullable = true)
#  |-- L3_S30_F3822: string (nullable = true)
#  |-- L3_S30_F3823: string (nullable = true)
#  |-- L3_S30_F3825: string (nullable = true)
#  |-- L3_S30_F3827: string (nullable = true)
#  |-- L3_S30_F3828: string (nullable = true)
#  |-- L3_S30_F3830: string (nullable = true)
#  |-- L3_S30_F3832: string (nullable = true)
#  |-- L3_S30_F3833: string (nullable = true)
#  |-- L3_S31_F3835: string (nullable = true)
#  |-- L3_S31_F3837: string (nullable = true)
#  |-- L3_S31_F3839: string (nullable = true)
#  |-- L3_S31_F3841: string (nullable = true)
#  |-- L3_S31_F3843: string (nullable = true)
#  |-- L3_S31_F3845: string (nullable = true)
#  |-- L3_S31_F3847: string (nullable = true)
#  |-- L3_S31_F3849: string (nullable = true)
#  |-- L3_S32_F3851: string (nullable = true)
#  |-- L3_S32_F3853: string (nullable = true)
#  |-- L3_S32_F3854: string (nullable = true)
#  |-- L3_S35_F3885: string (nullable = true)
#  |-- L3_S35_F3887: string (nullable = true)
#  |-- L3_S35_F3888: string (nullable = true)
#  |-- L3_S35_F3890: string (nullable = true)
#  |-- L3_S35_F3892: string (nullable = true)
#  |-- L3_S35_F3893: string (nullable = true)
#  |-- L3_S35_F3899: string (nullable = true)
#  |-- L3_S35_F3901: string (nullable = true)
#  |-- L3_S35_F3902: string (nullable = true)
#  |-- L3_S35_F3904: string (nullable = true)
#  |-- L3_S35_F3906: string (nullable = true)
#  |-- L3_S35_F3907: string (nullable = true)
#  |-- L3_S35_F3909: string (nullable = true)
#  |-- L3_S35_F3911: string (nullable = true)
#  |-- L3_S35_F3912: string (nullable = true)
#  |-- L3_S35_F3914: string (nullable = true)
#  |-- L3_S35_F3916: string (nullable = true)
#  |-- L3_S35_F3917: string (nullable = true)
#  |-- L3_S36_F3927: string (nullable = true)
#  |-- L3_S36_F3929: string (nullable = true)
#  |-- L3_S36_F3931: string (nullable = true)
#  |-- L3_S36_F3933: string (nullable = true)
#  |-- L3_S36_F3935: string (nullable = true)
#  |-- L3_S36_F3937: string (nullable = true)
#  |-- L3_S36_F3939: string (nullable = true)
#  |-- L3_S36_F3941: string (nullable = true)
#  |-- L3_S38_F3954: string (nullable = true)
#  |-- L3_S38_F3955: string (nullable = true)
#  |-- L3_S38_F3958: string (nullable = true)
#  |-- L3_S38_F3959: string (nullable = true)
#  |-- L3_S38_F3962: string (nullable = true)
#  |-- L3_S38_F3963: string (nullable = true)
#  |-- L3_S39_F3965: string (nullable = true)
#  |-- L3_S39_F3967: string (nullable = true)
#  |-- L3_S39_F3969: string (nullable = true)
#  |-- L3_S39_F3971: string (nullable = true)
#  |-- L3_S39_F3973: string (nullable = true)
#  |-- L3_S39_F3975: string (nullable = true)
#  |-- L3_S39_F3977: string (nullable = true)
#  |-- L3_S39_F3979: string (nullable = true)
#  |-- L3_S42_F4028: string (nullable = true)
#  |-- L3_S42_F4030: string (nullable = true)
#  |-- L3_S42_F4031: string (nullable = true)
#  |-- L3_S42_F4032: string (nullable = true)
#  |-- L3_S42_F4034: string (nullable = true)
#  |-- L3_S42_F4035: string (nullable = true)
#  |-- L3_S42_F4036: string (nullable = true)
#  |-- L3_S42_F4038: string (nullable = true)
#  |-- L3_S42_F4039: string (nullable = true)
#  |-- L3_S42_F4040: string (nullable = true)
#  |-- L3_S42_F4042: string (nullable = true)
#  |-- L3_S42_F4043: string (nullable = true)
#  |-- L3_S42_F4044: string (nullable = true)
#  |-- L3_S42_F4046: string (nullable = true)
#  |-- L3_S42_F4047: string (nullable = true)
#  |-- L3_S42_F4048: string (nullable = true)
#  |-- L3_S42_F4050: string (nullable = true)
#  |-- L3_S42_F4051: string (nullable = true)
#  |-- L3_S42_F4052: string (nullable = true)
#  |-- L3_S42_F4054: string (nullable = true)
#  |-- L3_S42_F4055: string (nullable = true)
#  |-- L3_S42_F4056: string (nullable = true)
#  |-- L3_S42_F4058: string (nullable = true)
#  |-- L3_S42_F4059: string (nullable = true)
#  |-- L3_S43_F4061: string (nullable = true)
#  |-- L3_S43_F4063: string (nullable = true)
#  |-- L3_S43_F4064: string (nullable = true)
#  |-- L3_S43_F4066: string (nullable = true)
#  |-- L3_S43_F4068: string (nullable = true)
#  |-- L3_S43_F4069: string (nullable = true)
#  |-- L3_S43_F4071: string (nullable = true)
#  |-- L3_S43_F4073: string (nullable = true)
#  |-- L3_S43_F4074: string (nullable = true)
#  |-- L3_S43_F4076: string (nullable = true)
#  |-- L3_S43_F4078: string (nullable = true)
#  |-- L3_S43_F4079: string (nullable = true)
#  |-- L3_S43_F4081: string (nullable = true)
#  |-- L3_S43_F4083: string (nullable = true)
#  |-- L3_S43_F4084: string (nullable = true)
#  |-- L3_S43_F4086: string (nullable = true)
#  |-- L3_S43_F4088: string (nullable = true)
#  |-- L3_S43_F4089: string (nullable = true)
#  |-- L3_S43_F4091: string (nullable = true)
#  |-- L3_S43_F4093: string (nullable = true)
#  |-- L3_S43_F4094: string (nullable = true)
#  |-- L3_S43_F4096: string (nullable = true)
#  |-- L3_S43_F4098: string (nullable = true)
#  |-- L3_S43_F4099: string (nullable = true)
#  |-- L3_S44_F4102: string (nullable = true)
#  |-- L3_S44_F4105: string (nullable = true)
#  |-- L3_S44_F4108: string (nullable = true)
#  |-- L3_S44_F4111: string (nullable = true)
#  |-- L3_S44_F4114: string (nullable = true)
#  |-- L3_S44_F4117: string (nullable = true)
#  |-- L3_S44_F4120: string (nullable = true)
#  |-- L3_S44_F4123: string (nullable = true)
#  |-- L3_S46_F4134: string (nullable = true)
#  |-- L3_S46_F4136: string (nullable = true)
#  |-- L3_S46_F4137: string (nullable = true)
#  |-- L3_S47_F4139: string (nullable = true)
#  |-- L3_S47_F4141: string (nullable = true)
#  |-- L3_S47_F4142: string (nullable = true)
#  |-- L3_S47_F4144: string (nullable = true)
#  |-- L3_S47_F4146: string (nullable = true)
#  |-- L3_S47_F4147: string (nullable = true)
#  |-- L3_S47_F4149: string (nullable = true)
#  |-- L3_S47_F4151: string (nullable = true)
#  |-- L3_S47_F4152: string (nullable = true)
#  |-- L3_S47_F4154: string (nullable = true)
#  |-- L3_S47_F4156: string (nullable = true)
#  |-- L3_S47_F4157: string (nullable = true)
#  |-- L3_S47_F4159: string (nullable = true)
#  |-- L3_S47_F4161: string (nullable = true)
#  |-- L3_S47_F4162: string (nullable = true)
#  |-- L3_S47_F4164: string (nullable = true)
#  |-- L3_S47_F4166: string (nullable = true)
#  |-- L3_S47_F4167: string (nullable = true)
#  |-- L3_S47_F4169: string (nullable = true)
#  |-- L3_S47_F4171: string (nullable = true)
#  |-- L3_S47_F4172: string (nullable = true)
#  |-- L3_S47_F4174: string (nullable = true)
#  |-- L3_S47_F4176: string (nullable = true)
#  |-- L3_S47_F4177: string (nullable = true)
#  |-- L3_S47_F4179: string (nullable = true)
#  |-- L3_S47_F4181: string (nullable = true)
#  |-- L3_S47_F4182: string (nullable = true)
#  |-- L3_S47_F4184: string (nullable = true)
#  |-- L3_S47_F4186: string (nullable = true)
#  |-- L3_S47_F4187: string (nullable = true)
#  |-- L3_S47_F4189: string (nullable = true)
#  |-- L3_S47_F4191: string (nullable = true)
#  |-- L3_S47_F4192: string (nullable = true)
#  |-- L3_S49_F4207: string (nullable = true)
#  |-- L3_S49_F4209: string (nullable = true)
#  |-- L3_S49_F4210: string (nullable = true)
#  |-- L3_S49_F4212: string (nullable = true)
#  |-- L3_S49_F4214: string (nullable = true)
#  |-- L3_S49_F4215: string (nullable = true)
#  |-- L3_S49_F4217: string (nullable = true)
#  |-- L3_S49_F4219: string (nullable = true)
#  |-- L3_S49_F4220: string (nullable = true)
#  |-- L3_S49_F4222: string (nullable = true)
#  |-- L3_S49_F4224: string (nullable = true)
#  |-- L3_S49_F4225: string (nullable = true)
#  |-- L3_S49_F4227: string (nullable = true)
#  |-- L3_S49_F4229: string (nullable = true)
#  |-- L3_S49_F4230: string (nullable = true)
#  |-- L3_S49_F4232: string (nullable = true)
#  |-- L3_S49_F4234: string (nullable = true)
#  |-- L3_S49_F4235: string (nullable = true)
#  |-- L3_S49_F4237: string (nullable = true)
#  |-- L3_S49_F4239: string (nullable = true)
#  |-- L3_S49_F4240: string (nullable = true)

# %%
#Line 0, station 1 and feature 25 has a component T1 used 25 times: 
(category.select('L0_S2_F35').filter(category['L0_S2_F35'].isNotNull())).groupby('L0_S2_F35').count().show()
# Out:
# +---------+-----+
# |L0_S2_F35|count|
# +---------+-----+
# |     T128|   20|
# |      T64|   22|
# |      T32|  178|
# |      T96|   29|
# |       T4|    1|
# |      T48|   13|
# +---------+-----+

# %%
#View date Schema:
date.printSchema()
#looks like dates are saved as string.
# Out:
# root
#  |-- Id: string (nullable = true)
#  |-- L0_S0_D1: string (nullable = true)
#  |-- L0_S0_D3: string (nullable = true)
#  |-- L0_S0_D5: string (nullable = true)
#  |-- L0_S0_D7: string (nullable = true)
#  |-- L0_S0_D9: string (nullable = true)
#  |-- L0_S0_D11: string (nullable = true)
#  |-- L0_S0_D13: string (nullable = true)
#  |-- L0_S0_D15: string (nullable = true)
#  |-- L0_S0_D17: string (nullable = true)
#  |-- L0_S0_D19: string (nullable = true)
#  |-- L0_S0_D21: string (nullable = true)
#  |-- L0_S0_D23: string (nullable = true)
#  |-- L0_S1_D26: string (nullable = true)
#  |-- L0_S1_D30: string (nullable = true)
#  |-- L0_S2_D34: string (nullable = true)
#  |-- L0_S2_D38: string (nullable = true)
#  |-- L0_S2_D42: string (nullable = true)
#  |-- L0_S2_D46: string (nullable = true)
#  |-- L0_S2_D50: string (nullable = true)
#  |-- L0_S2_D54: string (nullable = true)
#  |-- L0_S2_D58: string (nullable = true)
#  |-- L0_S2_D62: string (nullable = true)
#  |-- L0_S2_D66: string (nullable = true)
#  |-- L0_S3_D70: string (nullable = true)
#  |-- L0_S3_D74: string (nullable = true)
#  |-- L0_S3_D78: string (nullable = true)
#  |-- L0_S3_D82: string (nullable = true)
#  |-- L0_S3_D86: string (nullable = true)
#  |-- L0_S3_D90: string (nullable = true)
#  |-- L0_S3_D94: string (nullable = true)
#  |-- L0_S3_D98: string (nullable = true)
#  |-- L0_S3_D102: string (nullable = true)
#  |-- L0_S4_D106: string (nullable = true)
#  |-- L0_S4_D111: string (nullable = true)
#  |-- L0_S5_D115: string (nullable = true)
#  |-- L0_S5_D117: string (nullable = true)
#  |-- L0_S6_D120: string (nullable = true)
#  |-- L0_S6_D124: string (nullable = true)
#  |-- L0_S6_D127: string (nullable = true)
#  |-- L0_S6_D130: string (nullable = true)
#  |-- L0_S6_D134: string (nullable = true)
#  |-- L0_S7_D137: string (nullable = true)
#  |-- L0_S7_D139: string (nullable = true)
#  |-- L0_S7_D140: string (nullable = true)
#  |-- L0_S7_D141: string (nullable = true)
#  |-- L0_S7_D143: string (nullable = true)
#  |-- L0_S8_D145: string (nullable = true)
#  |-- L0_S8_D147: string (nullable = true)
#  |-- L0_S8_D148: string (nullable = true)
#  |-- L0_S8_D150: string (nullable = true)
#  |-- L0_S9_D152: string (nullable = true)
#  |-- L0_S9_D157: string (nullable = true)
#  |-- L0_S9_D162: string (nullable = true)
#  |-- L0_S9_D167: string (nullable = true)
#  |-- L0_S9_D172: string (nullable = true)
#  |-- L0_S9_D177: string (nullable = true)
#  |-- L0_S9_D182: string (nullable = true)
#  |-- L0_S9_D187: string (nullable = true)
#  |-- L0_S9_D192: string (nullable = true)
#  |-- L0_S9_D197: string (nullable = true)
#  |-- L0_S9_D202: string (nullable = true)
#  |-- L0_S9_D207: string (nullable = true)
#  |-- L0_S9_D212: string (nullable = true)
#  |-- L0_S10_D216: string (nullable = true)
#  |-- L0_S10_D221: string (nullable = true)
#  |-- L0_S10_D226: string (nullable = true)
#  |-- L0_S10_D231: string (nullable = true)
#  |-- L0_S10_D236: string (nullable = true)
#  |-- L0_S10_D241: string (nullable = true)
#  |-- L0_S10_D246: string (nullable = true)
#  |-- L0_S10_D251: string (nullable = true)
#  |-- L0_S10_D256: string (nullable = true)
#  |-- L0_S10_D261: string (nullable = true)
#  |-- L0_S10_D266: string (nullable = true)
#  |-- L0_S10_D271: string (nullable = true)
#  |-- L0_S10_D276: string (nullable = true)
#  |-- L0_S11_D280: string (nullable = true)
#  |-- L0_S11_D284: string (nullable = true)
#  |-- L0_S11_D288: string (nullable = true)
#  |-- L0_S11_D292: string (nullable = true)
#  |-- L0_S11_D296: string (nullable = true)
#  |-- L0_S11_D300: string (nullable = true)
#  |-- L0_S11_D304: string (nullable = true)
#  |-- L0_S11_D308: string (nullable = true)
#  |-- L0_S11_D312: string (nullable = true)
#  |-- L0_S11_D316: string (nullable = true)
#  |-- L0_S11_D320: string (nullable = true)
#  |-- L0_S11_D324: string (nullable = true)
#  |-- L0_S11_D328: string (nullable = true)
#  |-- L0_S12_D331: string (nullable = true)
#  |-- L0_S12_D333: string (nullable = true)
#  |-- L0_S12_D335: string (nullable = true)
#  |-- L0_S12_D337: string (nullable = true)
#  |-- L0_S12_D339: string (nullable = true)
#  |-- L0_S12_D341: string (nullable = true)
#  |-- L0_S12_D343: string (nullable = true)
#  |-- L0_S12_D345: string (nullable = true)
#  |-- L0_S12_D347: string (nullable = true)
#  |-- L0_S12_D349: string (nullable = true)
#  |-- L0_S12_D351: string (nullable = true)
#  |-- L0_S12_D353: string (nullable = true)
#  |-- L0_S13_D355: string (nullable = true)
#  |-- L0_S13_D357: string (nullable = true)
#  |-- L0_S14_D360: string (nullable = true)
#  |-- L0_S14_D364: string (nullable = true)
#  |-- L0_S14_D368: string (nullable = true)
#  |-- L0_S14_D372: string (nullable = true)
#  |-- L0_S14_D376: string (nullable = true)
#  |-- L0_S14_D380: string (nullable = true)
#  |-- L0_S14_D384: string (nullable = true)
#  |-- L0_S14_D388: string (nullable = true)
#  |-- L0_S14_D392: string (nullable = true)
#  |-- L0_S15_D395: string (nullable = true)
#  |-- L0_S15_D398: string (nullable = true)
#  |-- L0_S15_D401: string (nullable = true)
#  |-- L0_S15_D404: string (nullable = true)
#  |-- L0_S15_D407: string (nullable = true)
#  |-- L0_S15_D410: string (nullable = true)
#  |-- L0_S15_D413: string (nullable = true)
#  |-- L0_S15_D416: string (nullable = true)
#  |-- L0_S15_D419: string (nullable = true)
#  |-- L0_S16_D423: string (nullable = true)
#  |-- L0_S16_D428: string (nullable = true)
#  |-- L0_S17_D432: string (nullable = true)
#  |-- L0_S17_D434: string (nullable = true)
#  |-- L0_S18_D437: string (nullable = true)
#  |-- L0_S18_D441: string (nullable = true)
#  |-- L0_S18_D444: string (nullable = true)
#  |-- L0_S18_D447: string (nullable = true)
#  |-- L0_S18_D451: string (nullable = true)
#  |-- L0_S19_D454: string (nullable = true)
#  |-- L0_S19_D456: string (nullable = true)
#  |-- L0_S19_D457: string (nullable = true)
#  |-- L0_S19_D458: string (nullable = true)
#  |-- L0_S19_D460: string (nullable = true)
#  |-- L0_S20_D462: string (nullable = true)
#  |-- L0_S20_D464: string (nullable = true)
#  |-- L0_S20_D465: string (nullable = true)
#  |-- L0_S20_D467: string (nullable = true)
#  |-- L0_S21_D469: string (nullable = true)
#  |-- L0_S21_D474: string (nullable = true)
#  |-- L0_S21_D479: string (nullable = true)
#  |-- L0_S21_D484: string (nullable = true)
#  |-- L0_S21_D489: string (nullable = true)
#  |-- L0_S21_D494: string (nullable = true)
#  |-- L0_S21_D499: string (nullable = true)
#  |-- L0_S21_D504: string (nullable = true)
#  |-- L0_S21_D509: string (nullable = true)
#  |-- L0_S21_D514: string (nullable = true)
#  |-- L0_S21_D519: string (nullable = true)
#  |-- L0_S21_D524: string (nullable = true)
#  |-- L0_S21_D529: string (nullable = true)
#  |-- L0_S21_D534: string (nullable = true)
#  |-- L0_S21_D539: string (nullable = true)
#  |-- L0_S22_D543: string (nullable = true)
#  |-- L0_S22_D548: string (nullable = true)
#  |-- L0_S22_D553: string (nullable = true)
#  |-- L0_S22_D558: string (nullable = true)
#  |-- L0_S22_D563: string (nullable = true)
#  |-- L0_S22_D568: string (nullable = true)
#  |-- L0_S22_D573: string (nullable = true)
#  |-- L0_S22_D578: string (nullable = true)
#  |-- L0_S22_D583: string (nullable = true)
#  |-- L0_S22_D588: string (nullable = true)
#  |-- L0_S22_D593: string (nullable = true)
#  |-- L0_S22_D598: string (nullable = true)
#  |-- L0_S22_D603: string (nullable = true)
#  |-- L0_S22_D608: string (nullable = true)
#  |-- L0_S22_D613: string (nullable = true)
#  |-- L0_S23_D617: string (nullable = true)
#  |-- L0_S23_D621: string (nullable = true)
#  |-- L0_S23_D625: string (nullable = true)
#  |-- L0_S23_D629: string (nullable = true)
#  |-- L0_S23_D633: string (nullable = true)
#  |-- L0_S23_D637: string (nullable = true)
#  |-- L0_S23_D641: string (nullable = true)
#  |-- L0_S23_D645: string (nullable = true)
#  |-- L0_S23_D649: string (nullable = true)
#  |-- L0_S23_D653: string (nullable = true)
#  |-- L0_S23_D657: string (nullable = true)
#  |-- L0_S23_D661: string (nullable = true)
#  |-- L0_S23_D665: string (nullable = true)
#  |-- L0_S23_D669: string (nullable = true)
#  |-- L0_S23_D673: string (nullable = true)
#  |-- L1_S24_D677: string (nullable = true)
#  |-- L1_S24_D681: string (nullable = true)
#  |-- L1_S24_D685: string (nullable = true)
#  |-- L1_S24_D689: string (nullable = true)
#  |-- L1_S24_D693: string (nullable = true)
#  |-- L1_S24_D697: string (nullable = true)
#  |-- L1_S24_D702: string (nullable = true)
#  |-- L1_S24_D707: string (nullable = true)
#  |-- L1_S24_D712: string (nullable = true)
#  |-- L1_S24_D716: string (nullable = true)
#  |-- L1_S24_D721: string (nullable = true)
#  |-- L1_S24_D725: string (nullable = true)
#  |-- L1_S24_D730: string (nullable = true)
#  |-- L1_S24_D735: string (nullable = true)
#  |-- L1_S24_D739: string (nullable = true)
#  |-- L1_S24_D743: string (nullable = true)
#  |-- L1_S24_D748: string (nullable = true)
#  |-- L1_S24_D753: string (nullable = true)
#  |-- L1_S24_D758: string (nullable = true)
#  |-- L1_S24_D763: string (nullable = true)
#  |-- L1_S24_D768: string (nullable = true)
#  |-- L1_S24_D772: string (nullable = true)
#  |-- L1_S24_D777: string (nullable = true)
#  |-- L1_S24_D782: string (nullable = true)
#  |-- L1_S24_D787: string (nullable = true)
#  |-- L1_S24_D792: string (nullable = true)
#  |-- L1_S24_D797: string (nullable = true)
#  |-- L1_S24_D801: string (nullable = true)
#  |-- L1_S24_D804: string (nullable = true)
#  |-- L1_S24_D807: string (nullable = true)
#  |-- L1_S24_D809: string (nullable = true)
#  |-- L1_S24_D811: string (nullable = true)
#  |-- L1_S24_D813: string (nullable = true)
#  |-- L1_S24_D815: string (nullable = true)
#  |-- L1_S24_D818: string (nullable = true)
#  |-- L1_S24_D822: string (nullable = true)
#  |-- L1_S24_D826: string (nullable = true)
#  |-- L1_S24_D831: string (nullable = true)
#  |-- L1_S24_D836: string (nullable = true)
#  |-- L1_S24_D841: string (nullable = true)
#  |-- L1_S24_D846: string (nullable = true)
#  |-- L1_S24_D850: string (nullable = true)
#  |-- L1_S24_D854: string (nullable = true)
#  |-- L1_S24_D859: string (nullable = true)
#  |-- L1_S24_D864: string (nullable = true)
#  |-- L1_S24_D869: string (nullable = true)
#  |-- L1_S24_D874: string (nullable = true)
#  |-- L1_S24_D879: string (nullable = true)
#  |-- L1_S24_D884: string (nullable = true)
#  |-- L1_S24_D889: string (nullable = true)
#  |-- L1_S24_D894: string (nullable = true)
#  |-- L1_S24_D899: string (nullable = true)
#  |-- L1_S24_D904: string (nullable = true)
#  |-- L1_S24_D909: string (nullable = true)
#  |-- L1_S24_D913: string (nullable = true)
#  |-- L1_S24_D917: string (nullable = true)
#  |-- L1_S24_D922: string (nullable = true)
#  |-- L1_S24_D927: string (nullable = true)
#  |-- L1_S24_D932: string (nullable = true)
#  |-- L1_S24_D937: string (nullable = true)
#  |-- L1_S24_D941: string (nullable = true)
#  |-- L1_S24_D945: string (nullable = true)
#  |-- L1_S24_D950: string (nullable = true)
#  |-- L1_S24_D955: string (nullable = true)
#  |-- L1_S24_D960: string (nullable = true)
#  |-- L1_S24_D965: string (nullable = true)
#  |-- L1_S24_D970: string (nullable = true)
#  |-- L1_S24_D975: string (nullable = true)
#  |-- L1_S24_D980: string (nullable = true)
#  |-- L1_S24_D985: string (nullable = true)
#  |-- L1_S24_D990: string (nullable = true)
#  |-- L1_S24_D995: string (nullable = true)
#  |-- L1_S24_D999: string (nullable = true)
#  |-- L1_S24_D1001: string (nullable = true)
#  |-- L1_S24_D1003: string (nullable = true)
#  |-- L1_S24_D1005: string (nullable = true)
#  |-- L1_S24_D1007: string (nullable = true)
#  |-- L1_S24_D1009: string (nullable = true)
#  |-- L1_S24_D1011: string (nullable = true)
#  |-- L1_S24_D1013: string (nullable = true)
#  |-- L1_S24_D1015: string (nullable = true)
#  |-- L1_S24_D1018: string (nullable = true)
#  |-- L1_S24_D1023: string (nullable = true)
#  |-- L1_S24_D1028: string (nullable = true)
#  |-- L1_S24_D1033: string (nullable = true)
#  |-- L1_S24_D1038: string (nullable = true)
#  |-- L1_S24_D1043: string (nullable = true)
#  |-- L1_S24_D1048: string (nullable = true)
#  |-- L1_S24_D1053: string (nullable = true)
#  |-- L1_S24_D1058: string (nullable = true)
#  |-- L1_S24_D1062: string (nullable = true)
#  |-- L1_S24_D1066: string (nullable = true)
#  |-- L1_S24_D1070: string (nullable = true)
#  |-- L1_S24_D1074: string (nullable = true)
#  |-- L1_S24_D1077: string (nullable = true)
#  |-- L1_S24_D1081: string (nullable = true)
#  |-- L1_S24_D1085: string (nullable = true)
#  |-- L1_S24_D1089: string (nullable = true)
#  |-- L1_S24_D1092: string (nullable = true)
#  |-- L1_S24_D1096: string (nullable = true)
#  |-- L1_S24_D1100: string (nullable = true)
#  |-- L1_S24_D1104: string (nullable = true)
#  |-- L1_S24_D1108: string (nullable = true)
#  |-- L1_S24_D1112: string (nullable = true)
#  |-- L1_S24_D1116: string (nullable = true)
#  |-- L1_S24_D1120: string (nullable = true)
#  |-- L1_S24_D1124: string (nullable = true)
#  |-- L1_S24_D1128: string (nullable = true)
#  |-- L1_S24_D1132: string (nullable = true)
#  |-- L1_S24_D1135: string (nullable = true)
#  |-- L1_S24_D1138: string (nullable = true)
#  |-- L1_S24_D1141: string (nullable = true)
#  |-- L1_S24_D1143: string (nullable = true)
#  |-- L1_S24_D1146: string (nullable = true)
#  |-- L1_S24_D1149: string (nullable = true)
#  |-- L1_S24_D1151: string (nullable = true)
#  |-- L1_S24_D1153: string (nullable = true)
#  |-- L1_S24_D1155: string (nullable = true)
#  |-- L1_S24_D1158: string (nullable = true)
#  |-- L1_S24_D1163: string (nullable = true)
#  |-- L1_S24_D1168: string (nullable = true)
#  |-- L1_S24_D1171: string (nullable = true)
#  |-- L1_S24_D1173: string (nullable = true)
#  |-- L1_S24_D1175: string (nullable = true)
#  |-- L1_S24_D1178: string (nullable = true)
#  |-- L1_S24_D1182: string (nullable = true)
#  |-- L1_S24_D1186: string (nullable = true)
#  |-- L1_S24_D1190: string (nullable = true)
#  |-- L1_S24_D1194: string (nullable = true)
#  |-- L1_S24_D1199: string (nullable = true)
#  |-- L1_S24_D1204: string (nullable = true)
#  |-- L1_S24_D1209: string (nullable = true)
#  |-- L1_S24_D1214: string (nullable = true)
#  |-- L1_S24_D1218: string (nullable = true)
#  |-- L1_S24_D1222: string (nullable = true)
#  |-- L1_S24_D1227: string (nullable = true)
#  |-- L1_S24_D1232: string (nullable = true)
#  |-- L1_S24_D1237: string (nullable = true)
#  |-- L1_S24_D1242: string (nullable = true)
#  |-- L1_S24_D1247: string (nullable = true)
#  |-- L1_S24_D1252: string (nullable = true)
#  |-- L1_S24_D1257: string (nullable = true)
#  |-- L1_S24_D1262: string (nullable = true)
#  |-- L1_S24_D1267: string (nullable = true)
#  |-- L1_S24_D1272: string (nullable = true)
#  |-- L1_S24_D1277: string (nullable = true)
#  |-- L1_S24_D1281: string (nullable = true)
#  |-- L1_S24_D1285: string (nullable = true)
#  |-- L1_S24_D1290: string (nullable = true)
#  |-- L1_S24_D1295: string (nullable = true)
#  |-- L1_S24_D1300: string (nullable = true)
#  |-- L1_S24_D1305: string (nullable = true)
#  |-- L1_S24_D1309: string (nullable = true)
#  |-- L1_S24_D1313: string (nullable = true)
#  |-- L1_S24_D1318: string (nullable = true)
#  |-- L1_S24_D1323: string (nullable = true)
#  |-- L1_S24_D1328: string (nullable = true)
#  |-- L1_S24_D1333: string (nullable = true)
#  |-- L1_S24_D1338: string (nullable = true)
#  |-- L1_S24_D1343: string (nullable = true)
#  |-- L1_S24_D1348: string (nullable = true)
#  |-- L1_S24_D1353: string (nullable = true)
#  |-- L1_S24_D1358: string (nullable = true)
#  |-- L1_S24_D1363: string (nullable = true)
#  |-- L1_S24_D1368: string (nullable = true)
#  |-- L1_S24_D1373: string (nullable = true)
#  |-- L1_S24_D1378: string (nullable = true)
#  |-- L1_S24_D1383: string (nullable = true)
#  |-- L1_S24_D1388: string (nullable = true)
#  |-- L1_S24_D1393: string (nullable = true)
#  |-- L1_S24_D1398: string (nullable = true)
#  |-- L1_S24_D1403: string (nullable = true)
#  |-- L1_S24_D1408: string (nullable = true)
#  |-- L1_S24_D1413: string (nullable = true)
#  |-- L1_S24_D1418: string (nullable = true)
#  |-- L1_S24_D1423: string (nullable = true)
#  |-- L1_S24_D1428: string (nullable = true)
#  |-- L1_S24_D1433: string (nullable = true)
#  |-- L1_S24_D1438: string (nullable = true)
#  |-- L1_S24_D1443: string (nullable = true)
#  |-- L1_S24_D1448: string (nullable = true)
#  |-- L1_S24_D1453: string (nullable = true)
#  |-- L1_S24_D1457: string (nullable = true)
#  |-- L1_S24_D1461: string (nullable = true)
#  |-- L1_S24_D1465: string (nullable = true)
#  |-- L1_S24_D1469: string (nullable = true)
#  |-- L1_S24_D1472: string (nullable = true)
#  |-- L1_S24_D1476: string (nullable = true)
#  |-- L1_S24_D1480: string (nullable = true)
#  |-- L1_S24_D1484: string (nullable = true)
#  |-- L1_S24_D1488: string (nullable = true)
#  |-- L1_S24_D1492: string (nullable = true)
#  |-- L1_S24_D1496: string (nullable = true)
#  |-- L1_S24_D1500: string (nullable = true)
#  |-- L1_S24_D1504: string (nullable = true)
#  |-- L1_S24_D1508: string (nullable = true)
#  |-- L1_S24_D1511: string (nullable = true)
#  |-- L1_S24_D1513: string (nullable = true)
#  |-- L1_S24_D1515: string (nullable = true)
#  |-- L1_S24_D1517: string (nullable = true)
#  |-- L1_S24_D1519: string (nullable = true)
#  |-- L1_S24_D1522: string (nullable = true)
#  |-- L1_S24_D1527: string (nullable = true)
#  |-- L1_S24_D1532: string (nullable = true)
#  |-- L1_S24_D1536: string (nullable = true)
#  |-- L1_S24_D1541: string (nullable = true)
#  |-- L1_S24_D1546: string (nullable = true)
#  |-- L1_S24_D1550: string (nullable = true)
#  |-- L1_S24_D1554: string (nullable = true)
#  |-- L1_S24_D1558: string (nullable = true)
#  |-- L1_S24_D1562: string (nullable = true)
#  |-- L1_S24_D1566: string (nullable = true)
#  |-- L1_S24_D1568: string (nullable = true)
#  |-- L1_S24_D1570: string (nullable = true)
#  |-- L1_S24_D1572: string (nullable = true)
#  |-- L1_S24_D1574: string (nullable = true)
#  |-- L1_S24_D1576: string (nullable = true)
#  |-- L1_S24_D1579: string (nullable = true)
#  |-- L1_S24_D1583: string (nullable = true)
#  |-- L1_S24_D1587: string (nullable = true)
#  |-- L1_S24_D1591: string (nullable = true)
#  |-- L1_S24_D1596: string (nullable = true)
#  |-- L1_S24_D1601: string (nullable = true)
#  |-- L1_S24_D1606: string (nullable = true)
#  |-- L1_S24_D1611: string (nullable = true)
#  |-- L1_S24_D1615: string (nullable = true)
#  |-- L1_S24_D1619: string (nullable = true)
#  |-- L1_S24_D1624: string (nullable = true)
#  |-- L1_S24_D1629: string (nullable = true)
#  |-- L1_S24_D1634: string (nullable = true)
#  |-- L1_S24_D1639: string (nullable = true)
#  |-- L1_S24_D1644: string (nullable = true)
#  |-- L1_S24_D1649: string (nullable = true)
#  |-- L1_S24_D1654: string (nullable = true)
#  |-- L1_S24_D1659: string (nullable = true)
#  |-- L1_S24_D1664: string (nullable = true)
#  |-- L1_S24_D1669: string (nullable = true)
#  |-- L1_S24_D1674: string (nullable = true)
#  |-- L1_S24_D1678: string (nullable = true)
#  |-- L1_S24_D1682: string (nullable = true)
#  |-- L1_S24_D1687: string (nullable = true)
#  |-- L1_S24_D1692: string (nullable = true)
#  |-- L1_S24_D1697: string (nullable = true)
#  |-- L1_S24_D1702: string (nullable = true)
#  |-- L1_S24_D1706: string (nullable = true)
#  |-- L1_S24_D1710: string (nullable = true)
#  |-- L1_S24_D1715: string (nullable = true)
#  |-- L1_S24_D1720: string (nullable = true)
#  |-- L1_S24_D1725: string (nullable = true)
#  |-- L1_S24_D1730: string (nullable = true)
#  |-- L1_S24_D1735: string (nullable = true)
#  |-- L1_S24_D1740: string (nullable = true)
#  |-- L1_S24_D1745: string (nullable = true)
#  |-- L1_S24_D1750: string (nullable = true)
#  |-- L1_S24_D1755: string (nullable = true)
#  |-- L1_S24_D1760: string (nullable = true)
#  |-- L1_S24_D1765: string (nullable = true)
#  |-- L1_S24_D1770: string (nullable = true)
#  |-- L1_S24_D1775: string (nullable = true)
#  |-- L1_S24_D1780: string (nullable = true)
#  |-- L1_S24_D1785: string (nullable = true)
#  |-- L1_S24_D1790: string (nullable = true)
#  |-- L1_S24_D1795: string (nullable = true)
#  |-- L1_S24_D1800: string (nullable = true)
#  |-- L1_S24_D1805: string (nullable = true)
#  |-- L1_S24_D1809: string (nullable = true)
#  |-- L1_S24_D1811: string (nullable = true)
#  |-- L1_S24_D1813: string (nullable = true)
#  |-- L1_S24_D1815: string (nullable = true)
#  |-- L1_S24_D1817: string (nullable = true)
#  |-- L1_S24_D1819: string (nullable = true)
#  |-- L1_S24_D1821: string (nullable = true)
#  |-- L1_S24_D1823: string (nullable = true)
#  |-- L1_S24_D1825: string (nullable = true)
#  |-- L1_S24_D1826: string (nullable = true)
#  |-- L1_S24_D1828: string (nullable = true)
#  |-- L1_S24_D1830: string (nullable = true)
#  |-- L1_S24_D1832: string (nullable = true)
#  |-- L1_S24_D1833: string (nullable = true)
#  |-- L1_S24_D1835: string (nullable = true)
#  |-- L1_S24_D1837: string (nullable = true)
#  |-- L1_S24_D1839: string (nullable = true)
#  |-- L1_S24_D1841: string (nullable = true)
#  |-- L1_S24_D1843: string (nullable = true)
#  |-- L1_S24_D1845: string (nullable = true)
#  |-- L1_S24_D1847: string (nullable = true)
#  |-- L1_S24_D1849: string (nullable = true)
#  |-- L1_S24_D1851: string (nullable = true)
#  |-- L1_S25_D1854: string (nullable = true)
#  |-- L1_S25_D1857: string (nullable = true)
#  |-- L1_S25_D1860: string (nullable = true)
#  |-- L1_S25_D1862: string (nullable = true)
#  |-- L1_S25_D1864: string (nullable = true)
#  |-- L1_S25_D1867: string (nullable = true)
#  |-- L1_S25_D1871: string (nullable = true)
#  |-- L1_S25_D1875: string (nullable = true)
#  |-- L1_S25_D1879: string (nullable = true)
#  |-- L1_S25_D1883: string (nullable = true)
#  |-- L1_S25_D1887: string (nullable = true)
#  |-- L1_S25_D1891: string (nullable = true)
#  |-- L1_S25_D1893: string (nullable = true)
#  |-- L1_S25_D1895: string (nullable = true)
#  |-- L1_S25_D1898: string (nullable = true)
#  |-- L1_S25_D1902: string (nullable = true)
#  |-- L1_S25_D1906: string (nullable = true)
#  |-- L1_S25_D1911: string (nullable = true)
#  |-- L1_S25_D1916: string (nullable = true)
#  |-- L1_S25_D1921: string (nullable = true)
#  |-- L1_S25_D1926: string (nullable = true)
#  |-- L1_S25_D1931: string (nullable = true)
#  |-- L1_S25_D1935: string (nullable = true)
#  |-- L1_S25_D1940: string (nullable = true)
#  |-- L1_S25_D1945: string (nullable = true)
#  |-- L1_S25_D1950: string (nullable = true)
#  |-- L1_S25_D1955: string (nullable = true)
#  |-- L1_S25_D1960: string (nullable = true)
#  |-- L1_S25_D1965: string (nullable = true)
#  |-- L1_S25_D1970: string (nullable = true)
#  |-- L1_S25_D1975: string (nullable = true)
#  |-- L1_S25_D1980: string (nullable = true)
#  |-- L1_S25_D1984: string (nullable = true)
#  |-- L1_S25_D1989: string (nullable = true)
#  |-- L1_S25_D1994: string (nullable = true)
#  |-- L1_S25_D1999: string (nullable = true)
#  |-- L1_S25_D2004: string (nullable = true)
#  |-- L1_S25_D2009: string (nullable = true)
#  |-- L1_S25_D2013: string (nullable = true)
#  |-- L1_S25_D2018: string (nullable = true)
#  |-- L1_S25_D2023: string (nullable = true)
#  |-- L1_S25_D2028: string (nullable = true)
#  |-- L1_S25_D2033: string (nullable = true)
#  |-- L1_S25_D2038: string (nullable = true)
#  |-- L1_S25_D2043: string (nullable = true)
#  |-- L1_S25_D2048: string (nullable = true)
#  |-- L1_S25_D2053: string (nullable = true)
#  |-- L1_S25_D2058: string (nullable = true)
#  |-- L1_S25_D2063: string (nullable = true)
#  |-- L1_S25_D2068: string (nullable = true)
#  |-- L1_S25_D2073: string (nullable = true)
#  |-- L1_S25_D2078: string (nullable = true)
#  |-- L1_S25_D2083: string (nullable = true)
#  |-- L1_S25_D2088: string (nullable = true)
#  |-- L1_S25_D2093: string (nullable = true)
#  |-- L1_S25_D2098: string (nullable = true)
#  |-- L1_S25_D2103: string (nullable = true)
#  |-- L1_S25_D2108: string (nullable = true)
#  |-- L1_S25_D2113: string (nullable = true)
#  |-- L1_S25_D2118: string (nullable = true)
#  |-- L1_S25_D2123: string (nullable = true)
#  |-- L1_S25_D2128: string (nullable = true)
#  |-- L1_S25_D2133: string (nullable = true)
#  |-- L1_S25_D2138: string (nullable = true)
#  |-- L1_S25_D2140: string (nullable = true)
#  |-- L1_S25_D2143: string (nullable = true)
#  |-- L1_S25_D2146: string (nullable = true)
#  |-- L1_S25_D2149: string (nullable = true)
#  |-- L1_S25_D2151: string (nullable = true)
#  |-- L1_S25_D2154: string (nullable = true)
#  |-- L1_S25_D2157: string (nullable = true)
#  |-- L1_S25_D2160: string (nullable = true)
#  |-- L1_S25_D2163: string (nullable = true)
#  |-- L1_S25_D2166: string (nullable = true)
#  |-- L1_S25_D2169: string (nullable = true)
#  |-- L1_S25_D2172: string (nullable = true)
#  |-- L1_S25_D2175: string (nullable = true)
#  |-- L1_S25_D2178: string (nullable = true)
#  |-- L1_S25_D2180: string (nullable = true)
#  |-- L1_S25_D2183: string (nullable = true)
#  |-- L1_S25_D2186: string (nullable = true)
#  |-- L1_S25_D2189: string (nullable = true)
#  |-- L1_S25_D2192: string (nullable = true)
#  |-- L1_S25_D2195: string (nullable = true)
#  |-- L1_S25_D2198: string (nullable = true)
#  |-- L1_S25_D2201: string (nullable = true)
#  |-- L1_S25_D2204: string (nullable = true)
#  |-- L1_S25_D2206: string (nullable = true)
#  |-- L1_S25_D2209: string (nullable = true)
#  |-- L1_S25_D2212: string (nullable = true)
#  |-- L1_S25_D2214: string (nullable = true)
#  |-- L1_S25_D2216: string (nullable = true)
#  |-- L1_S25_D2219: string (nullable = true)
#  |-- L1_S25_D2222: string (nullable = true)
#  |-- L1_S25_D2225: string (nullable = true)
#  |-- L1_S25_D2228: string (nullable = true)
#  |-- L1_S25_D2230: string (nullable = true)
#  |-- L1_S25_D2232: string (nullable = true)
#  |-- L1_S25_D2234: string (nullable = true)
#  |-- L1_S25_D2235: string (nullable = true)
#  |-- L1_S25_D2236: string (nullable = true)
#  |-- L1_S25_D2238: string (nullable = true)
#  |-- L1_S25_D2240: string (nullable = true)
#  |-- L1_S25_D2242: string (nullable = true)
#  |-- L1_S25_D2244: string (nullable = true)
#  |-- L1_S25_D2246: string (nullable = true)
#  |-- L1_S25_D2248: string (nullable = true)
#  |-- L1_S25_D2251: string (nullable = true)
#  |-- L1_S25_D2255: string (nullable = true)
#  |-- L1_S25_D2260: string (nullable = true)
#  |-- L1_S25_D2265: string (nullable = true)
#  |-- L1_S25_D2270: string (nullable = true)
#  |-- L1_S25_D2275: string (nullable = true)
#  |-- L1_S25_D2280: string (nullable = true)
#  |-- L1_S25_D2284: string (nullable = true)
#  |-- L1_S25_D2289: string (nullable = true)
#  |-- L1_S25_D2294: string (nullable = true)
#  |-- L1_S25_D2299: string (nullable = true)
#  |-- L1_S25_D2304: string (nullable = true)
#  |-- L1_S25_D2309: string (nullable = true)
#  |-- L1_S25_D2314: string (nullable = true)
#  |-- L1_S25_D2319: string (nullable = true)
#  |-- L1_S25_D2324: string (nullable = true)
#  |-- L1_S25_D2329: string (nullable = true)
#  |-- L1_S25_D2333: string (nullable = true)
#  |-- L1_S25_D2338: string (nullable = true)
#  |-- L1_S25_D2343: string (nullable = true)
#  |-- L1_S25_D2348: string (nullable = true)
#  |-- L1_S25_D2353: string (nullable = true)
#  |-- L1_S25_D2358: string (nullable = true)
#  |-- L1_S25_D2362: string (nullable = true)
#  |-- L1_S25_D2367: string (nullable = true)
#  |-- L1_S25_D2372: string (nullable = true)
#  |-- L1_S25_D2377: string (nullable = true)
#  |-- L1_S25_D2382: string (nullable = true)
#  |-- L1_S25_D2387: string (nullable = true)
#  |-- L1_S25_D2392: string (nullable = true)
#  |-- L1_S25_D2397: string (nullable = true)
#  |-- L1_S25_D2402: string (nullable = true)
#  |-- L1_S25_D2406: string (nullable = true)
#  |-- L1_S25_D2409: string (nullable = true)
#  |-- L1_S25_D2412: string (nullable = true)
#  |-- L1_S25_D2415: string (nullable = true)
#  |-- L1_S25_D2418: string (nullable = true)
#  |-- L1_S25_D2421: string (nullable = true)
#  |-- L1_S25_D2424: string (nullable = true)
#  |-- L1_S25_D2427: string (nullable = true)
#  |-- L1_S25_D2430: string (nullable = true)
#  |-- L1_S25_D2432: string (nullable = true)
#  |-- L1_S25_D2434: string (nullable = true)
#  |-- L1_S25_D2436: string (nullable = true)
#  |-- L1_S25_D2438: string (nullable = true)
#  |-- L1_S25_D2440: string (nullable = true)
#  |-- L1_S25_D2442: string (nullable = true)
#  |-- L1_S25_D2444: string (nullable = true)
#  |-- L1_S25_D2445: string (nullable = true)
#  |-- L1_S25_D2446: string (nullable = true)
#  |-- L1_S25_D2448: string (nullable = true)
#  |-- L1_S25_D2450: string (nullable = true)
#  |-- L1_S25_D2452: string (nullable = true)
#  |-- L1_S25_D2453: string (nullable = true)
#  |-- L1_S25_D2455: string (nullable = true)
#  |-- L1_S25_D2457: string (nullable = true)
#  |-- L1_S25_D2459: string (nullable = true)
#  |-- L1_S25_D2461: string (nullable = true)
#  |-- L1_S25_D2463: string (nullable = true)
#  |-- L1_S25_D2465: string (nullable = true)
#  |-- L1_S25_D2467: string (nullable = true)
#  |-- L1_S25_D2469: string (nullable = true)
#  |-- L1_S25_D2471: string (nullable = true)
#  |-- L1_S25_D2474: string (nullable = true)
#  |-- L1_S25_D2477: string (nullable = true)
#  |-- L1_S25_D2480: string (nullable = true)
#  |-- L1_S25_D2483: string (nullable = true)
#  |-- L1_S25_D2486: string (nullable = true)
#  |-- L1_S25_D2489: string (nullable = true)
#  |-- L1_S25_D2492: string (nullable = true)
#  |-- L1_S25_D2495: string (nullable = true)
#  |-- L1_S25_D2497: string (nullable = true)
#  |-- L1_S25_D2499: string (nullable = true)
#  |-- L1_S25_D2501: string (nullable = true)
#  |-- L1_S25_D2502: string (nullable = true)
#  |-- L1_S25_D2503: string (nullable = true)
#  |-- L1_S25_D2505: string (nullable = true)
#  |-- L1_S25_D2507: string (nullable = true)
#  |-- L1_S25_D2509: string (nullable = true)
#  |-- L1_S25_D2511: string (nullable = true)
#  |-- L1_S25_D2513: string (nullable = true)
#  |-- L1_S25_D2515: string (nullable = true)
#  |-- L1_S25_D2518: string (nullable = true)
#  |-- L1_S25_D2522: string (nullable = true)
#  |-- L1_S25_D2527: string (nullable = true)
#  |-- L1_S25_D2532: string (nullable = true)
#  |-- L1_S25_D2537: string (nullable = true)
#  |-- L1_S25_D2542: string (nullable = true)
#  |-- L1_S25_D2547: string (nullable = true)
#  |-- L1_S25_D2551: string (nullable = true)
#  |-- L1_S25_D2556: string (nullable = true)
#  |-- L1_S25_D2561: string (nullable = true)
#  |-- L1_S25_D2566: string (nullable = true)
#  |-- L1_S25_D2571: string (nullable = true)
#  |-- L1_S25_D2576: string (nullable = true)
#  |-- L1_S25_D2581: string (nullable = true)
#  |-- L1_S25_D2586: string (nullable = true)
#  |-- L1_S25_D2591: string (nullable = true)
#  |-- L1_S25_D2596: string (nullable = true)
#  |-- L1_S25_D2600: string (nullable = true)
#  |-- L1_S25_D2605: string (nullable = true)
#  |-- L1_S25_D2610: string (nullable = true)
#  |-- L1_S25_D2615: string (nullable = true)
#  |-- L1_S25_D2620: string (nullable = true)
#  |-- L1_S25_D2625: string (nullable = true)
#  |-- L1_S25_D2629: string (nullable = true)
#  |-- L1_S25_D2634: string (nullable = true)
#  |-- L1_S25_D2639: string (nullable = true)
#  |-- L1_S25_D2644: string (nullable = true)
#  |-- L1_S25_D2649: string (nullable = true)
#  |-- L1_S25_D2654: string (nullable = true)
#  |-- L1_S25_D2659: string (nullable = true)
#  |-- L1_S25_D2664: string (nullable = true)
#  |-- L1_S25_D2669: string (nullable = true)
#  |-- L1_S25_D2674: string (nullable = true)
#  |-- L1_S25_D2679: string (nullable = true)
#  |-- L1_S25_D2684: string (nullable = true)
#  |-- L1_S25_D2689: string (nullable = true)
#  |-- L1_S25_D2694: string (nullable = true)
#  |-- L1_S25_D2699: string (nullable = true)
#  |-- L1_S25_D2704: string (nullable = true)
#  |-- L1_S25_D2709: string (nullable = true)
#  |-- L1_S25_D2713: string (nullable = true)
#  |-- L1_S25_D2715: string (nullable = true)
#  |-- L1_S25_D2717: string (nullable = true)
#  |-- L1_S25_D2719: string (nullable = true)
#  |-- L1_S25_D2721: string (nullable = true)
#  |-- L1_S25_D2723: string (nullable = true)
#  |-- L1_S25_D2725: string (nullable = true)
#  |-- L1_S25_D2727: string (nullable = true)
#  |-- L1_S25_D2728: string (nullable = true)
#  |-- L1_S25_D2729: string (nullable = true)
#  |-- L1_S25_D2731: string (nullable = true)
#  |-- L1_S25_D2733: string (nullable = true)
#  |-- L1_S25_D2735: string (nullable = true)
#  |-- L1_S25_D2736: string (nullable = true)
#  |-- L1_S25_D2738: string (nullable = true)
#  |-- L1_S25_D2740: string (nullable = true)
#  |-- L1_S25_D2742: string (nullable = true)
#  |-- L1_S25_D2744: string (nullable = true)
#  |-- L1_S25_D2746: string (nullable = true)
#  |-- L1_S25_D2748: string (nullable = true)
#  |-- L1_S25_D2750: string (nullable = true)
#  |-- L1_S25_D2752: string (nullable = true)
#  |-- L1_S25_D2754: string (nullable = true)
#  |-- L1_S25_D2757: string (nullable = true)
#  |-- L1_S25_D2760: string (nullable = true)
#  |-- L1_S25_D2763: string (nullable = true)
#  |-- L1_S25_D2766: string (nullable = true)
#  |-- L1_S25_D2769: string (nullable = true)
#  |-- L1_S25_D2772: string (nullable = true)
#  |-- L1_S25_D2775: string (nullable = true)
#  |-- L1_S25_D2778: string (nullable = true)
#  |-- L1_S25_D2780: string (nullable = true)
#  |-- L1_S25_D2782: string (nullable = true)
#  |-- L1_S25_D2784: string (nullable = true)
#  |-- L1_S25_D2785: string (nullable = true)
#  |-- L1_S25_D2786: string (nullable = true)
#  |-- L1_S25_D2788: string (nullable = true)
#  |-- L1_S25_D2790: string (nullable = true)
#  |-- L1_S25_D2792: string (nullable = true)
#  |-- L1_S25_D2794: string (nullable = true)
#  |-- L1_S25_D2796: string (nullable = true)
#  |-- L1_S25_D2798: string (nullable = true)
#  |-- L1_S25_D2801: string (nullable = true)
#  |-- L1_S25_D2805: string (nullable = true)
#  |-- L1_S25_D2810: string (nullable = true)
#  |-- L1_S25_D2815: string (nullable = true)
#  |-- L1_S25_D2820: string (nullable = true)
#  |-- L1_S25_D2825: string (nullable = true)
#  |-- L1_S25_D2830: string (nullable = true)
#  |-- L1_S25_D2834: string (nullable = true)
#  |-- L1_S25_D2839: string (nullable = true)
#  |-- L1_S25_D2844: string (nullable = true)
#  |-- L1_S25_D2849: string (nullable = true)
#  |-- L1_S25_D2854: string (nullable = true)
#  |-- L1_S25_D2859: string (nullable = true)
#  |-- L1_S25_D2864: string (nullable = true)
#  |-- L1_S25_D2869: string (nullable = true)
#  |-- L1_S25_D2874: string (nullable = true)
#  |-- L1_S25_D2879: string (nullable = true)
#  |-- L1_S25_D2883: string (nullable = true)
#  |-- L1_S25_D2888: string (nullable = true)
#  |-- L1_S25_D2893: string (nullable = true)
#  |-- L1_S25_D2898: string (nullable = true)
#  |-- L1_S25_D2903: string (nullable = true)
#  |-- L1_S25_D2908: string (nullable = true)
#  |-- L1_S25_D2912: string (nullable = true)
#  |-- L1_S25_D2917: string (nullable = true)
#  |-- L1_S25_D2922: string (nullable = true)
#  |-- L1_S25_D2927: string (nullable = true)
#  |-- L1_S25_D2932: string (nullable = true)
#  |-- L1_S25_D2937: string (nullable = true)
#  |-- L1_S25_D2942: string (nullable = true)
#  |-- L1_S25_D2947: string (nullable = true)
#  |-- L1_S25_D2952: string (nullable = true)
#  |-- L1_S25_D2957: string (nullable = true)
#  |-- L1_S25_D2962: string (nullable = true)
#  |-- L1_S25_D2967: string (nullable = true)
#  |-- L1_S25_D2972: string (nullable = true)
#  |-- L1_S25_D2977: string (nullable = true)
#  |-- L1_S25_D2982: string (nullable = true)
#  |-- L1_S25_D2987: string (nullable = true)
#  |-- L1_S25_D2992: string (nullable = true)
#  |-- L1_S25_D2996: string (nullable = true)
#  |-- L1_S25_D2998: string (nullable = true)
#  |-- L1_S25_D3000: string (nullable = true)
#  |-- L1_S25_D3002: string (nullable = true)
#  |-- L1_S25_D3004: string (nullable = true)
#  |-- L1_S25_D3006: string (nullable = true)
#  |-- L1_S25_D3008: string (nullable = true)
#  |-- L1_S25_D3010: string (nullable = true)
#  |-- L1_S25_D3011: string (nullable = true)
#  |-- L1_S25_D3012: string (nullable = true)
#  |-- L1_S25_D3014: string (nullable = true)
#  |-- L1_S25_D3016: string (nullable = true)
#  |-- L1_S25_D3018: string (nullable = true)
#  |-- L1_S25_D3019: string (nullable = true)
#  |-- L1_S25_D3021: string (nullable = true)
#  |-- L1_S25_D3023: string (nullable = true)
#  |-- L1_S25_D3025: string (nullable = true)
#  |-- L1_S25_D3027: string (nullable = true)
#  |-- L1_S25_D3029: string (nullable = true)
#  |-- L1_S25_D3031: string (nullable = true)
#  |-- L1_S25_D3033: string (nullable = true)
#  |-- L1_S25_D3035: string (nullable = true)
#  |-- L2_S26_D3037: string (nullable = true)
#  |-- L2_S26_D3041: string (nullable = true)
#  |-- L2_S26_D3044: string (nullable = true)
#  |-- L2_S26_D3048: string (nullable = true)
#  |-- L2_S26_D3052: string (nullable = true)
#  |-- L2_S26_D3056: string (nullable = true)
#  |-- L2_S26_D3059: string (nullable = true)
#  |-- L2_S26_D3063: string (nullable = true)
#  |-- L2_S26_D3066: string (nullable = true)
#  |-- L2_S26_D3070: string (nullable = true)
#  |-- L2_S26_D3074: string (nullable = true)
#  |-- L2_S26_D3078: string (nullable = true)
#  |-- L2_S26_D3081: string (nullable = true)
#  |-- L2_S26_D3084: string (nullable = true)
#  |-- L2_S26_D3087: string (nullable = true)
#  |-- L2_S26_D3090: string (nullable = true)
#  |-- L2_S26_D3093: string (nullable = true)
#  |-- L2_S26_D3096: string (nullable = true)
#  |-- L2_S26_D3100: string (nullable = true)
#  |-- L2_S26_D3103: string (nullable = true)
#  |-- L2_S26_D3107: string (nullable = true)
#  |-- L2_S26_D3110: string (nullable = true)
#  |-- L2_S26_D3114: string (nullable = true)
#  |-- L2_S26_D3118: string (nullable = true)
#  |-- L2_S26_D3122: string (nullable = true)
#  |-- L2_S26_D3126: string (nullable = true)
#  |-- L2_S27_D3130: string (nullable = true)
#  |-- L2_S27_D3134: string (nullable = true)
#  |-- L2_S27_D3137: string (nullable = true)
#  |-- L2_S27_D3141: string (nullable = true)
#  |-- L2_S27_D3145: string (nullable = true)
#  |-- L2_S27_D3149: string (nullable = true)
#  |-- L2_S27_D3152: string (nullable = true)
#  |-- L2_S27_D3156: string (nullable = true)
#  |-- L2_S27_D3159: string (nullable = true)
#  |-- L2_S27_D3163: string (nullable = true)
#  |-- L2_S27_D3167: string (nullable = true)
#  |-- L2_S27_D3171: string (nullable = true)
#  |-- L2_S27_D3174: string (nullable = true)
#  |-- L2_S27_D3177: string (nullable = true)
#  |-- L2_S27_D3180: string (nullable = true)
#  |-- L2_S27_D3183: string (nullable = true)
#  |-- L2_S27_D3186: string (nullable = true)
#  |-- L2_S27_D3189: string (nullable = true)
#  |-- L2_S27_D3193: string (nullable = true)
#  |-- L2_S27_D3196: string (nullable = true)
#  |-- L2_S27_D3200: string (nullable = true)
#  |-- L2_S27_D3203: string (nullable = true)
#  |-- L2_S27_D3207: string (nullable = true)
#  |-- L2_S27_D3211: string (nullable = true)
#  |-- L2_S27_D3215: string (nullable = true)
#  |-- L2_S27_D3219: string (nullable = true)
#  |-- L2_S28_D3223: string (nullable = true)
#  |-- L2_S28_D3227: string (nullable = true)
#  |-- L2_S28_D3230: string (nullable = true)
#  |-- L2_S28_D3234: string (nullable = true)
#  |-- L2_S28_D3238: string (nullable = true)
#  |-- L2_S28_D3242: string (nullable = true)
#  |-- L2_S28_D3245: string (nullable = true)
#  |-- L2_S28_D3249: string (nullable = true)
#  |-- L2_S28_D3252: string (nullable = true)
#  |-- L2_S28_D3256: string (nullable = true)
#  |-- L2_S28_D3260: string (nullable = true)
#  |-- L2_S28_D3264: string (nullable = true)
#  |-- L2_S28_D3267: string (nullable = true)
#  |-- L2_S28_D3270: string (nullable = true)
#  |-- L2_S28_D3273: string (nullable = true)
#  |-- L2_S28_D3276: string (nullable = true)
#  |-- L2_S28_D3279: string (nullable = true)
#  |-- L2_S28_D3282: string (nullable = true)
#  |-- L2_S28_D3286: string (nullable = true)
#  |-- L2_S28_D3289: string (nullable = true)
#  |-- L2_S28_D3293: string (nullable = true)
#  |-- L2_S28_D3296: string (nullable = true)
#  |-- L2_S28_D3300: string (nullable = true)
#  |-- L2_S28_D3304: string (nullable = true)
#  |-- L2_S28_D3308: string (nullable = true)
#  |-- L2_S28_D3312: string (nullable = true)
#  |-- L3_S29_D3316: string (nullable = true)
#  |-- L3_S29_D3319: string (nullable = true)
#  |-- L3_S29_D3322: string (nullable = true)
#  |-- L3_S29_D3325: string (nullable = true)
#  |-- L3_S29_D3328: string (nullable = true)
#  |-- L3_S29_D3331: string (nullable = true)
#  |-- L3_S29_D3334: string (nullable = true)
#  |-- L3_S29_D3337: string (nullable = true)
#  |-- L3_S29_D3340: string (nullable = true)
#  |-- L3_S29_D3343: string (nullable = true)
#  |-- L3_S29_D3346: string (nullable = true)
#  |-- L3_S29_D3349: string (nullable = true)
#  |-- L3_S29_D3352: string (nullable = true)
#  |-- L3_S29_D3355: string (nullable = true)
#  |-- L3_S29_D3358: string (nullable = true)
#  |-- L3_S29_D3361: string (nullable = true)
#  |-- L3_S29_D3363: string (nullable = true)
#  |-- L3_S29_D3365: string (nullable = true)
#  |-- L3_S29_D3368: string (nullable = true)
#  |-- L3_S29_D3371: string (nullable = true)
#  |-- L3_S29_D3374: string (nullable = true)
#  |-- L3_S29_D3377: string (nullable = true)
#  |-- L3_S29_D3380: string (nullable = true)
#  |-- L3_S29_D3383: string (nullable = true)
#  |-- L3_S29_D3386: string (nullable = true)
#  |-- L3_S29_D3389: string (nullable = true)
#  |-- L3_S29_D3391: string (nullable = true)
#  |-- L3_S29_D3393: string (nullable = true)
#  |-- L3_S29_D3396: string (nullable = true)
#  |-- L3_S29_D3399: string (nullable = true)
#  |-- L3_S29_D3402: string (nullable = true)
#  |-- L3_S29_D3405: string (nullable = true)
#  |-- L3_S29_D3408: string (nullable = true)
#  |-- L3_S29_D3410: string (nullable = true)
#  |-- L3_S29_D3413: string (nullable = true)
#  |-- L3_S29_D3415: string (nullable = true)
#  |-- L3_S29_D3417: string (nullable = true)
#  |-- L3_S29_D3419: string (nullable = true)
#  |-- L3_S29_D3422: string (nullable = true)
#  |-- L3_S29_D3425: string (nullable = true)
#  |-- L3_S29_D3428: string (nullable = true)
#  |-- L3_S29_D3431: string (nullable = true)
#  |-- L3_S29_D3434: string (nullable = true)
#  |-- L3_S29_D3437: string (nullable = true)
#  |-- L3_S29_D3440: string (nullable = true)
#  |-- L3_S29_D3443: string (nullable = true)
#  |-- L3_S29_D3445: string (nullable = true)
#  |-- L3_S29_D3447: string (nullable = true)
#  |-- L3_S29_D3450: string (nullable = true)
#  |-- L3_S29_D3453: string (nullable = true)
#  |-- L3_S29_D3456: string (nullable = true)
#  |-- L3_S29_D3459: string (nullable = true)
#  |-- L3_S29_D3462: string (nullable = true)
#  |-- L3_S29_D3465: string (nullable = true)
#  |-- L3_S29_D3468: string (nullable = true)
#  |-- L3_S29_D3471: string (nullable = true)
#  |-- L3_S29_D3474: string (nullable = true)
#  |-- L3_S29_D3477: string (nullable = true)
#  |-- L3_S29_D3480: string (nullable = true)
#  |-- L3_S29_D3483: string (nullable = true)
#  |-- L3_S29_D3486: string (nullable = true)
#  |-- L3_S29_D3489: string (nullable = true)
#  |-- L3_S29_D3492: string (nullable = true)
#  |-- L3_S30_D3496: string (nullable = true)
#  |-- L3_S30_D3501: string (nullable = true)
#  |-- L3_S30_D3506: string (nullable = true)
#  |-- L3_S30_D3511: string (nullable = true)
#  |-- L3_S30_D3516: string (nullable = true)
#  |-- L3_S30_D3521: string (nullable = true)
#  |-- L3_S30_D3526: string (nullable = true)
#  |-- L3_S30_D3531: string (nullable = true)
#  |-- L3_S30_D3536: string (nullable = true)
#  |-- L3_S30_D3541: string (nullable = true)
#  |-- L3_S30_D3546: string (nullable = true)
#  |-- L3_S30_D3551: string (nullable = true)
#  |-- L3_S30_D3556: string (nullable = true)
#  |-- L3_S30_D3561: string (nullable = true)
#  |-- L3_S30_D3566: string (nullable = true)
#  |-- L3_S30_D3571: string (nullable = true)
#  |-- L3_S30_D3576: string (nullable = true)
#  |-- L3_S30_D3581: string (nullable = true)
#  |-- L3_S30_D3586: string (nullable = true)
#  |-- L3_S30_D3591: string (nullable = true)
#  |-- L3_S30_D3596: string (nullable = true)
#  |-- L3_S30_D3601: string (nullable = true)
#  |-- L3_S30_D3606: string (nullable = true)
#  |-- L3_S30_D3611: string (nullable = true)
#  |-- L3_S30_D3616: string (nullable = true)
#  |-- L3_S30_D3621: string (nullable = true)
#  |-- L3_S30_D3626: string (nullable = true)
#  |-- L3_S30_D3631: string (nullable = true)
#  |-- L3_S30_D3636: string (nullable = true)
#  |-- L3_S30_D3641: string (nullable = true)
#  |-- L3_S30_D3646: string (nullable = true)
#  |-- L3_S30_D3651: string (nullable = true)
#  |-- L3_S30_D3656: string (nullable = true)
#  |-- L3_S30_D3661: string (nullable = true)
#  |-- L3_S30_D3666: string (nullable = true)
#  |-- L3_S30_D3671: string (nullable = true)
#  |-- L3_S30_D3676: string (nullable = true)
#  |-- L3_S30_D3681: string (nullable = true)
#  |-- L3_S30_D3686: string (nullable = true)
#  |-- L3_S30_D3691: string (nullable = true)
#  |-- L3_S30_D3696: string (nullable = true)
#  |-- L3_S30_D3701: string (nullable = true)
#  |-- L3_S30_D3706: string (nullable = true)
#  |-- L3_S30_D3711: string (nullable = true)
#  |-- L3_S30_D3716: string (nullable = true)
#  |-- L3_S30_D3721: string (nullable = true)
#  |-- L3_S30_D3726: string (nullable = true)
#  |-- L3_S30_D3731: string (nullable = true)
#  |-- L3_S30_D3736: string (nullable = true)
#  |-- L3_S30_D3741: string (nullable = true)
#  |-- L3_S30_D3746: string (nullable = true)
#  |-- L3_S30_D3751: string (nullable = true)
#  |-- L3_S30_D3756: string (nullable = true)
#  |-- L3_S30_D3761: string (nullable = true)
#  |-- L3_S30_D3766: string (nullable = true)
#  |-- L3_S30_D3771: string (nullable = true)
#  |-- L3_S30_D3776: string (nullable = true)
#  |-- L3_S30_D3781: string (nullable = true)
#  |-- L3_S30_D3786: string (nullable = true)
#  |-- L3_S30_D3791: string (nullable = true)
#  |-- L3_S30_D3796: string (nullable = true)
#  |-- L3_S30_D3801: string (nullable = true)
#  |-- L3_S30_D3806: string (nullable = true)
#  |-- L3_S30_D3811: string (nullable = true)
#  |-- L3_S30_D3816: string (nullable = true)
#  |-- L3_S30_D3821: string (nullable = true)
#  |-- L3_S30_D3826: string (nullable = true)
#  |-- L3_S30_D3831: string (nullable = true)
#  |-- L3_S31_D3836: string (nullable = true)
#  |-- L3_S31_D3840: string (nullable = true)
#  |-- L3_S31_D3844: string (nullable = true)
#  |-- L3_S31_D3848: string (nullable = true)
#  |-- L3_S32_D3852: string (nullable = true)
#  |-- L3_S33_D3856: string (nullable = true)
#  |-- L3_S33_D3858: string (nullable = true)
#  |-- L3_S33_D3860: string (nullable = true)
#  |-- L3_S33_D3862: string (nullable = true)
#  |-- L3_S33_D3864: string (nullable = true)
#  |-- L3_S33_D3866: string (nullable = true)
#  |-- L3_S33_D3868: string (nullable = true)
#  |-- L3_S33_D3870: string (nullable = true)
#  |-- L3_S33_D3872: string (nullable = true)
#  |-- L3_S33_D3874: string (nullable = true)
#  |-- L3_S34_D3875: string (nullable = true)
#  |-- L3_S34_D3877: string (nullable = true)
#  |-- L3_S34_D3879: string (nullable = true)
#  |-- L3_S34_D3881: string (nullable = true)
#  |-- L3_S34_D3883: string (nullable = true)
#  |-- L3_S35_D3886: string (nullable = true)
#  |-- L3_S35_D3891: string (nullable = true)
#  |-- L3_S35_D3895: string (nullable = true)
#  |-- L3_S35_D3897: string (nullable = true)
#  |-- L3_S35_D3900: string (nullable = true)
#  |-- L3_S35_D3905: string (nullable = true)
#  |-- L3_S35_D3910: string (nullable = true)
#  |-- L3_S35_D3915: string (nullable = true)
#  |-- L3_S36_D3919: string (nullable = true)
#  |-- L3_S36_D3921: string (nullable = true)
#  |-- L3_S36_D3923: string (nullable = true)
#  |-- L3_S36_D3925: string (nullable = true)
#  |-- L3_S36_D3928: string (nullable = true)
#  |-- L3_S36_D3932: string (nullable = true)
#  |-- L3_S36_D3936: string (nullable = true)
#  |-- L3_S36_D3940: string (nullable = true)
#  |-- L3_S37_D3942: string (nullable = true)
#  |-- L3_S37_D3943: string (nullable = true)
#  |-- L3_S37_D3945: string (nullable = true)
#  |-- L3_S37_D3947: string (nullable = true)
#  |-- L3_S37_D3949: string (nullable = true)
#  |-- L3_S37_D3951: string (nullable = true)
#  |-- L3_S38_D3953: string (nullable = true)
#  |-- L3_S38_D3957: string (nullable = true)
#  |-- L3_S38_D3961: string (nullable = true)
#  |-- L3_S39_D3966: string (nullable = true)
#  |-- L3_S39_D3970: string (nullable = true)
#  |-- L3_S39_D3974: string (nullable = true)
#  |-- L3_S39_D3978: string (nullable = true)
#  |-- L3_S40_D3981: string (nullable = true)
#  |-- L3_S40_D3983: string (nullable = true)
#  |-- L3_S40_D3985: string (nullable = true)
#  |-- L3_S40_D3987: string (nullable = true)
#  |-- L3_S40_D3989: string (nullable = true)
#  |-- L3_S40_D3991: string (nullable = true)
#  |-- L3_S40_D3993: string (nullable = true)
#  |-- L3_S40_D3995: string (nullable = true)
#  |-- L3_S41_D3997: string (nullable = true)
#  |-- L3_S41_D3999: string (nullable = true)
#  |-- L3_S41_D4001: string (nullable = true)
#  |-- L3_S41_D4003: string (nullable = true)
#  |-- L3_S41_D4005: string (nullable = true)
#  |-- L3_S41_D4007: string (nullable = true)
#  |-- L3_S41_D4009: string (nullable = true)
#  |-- L3_S41_D4010: string (nullable = true)
#  |-- L3_S41_D4012: string (nullable = true)
#  |-- L3_S41_D4013: string (nullable = true)
#  |-- L3_S41_D4015: string (nullable = true)
#  |-- L3_S41_D4017: string (nullable = true)
#  |-- L3_S41_D4019: string (nullable = true)
#  |-- L3_S41_D4021: string (nullable = true)
#  |-- L3_S41_D4022: string (nullable = true)
#  |-- L3_S41_D4024: string (nullable = true)
#  |-- L3_S41_D4025: string (nullable = true)
#  |-- L3_S41_D4027: string (nullable = true)
#  |-- L3_S42_D4029: string (nullable = true)
#  |-- L3_S42_D4033: string (nullable = true)
#  |-- L3_S42_D4037: string (nullable = true)
#  |-- L3_S42_D4041: string (nullable = true)
#  |-- L3_S42_D4045: string (nullable = true)
#  |-- L3_S42_D4049: string (nullable = true)
#  |-- L3_S42_D4053: string (nullable = true)
#  |-- L3_S42_D4057: string (nullable = true)
#  |-- L3_S43_D4062: string (nullable = true)
#  |-- L3_S43_D4067: string (nullable = true)
#  |-- L3_S43_D4072: string (nullable = true)
#  |-- L3_S43_D4077: string (nullable = true)
#  |-- L3_S43_D4082: string (nullable = true)
#  |-- L3_S43_D4087: string (nullable = true)
#  |-- L3_S43_D4092: string (nullable = true)
#  |-- L3_S43_D4097: string (nullable = true)
#  |-- L3_S44_D4101: string (nullable = true)
#  |-- L3_S44_D4104: string (nullable = true)
#  |-- L3_S44_D4107: string (nullable = true)
#  |-- L3_S44_D4110: string (nullable = true)
#  |-- L3_S44_D4113: string (nullable = true)
#  |-- L3_S44_D4116: string (nullable = true)
#  |-- L3_S44_D4119: string (nullable = true)
#  |-- L3_S44_D4122: string (nullable = true)
#  |-- L3_S45_D4125: string (nullable = true)
#  |-- L3_S45_D4127: string (nullable = true)
#  |-- L3_S45_D4129: string (nullable = true)
#  |-- L3_S45_D4131: string (nullable = true)
#  |-- L3_S45_D4133: string (nullable = true)
#  |-- L3_S46_D4135: string (nullable = true)
#  |-- L3_S47_D4140: string (nullable = true)
#  |-- L3_S47_D4145: string (nullable = true)
#  |-- L3_S47_D4150: string (nullable = true)
#  |-- L3_S47_D4155: string (nullable = true)
#  |-- L3_S47_D4160: string (nullable = true)
#  |-- L3_S47_D4165: string (nullable = true)
#  |-- L3_S47_D4170: string (nullable = true)
#  |-- L3_S47_D4175: string (nullable = true)
#  |-- L3_S47_D4180: string (nullable = true)
#  |-- L3_S47_D4185: string (nullable = true)
#  |-- L3_S47_D4190: string (nullable = true)
#  |-- L3_S48_D4194: string (nullable = true)
#  |-- L3_S48_D4195: string (nullable = true)
#  |-- L3_S48_D4197: string (nullable = true)
#  |-- L3_S48_D4199: string (nullable = true)
#  |-- L3_S48_D4201: string (nullable = true)
#  |-- L3_S48_D4203: string (nullable = true)
#  |-- L3_S48_D4205: string (nullable = true)
#  |-- L3_S49_D4208: string (nullable = true)
#  |-- L3_S49_D4213: string (nullable = true)
#  |-- L3_S49_D4218: string (nullable = true)
#  |-- L3_S49_D4223: string (nullable = true)
#  |-- L3_S49_D4228: string (nullable = true)
#  |-- L3_S49_D4233: string (nullable = true)
#  |-- L3_S49_D4238: string (nullable = true)
#  |-- L3_S50_D4242: string (nullable = true)
#  |-- L3_S50_D4244: string (nullable = true)
#  |-- L3_S50_D4246: string (nullable = true)
#  |-- L3_S50_D4248: string (nullable = true)
#  |-- L3_S50_D4250: string (nullable = true)
#  |-- L3_S50_D4252: string (nullable = true)
#  |-- L3_S50_D4254: string (nullable = true)
#  |-- L3_S51_D4255: string (nullable = true)
#  |-- L3_S51_D4257: string (nullable = true)
#  |-- L3_S51_D4259: string (nullable = true)
#  |-- L3_S51_D4261: string (nullable = true)
#  |-- L3_S51_D4263: string (nullable = true)

# %%
#Let's find the datestamp for L0_S1_F25, which should be L0_S1_D26 
#Here D26 represents datestamp of feature 25, which went through line 0 and station 1:
date.select('L0_S1_D26')\
    .filter(date['L0_S1_D26'].isNotNull())\
    .groupby('L0_S1_D26')\
    .count()\
    .show()
# Out:
# +---------+-----+
# |L0_S1_D26|count|
# +---------+-----+
# |      691|   21|
# |  1432.79|   24|
# |     73.7|   15|
# |   560.38|   18|
# |   189.92|   16|
# |   641.53|   17|
# |  1612.75|   18|
# |  1669.13|   16|
# |  1542.16|   16|
# |    829.4|   19|
# |   958.75|   15|
# |   909.14|   19|
# |    37.21|   23|
# |   368.62|   21|
# |   961.48|    8|
# |  1227.46|   23|
# |   188.27|   15|
# |  1239.79|   18|
# |   611.05|   19|
# |  1154.08|   19|
# +---------+-----+
# only showing top 20 rows

# %%
#View Numeric Schema:
numeric.printSchema()

#Even numeric field is in string format
# Out:
# root
#  |-- Id: string (nullable = true)
#  |-- L0_S0_F0: string (nullable = true)
#  |-- L0_S0_F2: string (nullable = true)
#  |-- L0_S0_F4: string (nullable = true)
#  |-- L0_S0_F6: string (nullable = true)
#  |-- L0_S0_F8: string (nullable = true)
#  |-- L0_S0_F10: string (nullable = true)
#  |-- L0_S0_F12: string (nullable = true)
#  |-- L0_S0_F14: string (nullable = true)
#  |-- L0_S0_F16: string (nullable = true)
#  |-- L0_S0_F18: string (nullable = true)
#  |-- L0_S0_F20: string (nullable = true)
#  |-- L0_S0_F22: string (nullable = true)
#  |-- L0_S1_F24: string (nullable = true)
#  |-- L0_S1_F28: string (nullable = true)
#  |-- L0_S2_F32: string (nullable = true)
#  |-- L0_S2_F36: string (nullable = true)
#  |-- L0_S2_F40: string (nullable = true)
#  |-- L0_S2_F44: string (nullable = true)
#  |-- L0_S2_F48: string (nullable = true)
#  |-- L0_S2_F52: string (nullable = true)
#  |-- L0_S2_F56: string (nullable = true)
#  |-- L0_S2_F60: string (nullable = true)
#  |-- L0_S2_F64: string (nullable = true)
#  |-- L0_S3_F68: string (nullable = true)
#  |-- L0_S3_F72: string (nullable = true)
#  |-- L0_S3_F76: string (nullable = true)
#  |-- L0_S3_F80: string (nullable = true)
#  |-- L0_S3_F84: string (nullable = true)
#  |-- L0_S3_F88: string (nullable = true)
#  |-- L0_S3_F92: string (nullable = true)
#  |-- L0_S3_F96: string (nullable = true)
#  |-- L0_S3_F100: string (nullable = true)
#  |-- L0_S4_F104: string (nullable = true)
#  |-- L0_S4_F109: string (nullable = true)
#  |-- L0_S5_F114: string (nullable = true)
#  |-- L0_S5_F116: string (nullable = true)
#  |-- L0_S6_F118: string (nullable = true)
#  |-- L0_S6_F122: string (nullable = true)
#  |-- L0_S6_F132: string (nullable = true)
#  |-- L0_S7_F136: string (nullable = true)
#  |-- L0_S7_F138: string (nullable = true)
#  |-- L0_S7_F142: string (nullable = true)
#  |-- L0_S8_F144: string (nullable = true)
#  |-- L0_S8_F146: string (nullable = true)
#  |-- L0_S8_F149: string (nullable = true)
#  |-- L0_S9_F155: string (nullable = true)
#  |-- L0_S9_F160: string (nullable = true)
#  |-- L0_S9_F165: string (nullable = true)
#  |-- L0_S9_F170: string (nullable = true)
#  |-- L0_S9_F175: string (nullable = true)
#  |-- L0_S9_F180: string (nullable = true)
#  |-- L0_S9_F185: string (nullable = true)
#  |-- L0_S9_F190: string (nullable = true)
#  |-- L0_S9_F195: string (nullable = true)
#  |-- L0_S9_F200: string (nullable = true)
#  |-- L0_S9_F205: string (nullable = true)
#  |-- L0_S9_F210: string (nullable = true)
#  |-- L0_S10_F219: string (nullable = true)
#  |-- L0_S10_F224: string (nullable = true)
#  |-- L0_S10_F229: string (nullable = true)
#  |-- L0_S10_F234: string (nullable = true)
#  |-- L0_S10_F239: string (nullable = true)
#  |-- L0_S10_F244: string (nullable = true)
#  |-- L0_S10_F249: string (nullable = true)
#  |-- L0_S10_F254: string (nullable = true)
#  |-- L0_S10_F259: string (nullable = true)
#  |-- L0_S10_F264: string (nullable = true)
#  |-- L0_S10_F269: string (nullable = true)
#  |-- L0_S10_F274: string (nullable = true)
#  |-- L0_S11_F282: string (nullable = true)
#  |-- L0_S11_F286: string (nullable = true)
#  |-- L0_S11_F290: string (nullable = true)
#  |-- L0_S11_F294: string (nullable = true)
#  |-- L0_S11_F298: string (nullable = true)
#  |-- L0_S11_F302: string (nullable = true)
#  |-- L0_S11_F306: string (nullable = true)
#  |-- L0_S11_F310: string (nullable = true)
#  |-- L0_S11_F314: string (nullable = true)
#  |-- L0_S11_F318: string (nullable = true)
#  |-- L0_S11_F322: string (nullable = true)
#  |-- L0_S11_F326: string (nullable = true)
#  |-- L0_S12_F330: string (nullable = true)
#  |-- L0_S12_F332: string (nullable = true)
#  |-- L0_S12_F334: string (nullable = true)
#  |-- L0_S12_F336: string (nullable = true)
#  |-- L0_S12_F338: string (nullable = true)
#  |-- L0_S12_F340: string (nullable = true)
#  |-- L0_S12_F342: string (nullable = true)
#  |-- L0_S12_F344: string (nullable = true)
#  |-- L0_S12_F346: string (nullable = true)
#  |-- L0_S12_F348: string (nullable = true)
#  |-- L0_S12_F350: string (nullable = true)
#  |-- L0_S12_F352: string (nullable = true)
#  |-- L0_S13_F354: string (nullable = true)
#  |-- L0_S13_F356: string (nullable = true)
#  |-- L0_S14_F358: string (nullable = true)
#  |-- L0_S14_F362: string (nullable = true)
#  |-- L0_S14_F366: string (nullable = true)
#  |-- L0_S14_F370: string (nullable = true)
#  |-- L0_S14_F374: string (nullable = true)
#  |-- L0_S14_F378: string (nullable = true)
#  |-- L0_S14_F382: string (nullable = true)
#  |-- L0_S14_F386: string (nullable = true)
#  |-- L0_S14_F390: string (nullable = true)
#  |-- L0_S15_F394: string (nullable = true)
#  |-- L0_S15_F397: string (nullable = true)
#  |-- L0_S15_F400: string (nullable = true)
#  |-- L0_S15_F403: string (nullable = true)
#  |-- L0_S15_F406: string (nullable = true)
#  |-- L0_S15_F409: string (nullable = true)
#  |-- L0_S15_F412: string (nullable = true)
#  |-- L0_S15_F415: string (nullable = true)
#  |-- L0_S15_F418: string (nullable = true)
#  |-- L0_S16_F421: string (nullable = true)
#  |-- L0_S16_F426: string (nullable = true)
#  |-- L0_S17_F431: string (nullable = true)
#  |-- L0_S17_F433: string (nullable = true)
#  |-- L0_S18_F435: string (nullable = true)
#  |-- L0_S18_F439: string (nullable = true)
#  |-- L0_S18_F449: string (nullable = true)
#  |-- L0_S19_F453: string (nullable = true)
#  |-- L0_S19_F455: string (nullable = true)
#  |-- L0_S19_F459: string (nullable = true)
#  |-- L0_S20_F461: string (nullable = true)
#  |-- L0_S20_F463: string (nullable = true)
#  |-- L0_S20_F466: string (nullable = true)
#  |-- L0_S21_F472: string (nullable = true)
#  |-- L0_S21_F477: string (nullable = true)
#  |-- L0_S21_F482: string (nullable = true)
#  |-- L0_S21_F487: string (nullable = true)
#  |-- L0_S21_F492: string (nullable = true)
#  |-- L0_S21_F497: string (nullable = true)
#  |-- L0_S21_F502: string (nullable = true)
#  |-- L0_S21_F507: string (nullable = true)
#  |-- L0_S21_F512: string (nullable = true)
#  |-- L0_S21_F517: string (nullable = true)
#  |-- L0_S21_F522: string (nullable = true)
#  |-- L0_S21_F527: string (nullable = true)
#  |-- L0_S21_F532: string (nullable = true)
#  |-- L0_S21_F537: string (nullable = true)
#  |-- L0_S22_F546: string (nullable = true)
#  |-- L0_S22_F551: string (nullable = true)
#  |-- L0_S22_F556: string (nullable = true)
#  |-- L0_S22_F561: string (nullable = true)
#  |-- L0_S22_F566: string (nullable = true)
#  |-- L0_S22_F571: string (nullable = true)
#  |-- L0_S22_F576: string (nullable = true)
#  |-- L0_S22_F581: string (nullable = true)
#  |-- L0_S22_F586: string (nullable = true)
#  |-- L0_S22_F591: string (nullable = true)
#  |-- L0_S22_F596: string (nullable = true)
#  |-- L0_S22_F601: string (nullable = true)
#  |-- L0_S22_F606: string (nullable = true)
#  |-- L0_S22_F611: string (nullable = true)
#  |-- L0_S23_F619: string (nullable = true)
#  |-- L0_S23_F623: string (nullable = true)
#  |-- L0_S23_F627: string (nullable = true)
#  |-- L0_S23_F631: string (nullable = true)
#  |-- L0_S23_F635: string (nullable = true)
#  |-- L0_S23_F639: string (nullable = true)
#  |-- L0_S23_F643: string (nullable = true)
#  |-- L0_S23_F647: string (nullable = true)
#  |-- L0_S23_F651: string (nullable = true)
#  |-- L0_S23_F655: string (nullable = true)
#  |-- L0_S23_F659: string (nullable = true)
#  |-- L0_S23_F663: string (nullable = true)
#  |-- L0_S23_F667: string (nullable = true)
#  |-- L0_S23_F671: string (nullable = true)
#  |-- L1_S24_F679: string (nullable = true)
#  |-- L1_S24_F683: string (nullable = true)
#  |-- L1_S24_F687: string (nullable = true)
#  |-- L1_S24_F691: string (nullable = true)
#  |-- L1_S24_F700: string (nullable = true)
#  |-- L1_S24_F719: string (nullable = true)
#  |-- L1_S24_F728: string (nullable = true)
#  |-- L1_S24_F733: string (nullable = true)
#  |-- L1_S24_F746: string (nullable = true)
#  |-- L1_S24_F751: string (nullable = true)
#  |-- L1_S24_F756: string (nullable = true)
#  |-- L1_S24_F761: string (nullable = true)
#  |-- L1_S24_F766: string (nullable = true)
#  |-- L1_S24_F775: string (nullable = true)
#  |-- L1_S24_F780: string (nullable = true)
#  |-- L1_S24_F785: string (nullable = true)
#  |-- L1_S24_F790: string (nullable = true)
#  |-- L1_S24_F795: string (nullable = true)
#  |-- L1_S24_F800: string (nullable = true)
#  |-- L1_S24_F802: string (nullable = true)
#  |-- L1_S24_F806: string (nullable = true)
#  |-- L1_S24_F808: string (nullable = true)
#  |-- L1_S24_F810: string (nullable = true)
#  |-- L1_S24_F812: string (nullable = true)
#  |-- L1_S24_F814: string (nullable = true)
#  |-- L1_S24_F816: string (nullable = true)
#  |-- L1_S24_F829: string (nullable = true)
#  |-- L1_S24_F834: string (nullable = true)
#  |-- L1_S24_F839: string (nullable = true)
#  |-- L1_S24_F844: string (nullable = true)
#  |-- L1_S24_F857: string (nullable = true)
#  |-- L1_S24_F862: string (nullable = true)
#  |-- L1_S24_F867: string (nullable = true)
#  |-- L1_S24_F872: string (nullable = true)
#  |-- L1_S24_F877: string (nullable = true)
#  |-- L1_S24_F882: string (nullable = true)
#  |-- L1_S24_F887: string (nullable = true)
#  |-- L1_S24_F892: string (nullable = true)
#  |-- L1_S24_F897: string (nullable = true)
#  |-- L1_S24_F902: string (nullable = true)
#  |-- L1_S24_F907: string (nullable = true)
#  |-- L1_S24_F920: string (nullable = true)
#  |-- L1_S24_F925: string (nullable = true)
#  |-- L1_S24_F930: string (nullable = true)
#  |-- L1_S24_F935: string (nullable = true)
#  |-- L1_S24_F948: string (nullable = true)
#  |-- L1_S24_F953: string (nullable = true)
#  |-- L1_S24_F958: string (nullable = true)
#  |-- L1_S24_F963: string (nullable = true)
#  |-- L1_S24_F968: string (nullable = true)
#  |-- L1_S24_F973: string (nullable = true)
#  |-- L1_S24_F978: string (nullable = true)
#  |-- L1_S24_F983: string (nullable = true)
#  |-- L1_S24_F988: string (nullable = true)
#  |-- L1_S24_F993: string (nullable = true)
#  |-- L1_S24_F998: string (nullable = true)
#  |-- L1_S24_F1000: string (nullable = true)
#  |-- L1_S24_F1002: string (nullable = true)
#  |-- L1_S24_F1004: string (nullable = true)
#  |-- L1_S24_F1006: string (nullable = true)
#  |-- L1_S24_F1008: string (nullable = true)
#  |-- L1_S24_F1010: string (nullable = true)
#  |-- L1_S24_F1012: string (nullable = true)
#  |-- L1_S24_F1014: string (nullable = true)
#  |-- L1_S24_F1016: string (nullable = true)
#  |-- L1_S24_F1021: string (nullable = true)
#  |-- L1_S24_F1026: string (nullable = true)
#  |-- L1_S24_F1031: string (nullable = true)
#  |-- L1_S24_F1036: string (nullable = true)
#  |-- L1_S24_F1041: string (nullable = true)
#  |-- L1_S24_F1046: string (nullable = true)
#  |-- L1_S24_F1051: string (nullable = true)
#  |-- L1_S24_F1056: string (nullable = true)
#  |-- L1_S24_F1068: string (nullable = true)
#  |-- L1_S24_F1072: string (nullable = true)
#  |-- L1_S24_F1079: string (nullable = true)
#  |-- L1_S24_F1083: string (nullable = true)
#  |-- L1_S24_F1087: string (nullable = true)
#  |-- L1_S24_F1094: string (nullable = true)
#  |-- L1_S24_F1098: string (nullable = true)
#  |-- L1_S24_F1102: string (nullable = true)
#  |-- L1_S24_F1106: string (nullable = true)
#  |-- L1_S24_F1110: string (nullable = true)
#  |-- L1_S24_F1118: string (nullable = true)
#  |-- L1_S24_F1122: string (nullable = true)
#  |-- L1_S24_F1126: string (nullable = true)
#  |-- L1_S24_F1130: string (nullable = true)
#  |-- L1_S24_F1134: string (nullable = true)
#  |-- L1_S24_F1145: string (nullable = true)
#  |-- L1_S24_F1148: string (nullable = true)
#  |-- L1_S24_F1161: string (nullable = true)
#  |-- L1_S24_F1166: string (nullable = true)
#  |-- L1_S24_F1170: string (nullable = true)
#  |-- L1_S24_F1172: string (nullable = true)
#  |-- L1_S24_F1174: string (nullable = true)
#  |-- L1_S24_F1176: string (nullable = true)
#  |-- L1_S24_F1180: string (nullable = true)
#  |-- L1_S24_F1184: string (nullable = true)
#  |-- L1_S24_F1197: string (nullable = true)
#  |-- L1_S24_F1202: string (nullable = true)
#  |-- L1_S24_F1207: string (nullable = true)
#  |-- L1_S24_F1212: string (nullable = true)
#  |-- L1_S24_F1225: string (nullable = true)
#  |-- L1_S24_F1230: string (nullable = true)
#  |-- L1_S24_F1235: string (nullable = true)
#  |-- L1_S24_F1240: string (nullable = true)
#  |-- L1_S24_F1245: string (nullable = true)
#  |-- L1_S24_F1250: string (nullable = true)
#  |-- L1_S24_F1255: string (nullable = true)
#  |-- L1_S24_F1260: string (nullable = true)
#  |-- L1_S24_F1265: string (nullable = true)
#  |-- L1_S24_F1270: string (nullable = true)
#  |-- L1_S24_F1275: string (nullable = true)
#  |-- L1_S24_F1288: string (nullable = true)
#  |-- L1_S24_F1293: string (nullable = true)
#  |-- L1_S24_F1298: string (nullable = true)
#  |-- L1_S24_F1303: string (nullable = true)
#  |-- L1_S24_F1316: string (nullable = true)
#  |-- L1_S24_F1321: string (nullable = true)
#  |-- L1_S24_F1326: string (nullable = true)
#  |-- L1_S24_F1331: string (nullable = true)
#  |-- L1_S24_F1336: string (nullable = true)
#  |-- L1_S24_F1341: string (nullable = true)
#  |-- L1_S24_F1346: string (nullable = true)
#  |-- L1_S24_F1351: string (nullable = true)
#  |-- L1_S24_F1356: string (nullable = true)
#  |-- L1_S24_F1361: string (nullable = true)
#  |-- L1_S24_F1366: string (nullable = true)
#  |-- L1_S24_F1371: string (nullable = true)
#  |-- L1_S24_F1376: string (nullable = true)
#  |-- L1_S24_F1381: string (nullable = true)
#  |-- L1_S24_F1386: string (nullable = true)
#  |-- L1_S24_F1391: string (nullable = true)
#  |-- L1_S24_F1396: string (nullable = true)
#  |-- L1_S24_F1401: string (nullable = true)
#  |-- L1_S24_F1406: string (nullable = true)
#  |-- L1_S24_F1411: string (nullable = true)
#  |-- L1_S24_F1416: string (nullable = true)
#  |-- L1_S24_F1421: string (nullable = true)
#  |-- L1_S24_F1426: string (nullable = true)
#  |-- L1_S24_F1431: string (nullable = true)
#  |-- L1_S24_F1436: string (nullable = true)
#  |-- L1_S24_F1441: string (nullable = true)
#  |-- L1_S24_F1446: string (nullable = true)
#  |-- L1_S24_F1451: string (nullable = true)
#  |-- L1_S24_F1463: string (nullable = true)
#  |-- L1_S24_F1467: string (nullable = true)
#  |-- L1_S24_F1474: string (nullable = true)
#  |-- L1_S24_F1478: string (nullable = true)
#  |-- L1_S24_F1482: string (nullable = true)
#  |-- L1_S24_F1486: string (nullable = true)
#  |-- L1_S24_F1490: string (nullable = true)
#  |-- L1_S24_F1494: string (nullable = true)
#  |-- L1_S24_F1498: string (nullable = true)
#  |-- L1_S24_F1502: string (nullable = true)
#  |-- L1_S24_F1506: string (nullable = true)
#  |-- L1_S24_F1512: string (nullable = true)
#  |-- L1_S24_F1514: string (nullable = true)
#  |-- L1_S24_F1516: string (nullable = true)
#  |-- L1_S24_F1518: string (nullable = true)
#  |-- L1_S24_F1520: string (nullable = true)
#  |-- L1_S24_F1539: string (nullable = true)
#  |-- L1_S24_F1544: string (nullable = true)
#  |-- L1_S24_F1565: string (nullable = true)
#  |-- L1_S24_F1567: string (nullable = true)
#  |-- L1_S24_F1569: string (nullable = true)
#  |-- L1_S24_F1571: string (nullable = true)
#  |-- L1_S24_F1573: string (nullable = true)
#  |-- L1_S24_F1575: string (nullable = true)
#  |-- L1_S24_F1578: string (nullable = true)
#  |-- L1_S24_F1581: string (nullable = true)
#  |-- L1_S24_F1594: string (nullable = true)
#  |-- L1_S24_F1599: string (nullable = true)
#  |-- L1_S24_F1604: string (nullable = true)
#  |-- L1_S24_F1609: string (nullable = true)
#  |-- L1_S24_F1622: string (nullable = true)
#  |-- L1_S24_F1627: string (nullable = true)
#  |-- L1_S24_F1632: string (nullable = true)
#  |-- L1_S24_F1637: string (nullable = true)
#  |-- L1_S24_F1642: string (nullable = true)
#  |-- L1_S24_F1647: string (nullable = true)
#  |-- L1_S24_F1652: string (nullable = true)
#  |-- L1_S24_F1657: string (nullable = true)
#  |-- L1_S24_F1662: string (nullable = true)
#  |-- L1_S24_F1667: string (nullable = true)
#  |-- L1_S24_F1672: string (nullable = true)
#  |-- L1_S24_F1685: string (nullable = true)
#  |-- L1_S24_F1690: string (nullable = true)
#  |-- L1_S24_F1695: string (nullable = true)
#  |-- L1_S24_F1700: string (nullable = true)
#  |-- L1_S24_F1713: string (nullable = true)
#  |-- L1_S24_F1718: string (nullable = true)
#  |-- L1_S24_F1723: string (nullable = true)
#  |-- L1_S24_F1728: string (nullable = true)
#  |-- L1_S24_F1733: string (nullable = true)
#  |-- L1_S24_F1738: string (nullable = true)
#  |-- L1_S24_F1743: string (nullable = true)
#  |-- L1_S24_F1748: string (nullable = true)
#  |-- L1_S24_F1753: string (nullable = true)
#  |-- L1_S24_F1758: string (nullable = true)
#  |-- L1_S24_F1763: string (nullable = true)
#  |-- L1_S24_F1768: string (nullable = true)
#  |-- L1_S24_F1773: string (nullable = true)
#  |-- L1_S24_F1778: string (nullable = true)
#  |-- L1_S24_F1783: string (nullable = true)
#  |-- L1_S24_F1788: string (nullable = true)
#  |-- L1_S24_F1793: string (nullable = true)
#  |-- L1_S24_F1798: string (nullable = true)
#  |-- L1_S24_F1803: string (nullable = true)
#  |-- L1_S24_F1808: string (nullable = true)
#  |-- L1_S24_F1810: string (nullable = true)
#  |-- L1_S24_F1812: string (nullable = true)
#  |-- L1_S24_F1814: string (nullable = true)
#  |-- L1_S24_F1816: string (nullable = true)
#  |-- L1_S24_F1818: string (nullable = true)
#  |-- L1_S24_F1820: string (nullable = true)
#  |-- L1_S24_F1822: string (nullable = true)
#  |-- L1_S24_F1824: string (nullable = true)
#  |-- L1_S24_F1829: string (nullable = true)
#  |-- L1_S24_F1831: string (nullable = true)
#  |-- L1_S24_F1834: string (nullable = true)
#  |-- L1_S24_F1836: string (nullable = true)
#  |-- L1_S24_F1838: string (nullable = true)
#  |-- L1_S24_F1840: string (nullable = true)
#  |-- L1_S24_F1842: string (nullable = true)
#  |-- L1_S24_F1844: string (nullable = true)
#  |-- L1_S24_F1846: string (nullable = true)
#  |-- L1_S24_F1848: string (nullable = true)
#  |-- L1_S24_F1850: string (nullable = true)
#  |-- L1_S25_F1855: string (nullable = true)
#  |-- L1_S25_F1858: string (nullable = true)
#  |-- L1_S25_F1865: string (nullable = true)
#  |-- L1_S25_F1869: string (nullable = true)
#  |-- L1_S25_F1873: string (nullable = true)
#  |-- L1_S25_F1877: string (nullable = true)
#  |-- L1_S25_F1881: string (nullable = true)
#  |-- L1_S25_F1885: string (nullable = true)
#  |-- L1_S25_F1890: string (nullable = true)
#  |-- L1_S25_F1892: string (nullable = true)
#  |-- L1_S25_F1894: string (nullable = true)
#  |-- L1_S25_F1896: string (nullable = true)
#  |-- L1_S25_F1900: string (nullable = true)
#  |-- L1_S25_F1909: string (nullable = true)
#  |-- L1_S25_F1914: string (nullable = true)
#  |-- L1_S25_F1919: string (nullable = true)
#  |-- L1_S25_F1924: string (nullable = true)
#  |-- L1_S25_F1929: string (nullable = true)
#  |-- L1_S25_F1938: string (nullable = true)
#  |-- L1_S25_F1943: string (nullable = true)
#  |-- L1_S25_F1948: string (nullable = true)
#  |-- L1_S25_F1953: string (nullable = true)
#  |-- L1_S25_F1958: string (nullable = true)
#  |-- L1_S25_F1963: string (nullable = true)
#  |-- L1_S25_F1968: string (nullable = true)
#  |-- L1_S25_F1973: string (nullable = true)
#  |-- L1_S25_F1978: string (nullable = true)
#  |-- L1_S25_F1987: string (nullable = true)
#  |-- L1_S25_F1992: string (nullable = true)
#  |-- L1_S25_F1997: string (nullable = true)
#  |-- L1_S25_F2002: string (nullable = true)
#  |-- L1_S25_F2007: string (nullable = true)
#  |-- L1_S25_F2016: string (nullable = true)
#  |-- L1_S25_F2021: string (nullable = true)
#  |-- L1_S25_F2026: string (nullable = true)
#  |-- L1_S25_F2031: string (nullable = true)
#  |-- L1_S25_F2036: string (nullable = true)
#  |-- L1_S25_F2041: string (nullable = true)
#  |-- L1_S25_F2046: string (nullable = true)
#  |-- L1_S25_F2051: string (nullable = true)
#  |-- L1_S25_F2056: string (nullable = true)
#  |-- L1_S25_F2061: string (nullable = true)
#  |-- L1_S25_F2066: string (nullable = true)
#  |-- L1_S25_F2071: string (nullable = true)
#  |-- L1_S25_F2076: string (nullable = true)
#  |-- L1_S25_F2081: string (nullable = true)
#  |-- L1_S25_F2086: string (nullable = true)
#  |-- L1_S25_F2091: string (nullable = true)
#  |-- L1_S25_F2096: string (nullable = true)
#  |-- L1_S25_F2101: string (nullable = true)
#  |-- L1_S25_F2106: string (nullable = true)
#  |-- L1_S25_F2111: string (nullable = true)
#  |-- L1_S25_F2116: string (nullable = true)
#  |-- L1_S25_F2121: string (nullable = true)
#  |-- L1_S25_F2126: string (nullable = true)
#  |-- L1_S25_F2131: string (nullable = true)
#  |-- L1_S25_F2136: string (nullable = true)
#  |-- L1_S25_F2144: string (nullable = true)
#  |-- L1_S25_F2147: string (nullable = true)
#  |-- L1_S25_F2152: string (nullable = true)
#  |-- L1_S25_F2155: string (nullable = true)
#  |-- L1_S25_F2158: string (nullable = true)
#  |-- L1_S25_F2161: string (nullable = true)
#  |-- L1_S25_F2164: string (nullable = true)
#  |-- L1_S25_F2167: string (nullable = true)
#  |-- L1_S25_F2170: string (nullable = true)
#  |-- L1_S25_F2173: string (nullable = true)
#  |-- L1_S25_F2176: string (nullable = true)
#  |-- L1_S25_F2181: string (nullable = true)
#  |-- L1_S25_F2184: string (nullable = true)
#  |-- L1_S25_F2187: string (nullable = true)
#  |-- L1_S25_F2190: string (nullable = true)
#  |-- L1_S25_F2193: string (nullable = true)
#  |-- L1_S25_F2196: string (nullable = true)
#  |-- L1_S25_F2199: string (nullable = true)
#  |-- L1_S25_F2202: string (nullable = true)
#  |-- L1_S25_F2207: string (nullable = true)
#  |-- L1_S25_F2210: string (nullable = true)
#  |-- L1_S25_F2217: string (nullable = true)
#  |-- L1_S25_F2220: string (nullable = true)
#  |-- L1_S25_F2223: string (nullable = true)
#  |-- L1_S25_F2226: string (nullable = true)
#  |-- L1_S25_F2231: string (nullable = true)
#  |-- L1_S25_F2233: string (nullable = true)
#  |-- L1_S25_F2237: string (nullable = true)
#  |-- L1_S25_F2239: string (nullable = true)
#  |-- L1_S25_F2241: string (nullable = true)
#  |-- L1_S25_F2243: string (nullable = true)
#  |-- L1_S25_F2245: string (nullable = true)
#  |-- L1_S25_F2247: string (nullable = true)
#  |-- L1_S25_F2249: string (nullable = true)
#  |-- L1_S25_F2258: string (nullable = true)
#  |-- L1_S25_F2263: string (nullable = true)
#  |-- L1_S25_F2268: string (nullable = true)
#  |-- L1_S25_F2273: string (nullable = true)
#  |-- L1_S25_F2278: string (nullable = true)
#  |-- L1_S25_F2287: string (nullable = true)
#  |-- L1_S25_F2292: string (nullable = true)
#  |-- L1_S25_F2297: string (nullable = true)
#  |-- L1_S25_F2302: string (nullable = true)
#  |-- L1_S25_F2307: string (nullable = true)
#  |-- L1_S25_F2312: string (nullable = true)
#  |-- L1_S25_F2317: string (nullable = true)
#  |-- L1_S25_F2322: string (nullable = true)
#  |-- L1_S25_F2327: string (nullable = true)
#  |-- L1_S25_F2336: string (nullable = true)
#  |-- L1_S25_F2341: string (nullable = true)
#  |-- L1_S25_F2346: string (nullable = true)
#  |-- L1_S25_F2351: string (nullable = true)
#  |-- L1_S25_F2356: string (nullable = true)
#  |-- L1_S25_F2365: string (nullable = true)
#  |-- L1_S25_F2370: string (nullable = true)
#  |-- L1_S25_F2375: string (nullable = true)
#  |-- L1_S25_F2380: string (nullable = true)
#  |-- L1_S25_F2385: string (nullable = true)
#  |-- L1_S25_F2390: string (nullable = true)
#  |-- L1_S25_F2395: string (nullable = true)
#  |-- L1_S25_F2400: string (nullable = true)
#  |-- L1_S25_F2405: string (nullable = true)
#  |-- L1_S25_F2408: string (nullable = true)
#  |-- L1_S25_F2411: string (nullable = true)
#  |-- L1_S25_F2414: string (nullable = true)
#  |-- L1_S25_F2417: string (nullable = true)
#  |-- L1_S25_F2420: string (nullable = true)
#  |-- L1_S25_F2423: string (nullable = true)
#  |-- L1_S25_F2426: string (nullable = true)
#  |-- L1_S25_F2429: string (nullable = true)
#  |-- L1_S25_F2431: string (nullable = true)
#  |-- L1_S25_F2433: string (nullable = true)
#  |-- L1_S25_F2435: string (nullable = true)
#  |-- L1_S25_F2437: string (nullable = true)
#  |-- L1_S25_F2439: string (nullable = true)
#  |-- L1_S25_F2441: string (nullable = true)
#  |-- L1_S25_F2443: string (nullable = true)
#  |-- L1_S25_F2449: string (nullable = true)
#  |-- L1_S25_F2451: string (nullable = true)
#  |-- L1_S25_F2454: string (nullable = true)
#  |-- L1_S25_F2456: string (nullable = true)
#  |-- L1_S25_F2458: string (nullable = true)
#  |-- L1_S25_F2460: string (nullable = true)
#  |-- L1_S25_F2462: string (nullable = true)
#  |-- L1_S25_F2464: string (nullable = true)
#  |-- L1_S25_F2466: string (nullable = true)
#  |-- L1_S25_F2468: string (nullable = true)
#  |-- L1_S25_F2472: string (nullable = true)
#  |-- L1_S25_F2475: string (nullable = true)
#  |-- L1_S25_F2478: string (nullable = true)
#  |-- L1_S25_F2481: string (nullable = true)
#  |-- L1_S25_F2484: string (nullable = true)
#  |-- L1_S25_F2487: string (nullable = true)
#  |-- L1_S25_F2490: string (nullable = true)
#  |-- L1_S25_F2493: string (nullable = true)
#  |-- L1_S25_F2498: string (nullable = true)
#  |-- L1_S25_F2500: string (nullable = true)
#  |-- L1_S25_F2504: string (nullable = true)
#  |-- L1_S25_F2506: string (nullable = true)
#  |-- L1_S25_F2508: string (nullable = true)
#  |-- L1_S25_F2510: string (nullable = true)
#  |-- L1_S25_F2512: string (nullable = true)
#  |-- L1_S25_F2514: string (nullable = true)
#  |-- L1_S25_F2516: string (nullable = true)
#  |-- L1_S25_F2525: string (nullable = true)
#  |-- L1_S25_F2530: string (nullable = true)
#  |-- L1_S25_F2535: string (nullable = true)
#  |-- L1_S25_F2540: string (nullable = true)
#  |-- L1_S25_F2545: string (nullable = true)
#  |-- L1_S25_F2554: string (nullable = true)
#  |-- L1_S25_F2559: string (nullable = true)
#  |-- L1_S25_F2564: string (nullable = true)
#  |-- L1_S25_F2569: string (nullable = true)
#  |-- L1_S25_F2574: string (nullable = true)
#  |-- L1_S25_F2579: string (nullable = true)
#  |-- L1_S25_F2584: string (nullable = true)
#  |-- L1_S25_F2589: string (nullable = true)
#  |-- L1_S25_F2594: string (nullable = true)
#  |-- L1_S25_F2603: string (nullable = true)
#  |-- L1_S25_F2608: string (nullable = true)
#  |-- L1_S25_F2613: string (nullable = true)
#  |-- L1_S25_F2618: string (nullable = true)
#  |-- L1_S25_F2623: string (nullable = true)
#  |-- L1_S25_F2632: string (nullable = true)
#  |-- L1_S25_F2637: string (nullable = true)
#  |-- L1_S25_F2642: string (nullable = true)
#  |-- L1_S25_F2647: string (nullable = true)
#  |-- L1_S25_F2652: string (nullable = true)
#  |-- L1_S25_F2657: string (nullable = true)
#  |-- L1_S25_F2662: string (nullable = true)
#  |-- L1_S25_F2667: string (nullable = true)
#  |-- L1_S25_F2672: string (nullable = true)
#  |-- L1_S25_F2677: string (nullable = true)
#  |-- L1_S25_F2682: string (nullable = true)
#  |-- L1_S25_F2687: string (nullable = true)
#  |-- L1_S25_F2692: string (nullable = true)
#  |-- L1_S25_F2697: string (nullable = true)
#  |-- L1_S25_F2702: string (nullable = true)
#  |-- L1_S25_F2707: string (nullable = true)
#  |-- L1_S25_F2712: string (nullable = true)
#  |-- L1_S25_F2714: string (nullable = true)
#  |-- L1_S25_F2716: string (nullable = true)
#  |-- L1_S25_F2718: string (nullable = true)
#  |-- L1_S25_F2720: string (nullable = true)
#  |-- L1_S25_F2722: string (nullable = true)
#  |-- L1_S25_F2724: string (nullable = true)
#  |-- L1_S25_F2726: string (nullable = true)
#  |-- L1_S25_F2732: string (nullable = true)
#  |-- L1_S25_F2734: string (nullable = true)
#  |-- L1_S25_F2737: string (nullable = true)
#  |-- L1_S25_F2739: string (nullable = true)
#  |-- L1_S25_F2741: string (nullable = true)
#  |-- L1_S25_F2743: string (nullable = true)
#  |-- L1_S25_F2745: string (nullable = true)
#  |-- L1_S25_F2747: string (nullable = true)
#  |-- L1_S25_F2749: string (nullable = true)
#  |-- L1_S25_F2751: string (nullable = true)
#  |-- L1_S25_F2755: string (nullable = true)
#  |-- L1_S25_F2758: string (nullable = true)
#  |-- L1_S25_F2761: string (nullable = true)
#  |-- L1_S25_F2764: string (nullable = true)
#  |-- L1_S25_F2767: string (nullable = true)
#  |-- L1_S25_F2770: string (nullable = true)
#  |-- L1_S25_F2773: string (nullable = true)
#  |-- L1_S25_F2776: string (nullable = true)
#  |-- L1_S25_F2781: string (nullable = true)
#  |-- L1_S25_F2783: string (nullable = true)
#  |-- L1_S25_F2787: string (nullable = true)
#  |-- L1_S25_F2789: string (nullable = true)
#  |-- L1_S25_F2791: string (nullable = true)
#  |-- L1_S25_F2793: string (nullable = true)
#  |-- L1_S25_F2795: string (nullable = true)
#  |-- L1_S25_F2797: string (nullable = true)
#  |-- L1_S25_F2799: string (nullable = true)
#  |-- L1_S25_F2808: string (nullable = true)
#  |-- L1_S25_F2813: string (nullable = true)
#  |-- L1_S25_F2818: string (nullable = true)
#  |-- L1_S25_F2823: string (nullable = true)
#  |-- L1_S25_F2828: string (nullable = true)
#  |-- L1_S25_F2837: string (nullable = true)
#  |-- L1_S25_F2842: string (nullable = true)
#  |-- L1_S25_F2847: string (nullable = true)
#  |-- L1_S25_F2852: string (nullable = true)
#  |-- L1_S25_F2857: string (nullable = true)
#  |-- L1_S25_F2862: string (nullable = true)
#  |-- L1_S25_F2867: string (nullable = true)
#  |-- L1_S25_F2872: string (nullable = true)
#  |-- L1_S25_F2877: string (nullable = true)
#  |-- L1_S25_F2886: string (nullable = true)
#  |-- L1_S25_F2891: string (nullable = true)
#  |-- L1_S25_F2896: string (nullable = true)
#  |-- L1_S25_F2901: string (nullable = true)
#  |-- L1_S25_F2906: string (nullable = true)
#  |-- L1_S25_F2915: string (nullable = true)
#  |-- L1_S25_F2920: string (nullable = true)
#  |-- L1_S25_F2925: string (nullable = true)
#  |-- L1_S25_F2930: string (nullable = true)
#  |-- L1_S25_F2935: string (nullable = true)
#  |-- L1_S25_F2940: string (nullable = true)
#  |-- L1_S25_F2945: string (nullable = true)
#  |-- L1_S25_F2950: string (nullable = true)
#  |-- L1_S25_F2955: string (nullable = true)
#  |-- L1_S25_F2960: string (nullable = true)
#  |-- L1_S25_F2965: string (nullable = true)
#  |-- L1_S25_F2970: string (nullable = true)
#  |-- L1_S25_F2975: string (nullable = true)
#  |-- L1_S25_F2980: string (nullable = true)
#  |-- L1_S25_F2985: string (nullable = true)
#  |-- L1_S25_F2990: string (nullable = true)
#  |-- L1_S25_F2995: string (nullable = true)
#  |-- L1_S25_F2997: string (nullable = true)
#  |-- L1_S25_F2999: string (nullable = true)
#  |-- L1_S25_F3001: string (nullable = true)
#  |-- L1_S25_F3003: string (nullable = true)
#  |-- L1_S25_F3005: string (nullable = true)
#  |-- L1_S25_F3007: string (nullable = true)
#  |-- L1_S25_F3009: string (nullable = true)
#  |-- L1_S25_F3015: string (nullable = true)
#  |-- L1_S25_F3017: string (nullable = true)
#  |-- L1_S25_F3020: string (nullable = true)
#  |-- L1_S25_F3022: string (nullable = true)
#  |-- L1_S25_F3024: string (nullable = true)
#  |-- L1_S25_F3026: string (nullable = true)
#  |-- L1_S25_F3028: string (nullable = true)
#  |-- L1_S25_F3030: string (nullable = true)
#  |-- L1_S25_F3032: string (nullable = true)
#  |-- L1_S25_F3034: string (nullable = true)
#  |-- L2_S26_F3036: string (nullable = true)
#  |-- L2_S26_F3040: string (nullable = true)
#  |-- L2_S26_F3047: string (nullable = true)
#  |-- L2_S26_F3051: string (nullable = true)
#  |-- L2_S26_F3055: string (nullable = true)
#  |-- L2_S26_F3062: string (nullable = true)
#  |-- L2_S26_F3069: string (nullable = true)
#  |-- L2_S26_F3073: string (nullable = true)
#  |-- L2_S26_F3077: string (nullable = true)
#  |-- L2_S26_F3106: string (nullable = true)
#  |-- L2_S26_F3113: string (nullable = true)
#  |-- L2_S26_F3117: string (nullable = true)
#  |-- L2_S26_F3121: string (nullable = true)
#  |-- L2_S26_F3125: string (nullable = true)
#  |-- L2_S27_F3129: string (nullable = true)
#  |-- L2_S27_F3133: string (nullable = true)
#  |-- L2_S27_F3140: string (nullable = true)
#  |-- L2_S27_F3144: string (nullable = true)
#  |-- L2_S27_F3148: string (nullable = true)
#  |-- L2_S27_F3155: string (nullable = true)
#  |-- L2_S27_F3162: string (nullable = true)
#  |-- L2_S27_F3166: string (nullable = true)
#  |-- L2_S27_F3170: string (nullable = true)
#  |-- L2_S27_F3199: string (nullable = true)
#  |-- L2_S27_F3206: string (nullable = true)
#  |-- L2_S27_F3210: string (nullable = true)
#  |-- L2_S27_F3214: string (nullable = true)
#  |-- L2_S27_F3218: string (nullable = true)
#  |-- L2_S28_F3222: string (nullable = true)
#  |-- L2_S28_F3226: string (nullable = true)
#  |-- L2_S28_F3233: string (nullable = true)
#  |-- L2_S28_F3237: string (nullable = true)
#  |-- L2_S28_F3241: string (nullable = true)
#  |-- L2_S28_F3248: string (nullable = true)
#  |-- L2_S28_F3255: string (nullable = true)
#  |-- L2_S28_F3259: string (nullable = true)
#  |-- L2_S28_F3263: string (nullable = true)
#  |-- L2_S28_F3292: string (nullable = true)
#  |-- L2_S28_F3299: string (nullable = true)
#  |-- L2_S28_F3303: string (nullable = true)
#  |-- L2_S28_F3307: string (nullable = true)
#  |-- L2_S28_F3311: string (nullable = true)
#  |-- L3_S29_F3315: string (nullable = true)
#  |-- L3_S29_F3318: string (nullable = true)
#  |-- L3_S29_F3321: string (nullable = true)
#  |-- L3_S29_F3324: string (nullable = true)
#  |-- L3_S29_F3327: string (nullable = true)
#  |-- L3_S29_F3330: string (nullable = true)
#  |-- L3_S29_F3333: string (nullable = true)
#  |-- L3_S29_F3336: string (nullable = true)
#  |-- L3_S29_F3339: string (nullable = true)
#  |-- L3_S29_F3342: string (nullable = true)
#  |-- L3_S29_F3345: string (nullable = true)
#  |-- L3_S29_F3348: string (nullable = true)
#  |-- L3_S29_F3351: string (nullable = true)
#  |-- L3_S29_F3354: string (nullable = true)
#  |-- L3_S29_F3357: string (nullable = true)
#  |-- L3_S29_F3360: string (nullable = true)
#  |-- L3_S29_F3367: string (nullable = true)
#  |-- L3_S29_F3370: string (nullable = true)
#  |-- L3_S29_F3373: string (nullable = true)
#  |-- L3_S29_F3376: string (nullable = true)
#  |-- L3_S29_F3379: string (nullable = true)
#  |-- L3_S29_F3382: string (nullable = true)
#  |-- L3_S29_F3385: string (nullable = true)
#  |-- L3_S29_F3388: string (nullable = true)
#  |-- L3_S29_F3395: string (nullable = true)
#  |-- L3_S29_F3398: string (nullable = true)
#  |-- L3_S29_F3401: string (nullable = true)
#  |-- L3_S29_F3404: string (nullable = true)
#  |-- L3_S29_F3407: string (nullable = true)
#  |-- L3_S29_F3412: string (nullable = true)
#  |-- L3_S29_F3421: string (nullable = true)
#  |-- L3_S29_F3424: string (nullable = true)
#  |-- L3_S29_F3427: string (nullable = true)
#  |-- L3_S29_F3430: string (nullable = true)
#  |-- L3_S29_F3433: string (nullable = true)
#  |-- L3_S29_F3436: string (nullable = true)
#  |-- L3_S29_F3439: string (nullable = true)
#  |-- L3_S29_F3442: string (nullable = true)
#  |-- L3_S29_F3449: string (nullable = true)
#  |-- L3_S29_F3452: string (nullable = true)
#  |-- L3_S29_F3455: string (nullable = true)
#  |-- L3_S29_F3458: string (nullable = true)
#  |-- L3_S29_F3461: string (nullable = true)
#  |-- L3_S29_F3464: string (nullable = true)
#  |-- L3_S29_F3467: string (nullable = true)
#  |-- L3_S29_F3470: string (nullable = true)
#  |-- L3_S29_F3473: string (nullable = true)
#  |-- L3_S29_F3476: string (nullable = true)
#  |-- L3_S29_F3479: string (nullable = true)
#  |-- L3_S29_F3482: string (nullable = true)
#  |-- L3_S29_F3485: string (nullable = true)
#  |-- L3_S29_F3488: string (nullable = true)
#  |-- L3_S29_F3491: string (nullable = true)
#  |-- L3_S30_F3494: string (nullable = true)
#  |-- L3_S30_F3499: string (nullable = true)
#  |-- L3_S30_F3504: string (nullable = true)
#  |-- L3_S30_F3509: string (nullable = true)
#  |-- L3_S30_F3514: string (nullable = true)
#  |-- L3_S30_F3519: string (nullable = true)
#  |-- L3_S30_F3524: string (nullable = true)
#  |-- L3_S30_F3529: string (nullable = true)
#  |-- L3_S30_F3534: string (nullable = true)
#  |-- L3_S30_F3539: string (nullable = true)
#  |-- L3_S30_F3544: string (nullable = true)
#  |-- L3_S30_F3549: string (nullable = true)
#  |-- L3_S30_F3554: string (nullable = true)
#  |-- L3_S30_F3559: string (nullable = true)
#  |-- L3_S30_F3564: string (nullable = true)
#  |-- L3_S30_F3569: string (nullable = true)
#  |-- L3_S30_F3574: string (nullable = true)
#  |-- L3_S30_F3579: string (nullable = true)
#  |-- L3_S30_F3584: string (nullable = true)
#  |-- L3_S30_F3589: string (nullable = true)
#  |-- L3_S30_F3594: string (nullable = true)
#  |-- L3_S30_F3599: string (nullable = true)
#  |-- L3_S30_F3604: string (nullable = true)
#  |-- L3_S30_F3609: string (nullable = true)
#  |-- L3_S30_F3614: string (nullable = true)
#  |-- L3_S30_F3619: string (nullable = true)
#  |-- L3_S30_F3624: string (nullable = true)
#  |-- L3_S30_F3629: string (nullable = true)
#  |-- L3_S30_F3634: string (nullable = true)
#  |-- L3_S30_F3639: string (nullable = true)
#  |-- L3_S30_F3644: string (nullable = true)
#  |-- L3_S30_F3649: string (nullable = true)
#  |-- L3_S30_F3654: string (nullable = true)
#  |-- L3_S30_F3659: string (nullable = true)
#  |-- L3_S30_F3664: string (nullable = true)
#  |-- L3_S30_F3669: string (nullable = true)
#  |-- L3_S30_F3674: string (nullable = true)
#  |-- L3_S30_F3679: string (nullable = true)
#  |-- L3_S30_F3684: string (nullable = true)
#  |-- L3_S30_F3689: string (nullable = true)
#  |-- L3_S30_F3694: string (nullable = true)
#  |-- L3_S30_F3699: string (nullable = true)
#  |-- L3_S30_F3704: string (nullable = true)
#  |-- L3_S30_F3709: string (nullable = true)
#  |-- L3_S30_F3714: string (nullable = true)
#  |-- L3_S30_F3719: string (nullable = true)
#  |-- L3_S30_F3724: string (nullable = true)
#  |-- L3_S30_F3729: string (nullable = true)
#  |-- L3_S30_F3734: string (nullable = true)
#  |-- L3_S30_F3739: string (nullable = true)
#  |-- L3_S30_F3744: string (nullable = true)
#  |-- L3_S30_F3749: string (nullable = true)
#  |-- L3_S30_F3754: string (nullable = true)
#  |-- L3_S30_F3759: string (nullable = true)
#  |-- L3_S30_F3764: string (nullable = true)
#  |-- L3_S30_F3769: string (nullable = true)
#  |-- L3_S30_F3774: string (nullable = true)
#  |-- L3_S30_F3779: string (nullable = true)
#  |-- L3_S30_F3784: string (nullable = true)
#  |-- L3_S30_F3789: string (nullable = true)
#  |-- L3_S30_F3794: string (nullable = true)
#  |-- L3_S30_F3799: string (nullable = true)
#  |-- L3_S30_F3804: string (nullable = true)
#  |-- L3_S30_F3809: string (nullable = true)
#  |-- L3_S30_F3814: string (nullable = true)
#  |-- L3_S30_F3819: string (nullable = true)
#  |-- L3_S30_F3824: string (nullable = true)
#  |-- L3_S30_F3829: string (nullable = true)
#  |-- L3_S31_F3834: string (nullable = true)
#  |-- L3_S31_F3838: string (nullable = true)
#  |-- L3_S31_F3842: string (nullable = true)
#  |-- L3_S31_F3846: string (nullable = true)
#  |-- L3_S32_F3850: string (nullable = true)
#  |-- L3_S33_F3855: string (nullable = true)
#  |-- L3_S33_F3857: string (nullable = true)
#  |-- L3_S33_F3859: string (nullable = true)
#  |-- L3_S33_F3861: string (nullable = true)
#  |-- L3_S33_F3863: string (nullable = true)
#  |-- L3_S33_F3865: string (nullable = true)
#  |-- L3_S33_F3867: string (nullable = true)
#  |-- L3_S33_F3869: string (nullable = true)
#  |-- L3_S33_F3871: string (nullable = true)
#  |-- L3_S33_F3873: string (nullable = true)
#  |-- L3_S34_F3876: string (nullable = true)
#  |-- L3_S34_F3878: string (nullable = true)
#  |-- L3_S34_F3880: string (nullable = true)
#  |-- L3_S34_F3882: string (nullable = true)
#  |-- L3_S35_F3884: string (nullable = true)
#  |-- L3_S35_F3889: string (nullable = true)
#  |-- L3_S35_F3894: string (nullable = true)
#  |-- L3_S35_F3896: string (nullable = true)
#  |-- L3_S35_F3898: string (nullable = true)
#  |-- L3_S35_F3903: string (nullable = true)
#  |-- L3_S35_F3908: string (nullable = true)
#  |-- L3_S35_F3913: string (nullable = true)
#  |-- L3_S36_F3918: string (nullable = true)
#  |-- L3_S36_F3920: string (nullable = true)
#  |-- L3_S36_F3922: string (nullable = true)
#  |-- L3_S36_F3924: string (nullable = true)
#  |-- L3_S36_F3926: string (nullable = true)
#  |-- L3_S36_F3930: string (nullable = true)
#  |-- L3_S36_F3934: string (nullable = true)
#  |-- L3_S36_F3938: string (nullable = true)
#  |-- L3_S37_F3944: string (nullable = true)
#  |-- L3_S37_F3946: string (nullable = true)
#  |-- L3_S37_F3948: string (nullable = true)
#  |-- L3_S37_F3950: string (nullable = true)
#  |-- L3_S38_F3952: string (nullable = true)
#  |-- L3_S38_F3956: string (nullable = true)
#  |-- L3_S38_F3960: string (nullable = true)
#  |-- L3_S39_F3964: string (nullable = true)
#  |-- L3_S39_F3968: string (nullable = true)
#  |-- L3_S39_F3972: string (nullable = true)
#  |-- L3_S39_F3976: string (nullable = true)
#  |-- L3_S40_F3980: string (nullable = true)
#  |-- L3_S40_F3982: string (nullable = true)
#  |-- L3_S40_F3984: string (nullable = true)
#  |-- L3_S40_F3986: string (nullable = true)
#  |-- L3_S40_F3988: string (nullable = true)
#  |-- L3_S40_F3990: string (nullable = true)
#  |-- L3_S40_F3992: string (nullable = true)
#  |-- L3_S40_F3994: string (nullable = true)
#  |-- L3_S41_F3996: string (nullable = true)
#  |-- L3_S41_F3998: string (nullable = true)
#  |-- L3_S41_F4000: string (nullable = true)
#  |-- L3_S41_F4002: string (nullable = true)
#  |-- L3_S41_F4004: string (nullable = true)
#  |-- L3_S41_F4006: string (nullable = true)
#  |-- L3_S41_F4008: string (nullable = true)
#  |-- L3_S41_F4011: string (nullable = true)
#  |-- L3_S41_F4014: string (nullable = true)
#  |-- L3_S41_F4016: string (nullable = true)
#  |-- L3_S41_F4018: string (nullable = true)
#  |-- L3_S41_F4020: string (nullable = true)
#  |-- L3_S41_F4023: string (nullable = true)
#  |-- L3_S41_F4026: string (nullable = true)
#  |-- L3_S43_F4060: string (nullable = true)
#  |-- L3_S43_F4065: string (nullable = true)
#  |-- L3_S43_F4070: string (nullable = true)
#  |-- L3_S43_F4075: string (nullable = true)
#  |-- L3_S43_F4080: string (nullable = true)
#  |-- L3_S43_F4085: string (nullable = true)
#  |-- L3_S43_F4090: string (nullable = true)
#  |-- L3_S43_F4095: string (nullable = true)
#  |-- L3_S44_F4100: string (nullable = true)
#  |-- L3_S44_F4103: string (nullable = true)
#  |-- L3_S44_F4106: string (nullable = true)
#  |-- L3_S44_F4109: string (nullable = true)
#  |-- L3_S44_F4112: string (nullable = true)
#  |-- L3_S44_F4115: string (nullable = true)
#  |-- L3_S44_F4118: string (nullable = true)
#  |-- L3_S44_F4121: string (nullable = true)
#  |-- L3_S45_F4124: string (nullable = true)
#  |-- L3_S45_F4126: string (nullable = true)
#  |-- L3_S45_F4128: string (nullable = true)
#  |-- L3_S45_F4130: string (nullable = true)
#  |-- L3_S45_F4132: string (nullable = true)
#  |-- L3_S47_F4138: string (nullable = true)
#  |-- L3_S47_F4143: string (nullable = true)
#  |-- L3_S47_F4148: string (nullable = true)
#  |-- L3_S47_F4153: string (nullable = true)
#  |-- L3_S47_F4158: string (nullable = true)
#  |-- L3_S47_F4163: string (nullable = true)
#  |-- L3_S47_F4168: string (nullable = true)
#  |-- L3_S47_F4173: string (nullable = true)
#  |-- L3_S47_F4178: string (nullable = true)
#  |-- L3_S47_F4183: string (nullable = true)
#  |-- L3_S47_F4188: string (nullable = true)
#  |-- L3_S48_F4193: string (nullable = true)
#  |-- L3_S48_F4196: string (nullable = true)
#  |-- L3_S48_F4198: string (nullable = true)
#  |-- L3_S48_F4200: string (nullable = true)
#  |-- L3_S48_F4202: string (nullable = true)
#  |-- L3_S48_F4204: string (nullable = true)
#  |-- L3_S49_F4206: string (nullable = true)
#  |-- L3_S49_F4211: string (nullable = true)
#  |-- L3_S49_F4216: string (nullable = true)
#  |-- L3_S49_F4221: string (nullable = true)
#  |-- L3_S49_F4226: string (nullable = true)
#  |-- L3_S49_F4231: string (nullable = true)
#  |-- L3_S49_F4236: string (nullable = true)
#  |-- L3_S50_F4241: string (nullable = true)
#  |-- L3_S50_F4243: string (nullable = true)
#  |-- L3_S50_F4245: string (nullable = true)
#  |-- L3_S50_F4247: string (nullable = true)
#  |-- L3_S50_F4249: string (nullable = true)
#  |-- L3_S50_F4251: string (nullable = true)
#  |-- L3_S50_F4253: string (nullable = true)
#  |-- L3_S51_F4256: string (nullable = true)
#  |-- L3_S51_F4258: string (nullable = true)
#  |-- L3_S51_F4260: string (nullable = true)
#  |-- L3_S51_F4262: string (nullable = true)
#  |-- Response: string (nullable = true)

# %%
#Let's review a numeric feature (L0_S1_F25), and see it's maximum passed and failed responses:  
 
fail_25 = numeric.select('L0_S1_F24', 'Response')\
        .filter(numeric['L0_S1_F24']\
                .isNotNull())\
        .groupBy('L0_S1_F24', 'Response')\
        .count()\
        .orderBy('Response', 'count', ascending = False)

pass_25 = numeric.select('L0_S1_F24', 'Response')\
        .filter(numeric['L0_S1_F24']\
                .isNotNull())\
        .groupBy('L0_S1_F24', 'Response')\
        .count()\
        .orderBy('count', ascending = False)

# %%
#Maximum pass and Failure Counts: 
fail_25.show(1), pass_25.show(1)
# Out:
# +---------+--------+-----+
# |L0_S1_F24|Response|count|
# +---------+--------+-----+
# |   -0.058|       1|   51|
# +---------+--------+-----+
# only showing top 1 row
#
# +---------+--------+-----+
# |L0_S1_F24|Response|count|
# +---------+--------+-----+
# |   -0.045|       0| 8449|
# +---------+--------+-----+
# only showing top 1 row
# (None, None)

# %%
#What is the size of each dataframe: 

query_cat = """SELECT COUNT(*) FROM category"""
query_date = """SELECT COUNT(*) FROM date"""
query_num = """SELECT COUNT(*) FROM numeric"""

# %%
spark.sql(query_cat).show(), print(len(category.columns))
spark.sql(query_date).show(), print(len(date.columns))
spark.sql(query_num).show(), print(len(numeric.columns))
# Out:
# +--------+
# |count(1)|
# +--------+
# | 1183747|
# +--------+
#
# 2141
# +--------+
# |count(1)|
# +--------+
# | 1183747|
# +--------+
#
# 1157
# +--------+
# |count(1)|
# +--------+
# | 1183747|
# +--------+
#
# 970
# (None, None)

# %%
query_num = """SELECT Response,COUNT(Response),ROUND(COUNT(Response)/1183747,2) AS percent\
                FROM numeric\
                GROUP BY Response"""

# %%
spark.sql(query_num).show()
# Out:
# +--------+---------------+-------+
# |Response|count(Response)|percent|
# +--------+---------------+-------+
# |       0|        1176868|   0.99|
# |       1|           6879|   0.01|
# +--------+---------------+-------+

# %% [markdown]
# #### Observation:
# So, what does this tell us so far?
#
# 1. Feature 25 under -0.58 failed 51 times. (Worst condition)
# 2. Feature 25 under -0.045 passed 8449 times. (Best Condition)
# 3. Since, each dataframe has 1,183,747 rows and some categories don't have date and numeric values given, there will be many missing values, which we will need to filter it out.
# 4. In order to do this, we will need to combine dataframes based on category, date and numeric values, and  reject nulls

# %%
#View tables in pandas: 
category.limit(5).toPandas()
# Out:
#    Id L0_S1_F25 L0_S1_F27 L0_S1_F29 L0_S1_F31 L0_S2_F33 L0_S2_F35 L0_S2_F37  \
# 0   4      None      None      None      None      None      None      None
# 1   6      None      None      None      None      None      None      None
# 2   7      None      None      None      None      None      None      None
# 3   9      None      None      None      None      None      None      None
# 4  11      None      None      None      None      None      None      None
#
#   L0_S2_F39 L0_S2_F41  ... L3_S49_F4225 L3_S49_F4227 L3_S49_F4229  \
# 0      None      None  ...         None         None         None
# 1      None      None  ...         None         None         None
# 2      None      None  ...         None         None         None
# 3      None      None  ...         None         None         None
# 4      None      None  ...         None         None         None
#
#   L3_S49_F4230 L3_S49_F4232 L3_S49_F4234 L3_S49_F4235 L3_S49_F4237  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
#
#   L3_S49_F4239 L3_S49_F4240
# 0         None         None
# 1         None         None
# 2         None         None
# 3         None         None
# 4         None         None
#
# [5 rows x 2141 columns]

# %%
numeric.limit(5).toPandas()
# Out:
#    Id L0_S0_F0 L0_S0_F2 L0_S0_F4 L0_S0_F6 L0_S0_F8 L0_S0_F10 L0_S0_F12  \
# 0   4     0.03   -0.034   -0.197   -0.179    0.118     0.116    -0.015
# 1   6     None     None     None     None     None      None      None
# 2   7    0.088    0.086    0.003   -0.052    0.161     0.025    -0.015
# 3   9   -0.036   -0.064    0.294     0.33    0.074     0.161     0.022
# 4  11   -0.055   -0.086    0.294     0.33    0.118     0.025      0.03
#
#   L0_S0_F14 L0_S0_F16  ... L3_S50_F4245 L3_S50_F4247 L3_S50_F4249  \
# 0    -0.032      0.02  ...         None         None         None
# 1      None      None  ...         None         None         None
# 2    -0.072    -0.225  ...         None         None         None
# 3     0.128    -0.026  ...         None         None         None
# 4     0.168    -0.169  ...         None         None         None
#
#   L3_S50_F4251 L3_S50_F4253 L3_S51_F4256 L3_S51_F4258 L3_S51_F4260  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
#
#   L3_S51_F4262 Response
# 0         None        0
# 1         None        0
# 2         None        0
# 3         None        0
# 4         None        0
#
# [5 rows x 970 columns]

# %%
date.limit(5).toPandas()
# Out:
#    Id L0_S0_D1 L0_S0_D3 L0_S0_D5 L0_S0_D7 L0_S0_D9 L0_S0_D11 L0_S0_D13  \
# 0   4    82.24    82.24    82.24    82.24    82.24     82.24     82.24
# 1   6     None     None     None     None     None      None      None
# 2   7   1618.7   1618.7   1618.7   1618.7   1618.7    1618.7    1618.7
# 3   9   1149.2   1149.2   1149.2   1149.2   1149.2    1149.2    1149.2
# 4  11   602.64   602.64   602.64   602.64   602.64    602.64    602.64
#
#   L0_S0_D15 L0_S0_D17  ... L3_S50_D4246 L3_S50_D4248 L3_S50_D4250  \
# 0     82.24     82.24  ...         None         None         None
# 1      None      None  ...         None         None         None
# 2    1618.7    1618.7  ...         None         None         None
# 3    1149.2    1149.2  ...         None         None         None
# 4    602.64    602.64  ...         None         None         None
#
#   L3_S50_D4252 L3_S50_D4254 L3_S51_D4255 L3_S51_D4257 L3_S51_D4259  \
# 0         None         None         None         None         None
# 1         None         None         None         None         None
# 2         None         None         None         None         None
# 3         None         None         None         None         None
# 4         None         None         None         None         None
#
#   L3_S51_D4261 L3_S51_D4263
# 0         None         None
# 1         None         None
# 2         None         None
# 3         None         None
# 4         None         None
#
# [5 rows x 1157 columns]

# %%
# Find number of assembly steps in each production line: 
#Columns specific to 4 production lines: 
L0_cols = [] #Production line 1
L1_cols = [] #Production line 2
L2_cols = [] #Production line 3
L3_cols = [] #Production line 4
for i in category.columns: 
    if i[0:2]=="L0":
        L0_cols.append(i)
    if i[0:2]=="L1":
        L1_cols.append(i)
    if i[0:2]=="L2":
        L2_cols.append(i)
    if i[0:2]=="L3":
        L3_cols.append(i)

# %%
#Production Line 1: 
df_l0 = category.select(L0_cols)
print("Columns in Line 1:", len(df_l0.columns)) 

#Production Line 2: 
df_l1 = category.select(L1_cols)
print("Columns in Line 2:",len(df_l1.columns)) 

#Production Line 3: 
df_l2 = category.select(L2_cols)
print("Columns in Line 3:",len(df_l2.columns)) 

#Production Line 4: 
df_l3 = category.select(L3_cols)
print("Columns in Line 4:",len(df_l3.columns)) 

#So, line 2 seems to have the most combination of stations and category features getting assesmbled.
# Out:
# Columns in Line 1: 323
# Columns in Line 2: 1227
# Columns in Line 3: 159
# Columns in Line 4: 431

# %%
#Spark Function: 
#Yields subcomponents and its count per production line
#Wile removing null values and empty pandas dataframe.
#Limit of subcomponents has been set to 1000 components.

def summarize_cat(df):
    for i in df.schema.names[1:]:
        df_cat = df.select(i).dropna().groupBy(i).count().orderBy('count', ascending= False).limit(1000).toPandas()
        if not df_cat.empty:
            yield pd.DataFrame(df_cat,columns = [df_cat.columns[0], 'count'])

# %%
# %%time
#Storing aggregated values as a list. 
#Collecting production line number (LSF)
#Components (T1, T2..Tn)
#Count of each sub-component (T = 25, T2 =35..Tn=z) 

production_line = []
components = []
for j in summarize_cat(category):
    production_line.append(j.columns[0])
    components.append(j.values[0:])
# Out:
# CPU times: user 19.6 s, sys: 3.58 s, total: 23.2 s
# Wall time: 6h 47min 26s

# %%
#Build Dataframe: 
df_summary = pd.DataFrame({"production_line":production_line, 'components': components})

# %%
df_summary
# Out:
#      production_line                      components
# 0          L0_S1_F25                      [[T1, 25]]
# 1          L0_S1_F27                      [[T9, 25]]
# 2          L0_S1_F29                      [[T1, 27]]
# 3          L0_S1_F31  [[T9, 25], [T24, 1], [T48, 1]]
# 4          L0_S2_F33                     [[T1, 263]]
# ...              ...                             ...
# 1972    L3_S49_F4234                      [[T1, 33]]
# 1973    L3_S49_F4235   [[T16, 33], [T2, 7], [T4, 3]]
# 1974    L3_S49_F4237                      [[T1, 43]]
# 1975    L3_S49_F4239                      [[T1, 33]]
# 1976    L3_S49_F4240   [[T16, 33], [T2, 7], [T4, 3]]
#
# [1977 rows x 2 columns]

# %%
#Get Number of Components per production line: 
df_summary['number_of_components'] = [len(j) for j in df_summary['components']]

# %%
df_summary
# Out:
#      production_line                      components  number_of_components
# 0          L0_S1_F25                      [[T1, 25]]                     1
# 1          L0_S1_F27                      [[T9, 25]]                     1
# 2          L0_S1_F29                      [[T1, 27]]                     1
# 3          L0_S1_F31  [[T9, 25], [T24, 1], [T48, 1]]                     3
# 4          L0_S2_F33                     [[T1, 263]]                     1
# ...              ...                             ...                   ...
# 1972    L3_S49_F4234                      [[T1, 33]]                     1
# 1973    L3_S49_F4235   [[T16, 33], [T2, 7], [T4, 3]]                     3
# 1974    L3_S49_F4237                      [[T1, 43]]                     1
# 1975    L3_S49_F4239                      [[T1, 33]]                     1
# 1976    L3_S49_F4240   [[T16, 33], [T2, 7], [T4, 3]]                     3
#
# [1977 rows x 3 columns]

# %%
#Make csv file:
df_summary.to_csv('components_summary.csv')

# %%
#Explode Dataframe: 
df_exp= df_summary.set_index(['production_line', 'number_of_components']).explode('components').explode('components')

# %%
df_exp
# Out:
#                                      components
# production_line number_of_components
# L0_S1_F25       1                            T1
#                 1                            25
# L0_S1_F27       1                            T9
#                 1                            25
# L0_S1_F29       1                            T1
# ...                                         ...
# L3_S49_F4240    3                            33
#                 3                            T2
#                 3                             7
#                 3                            T4
#                 3                             3
#
# [8516 rows x 1 columns]

# %%
#Get Components: 
components = df_exp[df_exp['components'].str.startswith('T')==True]
components
# Out:
#                                      components
# production_line number_of_components
# L0_S1_F25       1                            T1
# L0_S1_F27       1                            T9
# L0_S1_F29       1                            T1
# L0_S1_F31       3                            T9
#                 3                           T24
# ...                                         ...
# L3_S49_F4237    1                            T1
# L3_S49_F4239    1                            T1
# L3_S49_F4240    3                           T16
#                 3                            T2
#                 3                            T4
#
# [4258 rows x 1 columns]

# %%
#Get times_component_used: 
times_component_used = df_exp[df_exp['components'].str.startswith('T')!=True].rename(columns= {"components": "times_component_used"})
times_component_used
# Out:
#                                      times_component_used
# production_line number_of_components
# L0_S1_F25       1                                      25
# L0_S1_F27       1                                      25
# L0_S1_F29       1                                      27
# L0_S1_F31       3                                      25
#                 3                                       1
# ...                                                   ...
# L3_S49_F4237    1                                      43
# L3_S49_F4239    1                                      33
# L3_S49_F4240    3                                      33
#                 3                                       7
#                 3                                       3
#
# [4258 rows x 1 columns]

# %%
#Merge components and times_components_used:
components_concat = pd.concat([components, times_component_used], join = 'inner', axis = 1).reset_index()

# %%
components_concat

#Ok, this shows us the number of components per line
#and number of times each component was used to manufacture various bosch products.  
#We were able to get rid of the null values and reduce column size from 2141 down to 1977 (i.e. 164 columns)
#Next, let's extract only digits from production line so that we can use that to join columns with numeric and date tables.
# Out:
#      production_line  number_of_components components times_component_used
# 0          L0_S1_F25                     1         T1                   25
# 1          L0_S1_F27                     1         T9                   25
# 2          L0_S1_F29                     1         T1                   27
# 3          L0_S1_F31                     3         T9                   25
# 4          L0_S1_F31                     3        T24                    1
# ...              ...                   ...        ...                  ...
# 4253    L3_S49_F4237                     1         T1                   43
# 4254    L3_S49_F4239                     1         T1                   33
# 4255    L3_S49_F4240                     3        T16                   33
# 4256    L3_S49_F4240                     3         T2                    7
# 4257    L3_S49_F4240                     3         T4                    3
#
# [4258 rows x 4 columns]

# %%
#Category Connection Key: To connect other tables such as numeric and date with category table
#Lets' extract only the digits from production line columns and store this value as an integer. 
#We will use this integer value as a foreign key to connect with other tables. 
components_concat['connection_key_category'] = components_concat['production_line'].apply(lambda x: re.sub(r'([^\d+]+)','', x)).astype('int')

# %%
#Connection key with numeric: Category F25 would have numeric feature as F24. 
#Hence, I converted connection_key_to numeric and then subtracted 1 from it. 
components_concat['connection_key_numeric'] = components_concat.connection_key_category-1

# %%
#Connection Key with date: Category F25 would have a date stamp of D26. 
#Hence, I converted connection key to numeric and then added 1 to it.
components_concat['connection_key_date'] = components_concat.connection_key_category+1

# %%
components_concat

#Here we can see connection_keys stored as integer values
#which can be used to join other summarized tables, as per above.
# Out:
#      production_line  number_of_components components times_component_used  \
# 0          L0_S1_F25                     1         T1                   25
# 1          L0_S1_F27                     1         T9                   25
# 2          L0_S1_F29                     1         T1                   27
# 3          L0_S1_F31                     3         T9                   25
# 4          L0_S1_F31                     3        T24                    1
# ...              ...                   ...        ...                  ...
# 4253    L3_S49_F4237                     1         T1                   43
# 4254    L3_S49_F4239                     1         T1                   33
# 4255    L3_S49_F4240                     3        T16                   33
# 4256    L3_S49_F4240                     3         T2                    7
# 4257    L3_S49_F4240                     3         T4                    3
#
#       connection_key_category  connection_key_numeric  connection_key_date
# 0                         125                     124                  126
# 1                         127                     126                  128
# 2                         129                     128                  130
# 3                         131                     130                  132
# 4                         131                     130                  132
# ...                       ...                     ...                  ...
# 4253                  3494237                 3494236              3494238
# 4254                  3494239                 3494238              3494240
# 4255                  3494240                 3494239              3494241
# 4256                  3494240                 3494239              3494241
# 4257                  3494240                 3494239              3494241
#
# [4258 rows x 7 columns]

# %%
#Let's save this file as csv: 
components_concat.to_csv('components_summary_with_keys.csv')

# %%
#Next, let's look at numeric features first in another notebook. 
#Then we can connect come back here to build some visualizations.
